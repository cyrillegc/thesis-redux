# %%
import requests
import time
import pickle
from bs4 import BeautifulSoup
import re
import json
import pandas as pd
import os
from tqdm import tqdm

# %%
# open data files

with open('data/data_discogs_styles.csv', encoding='utf-8') as file_discogs:
    discogs_df = pd.read_csv(file_discogs, index_col=0)
    discogs_df.dropna(subset=['genre_url'], inplace=True)

with open('data/data_spotify_genres.csv', encoding='utf-8') as file_spotify:
    spotify_df = pd.read_csv(file_spotify, index_col=0)
    
with open('data/data_wikidata_top_genres.csv', encoding='utf-8') as file_wikidata:
    wikidata_df = pd.read_csv(file_wikidata, index_col=0)
    
wikidata_df
# Out:
#        genre_id                         genre_name  \
# 0       Q209498                             2 tone
# 1      Q1751409                      2-step garage
# 2      Q1751409                      2-step garage
# 3      Q1338153       20th-century classical music
# 4      Q4631020       21st-century classical music
# ...         ...                                ...
# 6839   Q2748579                              čoček
# 6840  Q17272400                              şarkı
# 6841  Q17272400                              şarkı
# 6842   Q1103669  țara călatei folk music and dance
# 6843   Q1103669  țara călatei folk music and dance
#
#                       genre_name_edited top_genre_id    top_genre_name  \
# 0                                2 tone       Q54365               ska
# 1                         2 step garage      Q316930       dance music
# 2                         2 step garage        Q9778  electronic music
# 3                20th century classical     Q1583807         art music
# 4                21st century classical     Q1583807         art music
# ...                                 ...          ...               ...
# 6839                              čoček     Q2748579             čoček
# 6840                              şarkı      Q205049       world music
# 6841                              şarkı     Q1583807         art music
# 6842  țara călatei folk music and dance      Q205049       world music
# 6843  țara călatei folk music and dance       Q43343        folk music
#
#       unique_top_genre         everynoise_id         everynoise_name  \
# 0                  0.0                   NaN                     NaN
# 1                  0.0                   NaN                     NaN
# 2                  0.0                   NaN                     NaN
# 3                  0.0                   NaN                     NaN
# 4                  0.0  21stcenturyclassical  21st century classical
# ...                ...                   ...                     ...
# 6839               1.0                   NaN                     NaN
# 6840               0.0                   NaN                     NaN
# 6841               0.0                   NaN                     NaN
# 6842               0.0                   NaN                     NaN
# 6843               0.0                   NaN                     NaN
#
#      discogs_genre_name discogs_style_name
# 0                   NaN                NaN
# 1                   NaN                NaN
# 2                   NaN                NaN
# 3                   NaN                NaN
# 4                   NaN                NaN
# ...                 ...                ...
# 6839                NaN                NaN
# 6840                NaN                NaN
# 6841                NaN                NaN
# 6842                NaN                NaN
# 6843                NaN                NaN
#
# [6844 rows x 10 columns]

# %%
# create dict from spotify_df

spotify_dict = dict()

for idx, row in spotify_df.iterrows():
    spotify_dict[idx] = row['occurrences']
    
print(len(spotify_dict))
spotify_dict
# Out:
# 3684
# {'21st century classical': 6,
#  '5th wave emo': 6,
#  'a cappella': 13,
#  'aarhus indie': 5,
#  'aberdeen indie': 1,
#  'abstract': 4,
#  'abstract beats': 8,
#  'abstract hip hop': 43,
#  'abstract idm': 1,
#  'abstractro': 5,
#  'accordeon': 2,
#  'accordion': 7,
#  'acid house': 19,
#  'acid idm': 5,
#  'acid jazz': 3,
#  'acid rock': 4,
#  'acid techno': 11,
#  'acid trance': 3,
#  'acousmatic': 3,
#  'acoustic blues': 5,
#  'acoustic cover': 3,
#  'acoustic pop': 37,
#  'acoustic punk': 12,
#  'acoustic rock': 13,
#  'action rock': 19,
#  'adoracao': 1,
#  'adult standards': 48,
#  'aesthetic rap': 4,
#  'afghan rap': 1,
#  'african electronic': 6,
#  'african experimental': 3,
#  'african metal': 1,
#  'african percussion': 3,
#  'african reggae': 5,
#  'african rock': 6,
#  'african-american classical': 2,
#  'afrikaans': 1,
#  'afro dancehall': 11,
#  'afro house': 14,
#  'afro psych': 1,
#  'afro r&b': 1,
#  'afro soul': 4,
#  'afro-cuban percussion': 3,
#  'afro-funk': 5,
#  'afrobeat': 32,
#  'afrobeat brasileiro': 1,
#  'afrobeat fusion': 4,
#  'afrofuturism': 25,
#  'afrofuturismo brasileiro': 5,
#  'afropop': 89,
#  'afroswing': 4,
#  'aggrotech': 36,
#  'ai': 2,
#  'alabama indie': 3,
#  'alabama metal': 5,
#  'alabama rap': 2,
#  'alaska indie': 4,
#  'albanian folk': 1,
#  'albanian hip hop': 9,
#  'albanian pop': 7,
#  'albany ny indie': 2,
#  'alberta country': 3,
#  'alberta hip hop': 3,
#  'album rock': 159,
#  'albuquerque indie': 3,
#  'algerian folk': 1,
#  'alphorn': 1,
#  'alpine yodeling': 1,
#  'alt z': 37,
#  'alternative americana': 17,
#  'alternative country': 80,
#  'alternative dance': 166,
#  'alternative emo': 61,
#  'alternative hardcore': 1,
#  'alternative hip hop': 124,
#  'alternative metal': 210,
#  'alternative metalcore': 2,
#  'alternative pop': 25,
#  'alternative pop rock': 4,
#  'alternative r&b': 61,
#  'alternative rock': 213,
#  'alternative roots rock': 19,
#  'ambeat': 3,
#  'ambient': 34,
#  'ambient black metal': 3,
#  'ambient folk': 14,
#  'ambient house': 4,
#  'ambient idm': 7,
#  'ambient industrial': 5,
#  'ambient pop': 7,
#  'ambient post-rock': 3,
#  'ambient psychill': 4,
#  'ambient techno': 11,
#  'ambient trance': 2,
#  'american 21st century classical': 4,
#  'american classical piano': 6,
#  'american contemporary classical': 3,
#  'american folk revival': 1,
#  'american grindcore': 8,
#  'american melodeath': 7,
#  'american metalcore': 8,
#  'american oi': 6,
#  'american orchestra': 1,
#  'american post-rock': 19,
#  'american primitive': 9,
#  'american shoegaze': 10,
#  'amharic pop': 1,
#  'anarcho-punk': 5,
#  'anime': 1,
#  'anime latino': 3,
#  'anime lo-fi': 1,
#  'anime rap': 1,
#  'anime rock': 1,
#  'ann arbor indie': 2,
#  'anthem emo': 39,
#  'anthem worship': 4,
#  'anti-folk': 54,
#  'antideutsche': 45,
#  'appenzeller folk': 2,
#  'arab alternative': 17,
#  'arab electronic': 9,
#  'arab experimental': 3,
#  'arab folk': 13,
#  'arab groove': 7,
#  'arab metal': 1,
#  'arab pop': 4,
#  'arabesk': 3,
#  'arabic hip hop': 4,
#  'arabic jazz': 18,
#  'argentine ambient': 2,
#  'argentine hardcore': 1,
#  'argentine indie': 5,
#  'argentine jazz': 3,
#  'argentine metal': 4,
#  'argentine punk': 6,
#  'argentine reggae': 1,
#  'argentine rock': 11,
#  'argentine telepop': 1,
#  'arizona punk': 3,
#  'arkansas country': 4,
#  'arkansas indie': 3,
#  'arkansas metal': 1,
#  'art pop': 187,
#  'art punk': 15,
#  'art rock': 144,
#  'art song': 4,
#  'asbury park indie': 3,
#  'asheville indie': 4,
#  'asian american hip hop': 4,
#  'athens indie': 7,
#  'atl hip hop': 21,
#  'atl trap': 2,
#  'atlanta indie': 7,
#  'atlanta metal': 10,
#  'atlanta punk': 3,
#  'atmosphere': 2,
#  'atmospheric black metal': 39,
#  'atmospheric dnb': 4,
#  'atmospheric doom': 8,
#  'atmospheric post-metal': 12,
#  'atmospheric post-rock': 6,
#  'atmospheric sludge': 15,
#  'auckland indie': 7,
#  'audiophile vocal': 4,
#  'aussie drill': 3,
#  'aussie emo': 4,
#  'aussietronica': 9,
#  'austin americana': 3,
#  'austin rock': 4,
#  'austin singer-songwriter': 2,
#  'austindie': 15,
#  'australian alternative pop': 3,
#  'australian alternative rock': 20,
#  'australian ambient': 4,
#  'australian americana': 5,
#  'australian black metal': 5,
#  'australian blues': 5,
#  'australian classical piano': 1,
#  'australian country': 1,
#  'australian dance': 17,
#  'australian death metal': 6,
#  'australian electropop': 6,
#  'australian experimental': 6,
#  'australian garage punk': 20,
#  'australian hardcore': 3,
#  'australian hip hop': 5,
#  'australian house': 3,
#  'australian indie': 29,
#  'australian indie folk': 8,
#  'australian indie rock': 9,
#  'australian indigenous': 2,
#  'australian jazz': 4,
#  'australian metal': 21,
#  'australian metalcore': 10,
#  'australian pop': 36,
#  'australian post-hardcore': 9,
#  'australian post-punk': 3,
#  'australian post-rock': 2,
#  'australian psych': 13,
#  'australian r&b': 3,
#  'australian reggae fusion': 11,
#  'australian rock': 17,
#  'australian shoegaze': 2,
#  'australian singer-songwriter': 13,
#  'australian ska': 4,
#  'australian talent show': 2,
#  'australian techno': 1,
#  'australian thrash metal': 5,
#  'australian trap': 3,
#  'australian underground hip hop': 3,
#  'austrian black metal': 6,
#  'austrian classical piano': 2,
#  'austrian contemporary classical': 1,
#  'austrian dnb': 3,
#  'austrian hip hop': 6,
#  'austrian indie': 10,
#  'austrian jazz': 11,
#  'austrian metal': 21,
#  'austrian orchestra': 4,
#  'austrian pop': 25,
#  'austrian punk': 10,
#  'austrian stoner rock': 6,
#  'austrian techno': 3,
#  'austropop': 22,
#  'auteur-compositeur-interprete quebecois': 16,
#  'autoharp': 2,
#  'autonomous black metal': 12,
#  'avant-garde': 10,
#  'avant-garde black metal': 8,
#  'avant-garde jazz': 47,
#  'avant-garde metal': 31,
#  'avant-rock': 7,
#  'axe': 11,
#  'azeri pop': 1,
#  'azeri rap': 1,
#  'azeri traditional': 2,
#  'azonto': 5,
#  'azontobeats': 13,
#  'bachata': 8,
#  'bachata dominicana': 5,
#  'background jazz': 6,
#  'background music': 4,
#  'background piano': 2,
#  'backing track': 1,
#  'bagpipe': 2,
#  'baiao': 1,
#  'bakersfield sound': 1,
#  'bal-musette': 1,
#  'balafon': 7,
#  'balearic': 13,
#  'balfolk': 3,
#  'balkan beats': 21,
#  'balkan brass': 42,
#  'balkan classical piano': 1,
#  'balkan folk metal': 5,
#  'balkan hip hop': 3,
#  'balkan trap': 2,
#  'ballroom': 3,
#  'baltic black metal': 3,
#  'baltic classical piano': 2,
#  'baltic folk': 2,
#  'baltic post-punk': 2,
#  'baltimore indie': 13,
#  'banda caliente': 1,
#  'bandolim': 1,
#  'bandoneon': 8,
#  'bangalore indie': 2,
#  'bangladeshi rock': 1,
#  'banjo': 9,
#  'barbadian pop': 1,
#  'barbershop': 2,
#  'bard': 2,
#  'bardcore': 1,
#  'barnmusik': 2,
#  'barockinterpreten': 5,
#  'baroque': 2,
#  'baroque brass': 1,
#  'baroque cello': 1,
#  'baroque ensemble': 7,
#  'baroque pop': 29,
#  'baroque singing': 8,
#  'baroque violin': 4,
#  'baroque woodwind': 2,
#  'basel indie': 42,
#  'bass house': 29,
#  'bass music': 62,
#  'bass trap': 15,
#  'bass trip': 3,
#  'basshall': 4,
#  'bassline': 6,
#  'bath indie': 3,
#  'batida': 3,
#  'baton rouge rap': 2,
#  'battle rap': 3,
#  'bay area hip hop': 1,
#  'bay area indie': 27,
#  'bayerischer rap': 10,
#  'bboy': 19,
#  'bc underground hip hop': 5,
#  'beat italiano': 2,
#  'beatboxing': 13,
#  'beatdown': 17,
#  'beatlesque': 6,
#  'bebop': 11,
#  'bedroom pop': 11,
#  'bedroom soul': 2,
#  'belarusian indie': 2,
#  'belarusian metal': 3,
#  'belfast indie': 8,
#  'belfast metal': 1,
#  'belgian black metal': 7,
#  'belgian blues': 6,
#  'belgian dance': 4,
#  'belgian death metal': 2,
#  'belgian edm': 15,
#  'belgian electronic': 3,
#  'belgian experimental': 3,
#  'belgian hardcore': 4,
#  'belgian hip hop': 20,
#  'belgian indie': 51,
#  'belgian indie rock': 18,
#  'belgian jazz': 7,
#  'belgian metal': 18,
#  'belgian modern jazz': 5,
#  'belgian new wave': 6,
#  'belgian pop': 22,
#  'belgian post-rock': 7,
#  'belgian rock': 35,
#  'belgian singer-songwriter': 7,
#  'belgian stoner rock': 7,
#  'belgian techno': 5,
#  'belly dance': 3,
#  'belo horizonte indie': 1,
#  'bemani': 2,
#  'benga': 2,
#  'beninese pop': 2,
#  'bergamo indie': 2,
#  'bergen indie': 14,
#  'berlin minimal techno': 1,
#  'berlin school': 3,
#  'bern indie': 57,
#  'bhangra': 2,
#  'big band': 10,
#  'big beat': 58,
#  'big room': 20,
#  'binaural': 1,
#  'birdsong': 2,
#  'birmingham grime': 2,
#  'birmingham hip hop': 3,
#  'birmingham indie': 5,
#  'birmingham metal': 8,
#  'bitpop': 8,
#  "black 'n' roll": 7,
#  'black death': 24,
#  'black metal': 69,
#  'black metal argentino': 1,
#  'black punk': 5,
#  'black sludge': 15,
#  'black speed metal': 3,
#  'black thrash': 19,
#  'blackened crust': 7,
#  'blackened deathcore': 9,
#  'blackened hardcore': 17,
#  'blackgaze': 20,
#  'blaskapelle': 5,
#  'blasmusik': 8,
#  'bleep techno': 1,
#  'bluegrass': 7,
#  'bluegrass gospel': 3,
#  'blues': 49,
#  'blues band': 3,
#  'blues rock': 122,
#  'blues-rock guitar': 7,
#  'bmore': 8,
#  'bolero': 1,
#  'bolero cubano': 1,
#  'boogaloo': 1,
#  'boogie': 1,
#  'boogie-woogie': 11,
#  'boom bap': 28,
#  'boom bap brasileiro': 1,
#  'boom bap espanol': 1,
#  'bosnian indie': 3,
#  'bossa nova': 24,
#  'bossa nova jazz': 2,
#  'boston electronic': 3,
#  'boston folk': 2,
#  'boston hardcore': 9,
#  'boston hip hop': 13,
#  'boston indie': 3,
#  'boston metal': 9,
#  'boston punk': 5,
#  'boston rock': 18,
#  'bouncy house': 1,
#  'bow pop': 31,
#  'boy band': 20,
#  'braindance': 7,
#  'brass band': 19,
#  'brass band brasileiro': 1,
#  'brass ensemble': 14,
#  'brass quintet': 2,
#  'brazilian bass': 1,
#  'brazilian black metal': 2,
#  'brazilian boogie': 1,
#  'brazilian death metal': 9,
#  'brazilian dnb': 4,
#  'brazilian edm': 6,
#  'brazilian gospel': 3,
#  'brazilian groove metal': 1,
#  'brazilian hardcore': 4,
#  'brazilian hip hop': 6,
#  'brazilian house': 2,
#  'brazilian indie': 6,
#  'brazilian indie rock': 1,
#  'brazilian jazz': 5,
#  'brazilian metal': 7,
#  'brazilian modern jazz': 3,
#  'brazilian percussion': 2,
#  'brazilian post-hardcore': 1,
#  'brazilian power metal': 1,
#  'brazilian progressive metal': 1,
#  'brazilian punk': 4,
#  'brazilian punk rock': 1,
#  'brazilian reggae': 7,
#  'brazilian rock': 13,
#  'brazilian rockabilly': 1,
#  'brazilian soul': 2,
#  'brazilian stoner rock': 2,
#  'brazilian surf rock': 1,
#  'brazilian techno': 4,
#  'brazilian thrash metal': 3,
#  'breakbeat': 18,
#  'breakcore': 12,
#  'breaks': 1,
#  'brega romantico': 1,
#  'breton folk': 7,
#  'brighton indie': 30,
#  'brill building pop': 16,
#  'brisbane indie': 3,
#  'bristol electronic': 14,
#  'bristol indie': 17,
#  'brit funk': 5,
#  'british alternative rock': 32,
#  'british black metal': 9,
#  'british blues': 33,
#  'british brass band': 8,
#  'british choir': 3,
#  'british classical piano': 3,
#  'british contemporary classical': 4,
#  'british country': 1,
#  'british death metal': 15,
#  'british experimental': 23,
#  'british folk': 16,
#  'british grindcore': 7,
#  'british indie rock': 27,
#  'british industrial': 20,
#  'british invasion': 16,
#  'british jazz': 30,
#  'british math rock': 5,
#  'british orchestra': 8,
#  'british post-rock': 11,
#  'british power metal': 6,
#  'british singer-songwriter': 24,
#  'british soul': 34,
#  'british soundtrack': 8,
#  'britpop': 58,
#  'broken beat': 15,
#  'bronx hip hop': 12,
#  'brooklyn drill': 1,
#  'brooklyn indie': 49,
#  'brostep': 33,
#  'brutal death metal': 105,
#  'brutal deathcore': 7,
#  'bubble trance': 20,
#  'bubblegrunge': 42,
#  'bubblegum dance': 22,
#  'bubblegum pop': 13,
#  'buffalo ny indie': 2,
#  'buffalo ny metal': 3,
#  'bulgarian electronic': 2,
#  'bulgarian experimental': 1,
#  'bulgarian folk': 3,
#  'bulgarian indie': 1,
#  'bulgarian metal': 1,
#  'bulgarian pop': 3,
#  'bulgarian rock': 1,
#  'burkinabe pop': 1,
#  'burkinabe traditional': 2,
#  'burundian pop': 2,
#  'bury st edmunds indie': 1,
#  'c-pop': 1,
#  'c86': 14,
#  'cabaret': 1,
#  'calgary indie': 3,
#  'cali rap': 1,
#  'california hardcore': 9,
#  'calming instrumental': 1,
#  'cambodian rock': 1,
#  'cambridge choir': 2,
#  'cambridgeshire indie': 7,
#  'cameroonian pop': 1,
#  'canadian americana': 12,
#  'canadian black metal': 4,
#  'canadian blues': 10,
#  'canadian ccm': 4,
#  'canadian celtic': 5,
#  'canadian classical piano': 3,
#  'canadian contemporary country': 6,
#  'canadian contemporary r&b': 11,
#  'canadian country': 9,
#  'canadian death metal': 3,
#  'canadian drill': 1,
#  'canadian electronic': 17,
#  'canadian electropop': 15,
#  'canadian experimental': 13,
#  'canadian folk': 27,
#  'canadian garage rock': 5,
#  'canadian hardcore': 9,
#  'canadian hip hop': 15,
#  'canadian house': 5,
#  'canadian indie': 71,
#  'canadian indie folk': 14,
#  'canadian indigenous': 2,
#  'canadian latin': 2,
#  'canadian metal': 44,
#  'canadian metalcore': 7,
#  'canadian modern jazz': 2,
#  'canadian old school hip hop': 5,
#  'canadian pop': 27,
#  'canadian pop punk': 6,
#  'canadian post-hardcore': 5,
#  'canadian post-punk': 10,
#  'canadian post-rock': 7,
#  'canadian psychedelic': 1,
#  'canadian psychedelic rock': 11,
#  'canadian punk': 25,
#  'canadian rock': 21,
#  'canadian rockabilly': 5,
#  'canadian shoegaze': 2,
#  'canadian singer-songwriter': 31,
#  'canadian stoner rock': 2,
#  'canadian trap': 4,
#  'canadian underground hip hop': 1,
#  'cancion infantil latinoamericana': 1,
#  'cancion melodica': 1,
#  'candomble': 2,
#  'candy pop': 12,
#  'cantautor': 12,
#  'cantautora argentina': 1,
#  'cante flamenco': 4,
#  'canterbury scene': 3,
#  "canzone d'autore": 12,
#  'canzone genovese': 1,
#  'canzone napoletana': 5,
#  'cape breton folk': 1,
#  'cape breton indie': 1,
#  'cape town indie': 4,
#  'cape verdean folk': 1,
#  'caracas indie': 1,
#  'cardiff indie': 2,
#  'carnatic': 2,
#  'carnatic instrumental': 1,
#  'cascadian black metal': 4,
#  'caucasian classical piano': 5,
#  'cavernous death metal': 7,
#  'ccm': 12,
#  'cedm': 1,
#  'cello': 17,
#  'celtic': 26,
#  'celtic metal': 11,
#  'celtic punk': 20,
#  'celtic rock': 36,
#  'chalga': 2,
#  'chamber choir': 1,
#  'chamber ensemble': 2,
#  'chamber folk': 10,
#  'chamber orchestra': 11,
#  'chamber pop': 51,
#  'chamber psych': 90,
#  'champeta': 1,
#  'channel islands indie': 2,
#  'channel pop': 4,
#  'chanson': 144,
#  'chanson paillarde': 2,
#  'chanson quebecois': 5,
#  'chanson virale': 2,
#  'chaotic black metal': 14,
#  'chaotic hardcore': 29,
#  'chapman stick': 3,
#  'charanga': 1,
#  'charango': 1,
#  'charlotte nc indie': 2,
#  'charlottesville indie': 4,
#  'charred death': 2,
#  'chicago blues': 8,
#  'chicago bop': 2,
#  'chicago drill': 2,
#  'chicago hardcore': 3,
#  'chicago house': 3,
#  'chicago indie': 24,
#  'chicago pop punk': 2,
#  'chicago punk': 11,
#  'chicago rap': 12,
#  'chicano punk': 5,
#  'chicano rap': 8,
#  'chicha': 6,
#  'chihuahua indie': 2,
#  "children's choir": 1,
#  "children's music": 4,
#  'chilean black metal': 1,
#  'chilean indie': 2,
#  'chilean metal': 3,
#  'chilean rock': 4,
#  'chill lounge': 4,
#  'chill out': 1,
#  'chill pop': 2,
#  'chill r&b': 12,
#  'chill-out trance': 1,
#  'chillhop': 23,
#  'chillstep': 8,
#  'chillsynth': 4,
#  'chillwave': 102,
#  'chinderlieder': 28,
#  'chinese classical performance': 3,
#  'chinese classical piano': 4,
#  'chinese electronic': 2,
#  'chinese electropop': 1,
#  'chinese experimental': 1,
#  'chinese indie': 2,
#  'chinese indie pop': 2,
#  'chinese indie rock': 3,
#  'chinese jazz': 1,
#  'chinese metal': 1,
#  'chinese post-punk': 2,
#  'chinese post-rock': 1,
#  'chinese traditional': 2,
#  'chinese worship': 1,
#  'chip hop': 9,
#  'chiptune': 5,
#  'chopped and screwed': 2,
#  'choral': 17,
#  'choro': 2,
#  'choro contemporaneo': 1,
#  'christchurch indie': 4,
#  'christelijk': 3,
#  'christian a cappella': 2,
#  'christian alternative rock': 19,
#  'christian deathcore': 2,
#  'christian hardcore': 16,
#  'christian indie': 1,
#  'christian metal': 25,
#  'christian metalcore': 9,
#  'christian music': 14,
#  'christian pop': 2,
#  'christian power metal': 9,
#  'christian punk': 9,
#  'christian relaxative': 1,
#  'christian rock': 31,
#  'christian uplift': 1,
#  'christlicher rap': 3,
#  'christmas product': 1,
#  'cimbalom': 1,
#  'cinematic post-rock': 5,
#  'circuit': 6,
#  'city pop': 1,
#  'classic afrobeat': 1,
#  'classic arab pop': 3,
#  'classic azeri pop': 1,
#  'classic bangla pop': 1,
#  'classic belgian pop': 2,
#  'classic bhangra': 1,
#  'classic canadian rock': 9,
#  'classic city pop': 2,
#  'classic colombian pop': 1,
#  'classic country pop': 4,
#  'classic czech pop': 1,
#  'classic danish pop': 3,
#  'classic danish rock': 1,
#  'classic dubstep': 29,
#  'classic eurovision': 1,
#  'classic finnish rock': 3,
#  'classic french pop': 18,
#  'classic garage rock': 8,
#  'classic girl group': 1,
#  'classic greek pop': 2,
#  'classic greek rock': 1,
#  'classic hardstyle': 40,
#  'classic house': 7,
#  'classic icelandic pop': 4,
#  'classic indo pop': 1,
#  'classic indonesian rock': 1,
#  'classic israeli pop': 3,
#  'classic italian folk pop': 1,
#  'classic italian pop': 53,
#  'classic j-pop': 1,
#  'classic k-pop': 1,
#  'classic norwegian pop': 6,
#  'classic opm': 1,
#  'classic pakistani pop': 1,
#  'classic persian pop': 4,
#  'classic polish pop': 1,
#  'classic praise': 1,
#  'classic progressive house': 4,
#  'classic rock': 158,
#  'classic romanian pop': 1,
#  'classic russian pop': 3,
#  'classic russian rock': 3,
#  'classic schlager': 52,
#  'classic sinhala pop': 1,
#  'classic soul': 8,
#  'classic soundtrack': 3,
#  'classic swedish pop': 11,
#  'classic uk pop': 9,
#  'classical': 23,
#  'classical accordion': 3,
#  'classical baritone': 5,
#  'classical bass': 3,
#  'classical cello': 16,
#  'classical clarinet': 17,
#  'classical contralto': 1,
#  'classical countertenor': 4,
#  'classical flute': 2,
#  'classical guitar': 3,
#  'classical harp': 5,
#  'classical horn': 1,
#  'classical jazz fusion': 1,
#  'classical mandolin': 2,
#  'classical mezzo-soprano': 7,
#  'classical oboe': 2,
#  'classical organ': 3,
#  'classical percussion': 4,
#  'classical performance': 113,
#  'classical piano': 45,
#  'classical piano trio': 1,
#  'classical saxophone': 1,
#  'classical saxophone quartet': 2,
#  'classical soprano': 26,
#  'classical tenor': 10,
#  'classical trombone': 1,
#  'classical trumpet': 9,
#  'classify': 3,
#  'cleveland indie': 1,
#  'cleveland metal': 4,
#  'coldwave': 1,
#  'collage pop': 4,
#  'cologne electronic': 15,
#  'cologne hip hop': 5,
#  'cologne indie': 21,
#  'colombian black metal': 2,
#  'colombian hip hop': 1,
#  'colombian indie': 2,
#  'colombian pop': 5,
#  'colombian rock': 5,
#  'columbus ohio indie': 2,
#  'combos nacionales': 1,
#  'comedy': 3,
#  'comedy rap': 1,
#  'comedy rock': 1,
#  'comic': 21,
#  'comic metal': 22,
#  'commons': 5,
#  'complextro': 26,
#  'compositional ambient': 58,
#  'comptine africaine': 1,
#  'concertina': 2,
#  'connecticut hardcore': 3,
#  'conscious hip hop': 50,
#  'contemporary classical': 7,
#  'contemporary classical piano': 1,
#  'contemporary country': 23,
#  'contemporary jazz': 138,
#  'contemporary post-bop': 30,
#  'contemporary vocal jazz': 51,
#  'cook islands pop': 1,
#  'cool jazz': 33,
#  'cork indie': 2,
#  'cornish folk': 1,
#  'cornwall indie': 3,
#  'corrido': 1,
#  'corrosion': 13,
#  'corsican folk': 2,
#  'cosmic american': 1,
#  'cosmic black metal': 7,
#  'cosmic death metal': 8,
#  'cosmic post-rock': 5,
#  'country': 31,
#  'country blues': 10,
#  'country dawn': 8,
#  'country pop': 18,
#  'country quebecois': 6,
#  'country rap': 3,
#  'country road': 20,
#  'country rock': 87,
#  'coupe-decale': 1,
#  'coverchill': 2,
#  'covertrance': 2,
#  'cowboy western': 2,
#  'cowpunk': 9,
#  'crack rock steady': 1,
#  'croatian electronic': 2,
#  'croatian hip hop': 1,
#  'croatian indie': 8,
#  'croatian metal': 2,
#  'croatian pop': 6,
#  'croatian rock': 3,
#  'crossover prog': 2,
#  'crossover thrash': 26,
#  'crunk': 3,
#  'crust punk': 19,
#  'cryptic black metal': 1,
#  'cuarteto': 2,
#  'cuatro venezolano': 1,
#  'cuban alternative': 6,
#  'cuban rumba': 2,
#  'cubaton': 3,
#  'cumbia': 2,
#  'cumbia chilena': 2,
#  'cumbia colombiana regia': 1,
#  'cumbia peruana': 1,
#  'cumbia pop': 4,
#  'cumbia ranchera': 1,
#  'cumbia sonorense': 1,
#  'cumbia villera': 5,
#  'cyber metal': 12,
#  'cybergrind': 3,
#  'cyberpunk': 15,
#  'czech classical piano': 1,
#  'czech electronic': 2,
#  'czech folk': 1,
#  'czech hip hop': 1,
#  'czech indie': 3,
#  'czech metal': 5,
#  'czech pop': 4,
#  'czech pop rock': 2,
#  'czech punk': 3,
#  'czech rock': 4,
#  'czech singer-songwriter': 1,
#  'czsk black metal': 2,
#  'czsk hip hop': 5,
#  'czsk reggae': 1,
#  'd-beat': 6,
#  'dabke': 2,
#  'dainuojamoji poezija': 1,
#  'dalarna indie': 1,
#  'dance pop': 247,
#  'dance rock': 33,
#  'dance-punk': 46,
#  'dancefloor dnb': 20,
#  'dancehall': 58,
#  'danish alternative rock': 27,
#  'danish black metal': 5,
#  'danish death metal': 8,
#  'danish electro': 2,
#  'danish electronic': 10,
#  'danish electropop': 14,
#  'danish experimental': 3,
#  'danish folk': 2,
#  'danish hardcore': 2,
#  'danish hip hop': 6,
#  'danish indie': 7,
#  'danish indie pop': 11,
#  'danish jazz': 5,
#  'danish metal': 24,
#  'danish modern jazz': 4,
#  'danish pop': 17,
#  'danish pop rock': 4,
#  'danish post-punk': 4,
#  'danish punk': 2,
#  'danish rock': 15,
#  'danish singer-songwriter': 2,
#  'danish techno': 6,
#  'dansband': 3,
#  'danseband': 1,
#  'dansktop': 1,
#  'danspunk': 2,
#  'darbuka': 2,
#  'dark ambient': 6,
#  'dark black metal': 38,
#  'dark cabaret': 19,
#  'dark clubbing': 18,
#  'dark disco': 11,
#  'dark electro': 33,
#  'dark folk': 2,
#  'dark hardcore': 8,
#  'dark jazz': 29,
#  'dark minimal techno': 4,
#  'dark post-punk': 39,
#  'dark psytrance': 3,
#  'dark rock': 23,
#  'dark techno': 31,
#  'dark trap': 17,
#  'dark wave': 59,
#  'darkstep': 23,
#  'darksynth': 6,
#  'dayton indie': 3,
#  'dc hardcore': 4,
#  'dc indie': 1,
#  "death 'n' roll": 5,
#  'death doom': 7,
#  'death industrial': 5,
#  'death metal': 127,
#  'deathcore': 86,
#  'deathgrass': 11,
#  'deathgrind': 30,
#  'deathrash': 17,
#  'deathrock': 12,
#  'deathstep': 8,
#  'deconstructed club': 35,
#  'deep acoustic pop': 5,
#  'deep big room': 2,
#  'deep breakcore': 2,
#  'deep ccm': 1,
#  'deep chill-out': 1,
#  'deep christian rock': 2,
#  'deep classic garage rock': 1,
#  'deep comedy': 2,
#  'deep dance pop': 5,
#  'deep darkpsy': 1,
#  'deep deep house': 3,
#  'deep disco house': 39,
#  'deep discofox': 1,
#  'deep dnb': 10,
#  'deep dubstep': 16,
#  'deep east coast hip hop': 2,
#  'deep euro house': 50,
#  'deep flow': 1,
#  'deep folk metal': 16,
#  'deep funk': 4,
#  'deep german hip hop': 49,
#  'deep german indie': 6,
#  'deep german punk': 17,
#  'deep gothic post-punk': 15,
#  'deep groove house': 25,
#  'deep hardcore': 2,
#  'deep house': 67,
#  'deep idm': 16,
#  'deep indie pop': 3,
#  'deep indie rock': 1,
#  'deep indie singer-songwriter': 4,
#  'deep italo disco': 1,
#  'deep jazz fusion': 1,
#  'deep latin alternative': 2,
#  'deep latin christian': 1,
#  'deep latin jazz': 1,
#  'deep liquid': 2,
#  'deep liquid bass': 7,
#  'deep melodic death metal': 10,
#  'deep melodic hard rock': 6,
#  'deep melodic metalcore': 7,
#  'deep metalcore': 1,
#  'deep minimal techno': 29,
#  'deep motown': 1,
#  'deep new americana': 54,
#  'deep pop edm': 2,
#  'deep pop emo': 1,
#  'deep power-pop punk': 3,
#  'deep progressive rock': 4,
#  'deep psychobilly': 5,
#  'deep rai': 1,
#  'deep regional mexican': 1,
#  'deep soft rock': 1,
#  'deep soul house': 12,
#  'deep southern trap': 1,
#  'deep space rock': 3,
#  'deep surf music': 2,
#  'deep swedish rock': 2,
#  'deep talent show': 1,
#  'deep tech house': 11,
#  'deep techno': 12,
#  'deep tropical house': 23,
#  'deep turkish pop': 2,
#  'deep underground hip hop': 6,
#  'deep uplifting trance': 3,
#  'delaware indie': 1,
#  'dembow': 2,
#  'demoscene': 1,
#  'denton tx indie': 10,
#  'denver indie': 2,
#  'denver metal': 6,
#  'depressive black metal': 6,
#  'derby indie': 4,
#  'derry indie': 3,
#  'desert blues': 16,
#  'desi hip hop': 2,
#  'desi pop': 3,
#  'destroy techno': 22,
#  'detroit hip hop': 11,
#  'detroit house': 12,
#  'detroit indie': 4,
#  'detroit rock': 11,
#  'detroit techno': 19,
#  'deutschrock': 46,
#  'devon indie': 7,
#  'dfw rap': 1,
#  'didgeridoo': 4,
#  'digital hardcore': 10,
#  'dinner jazz': 1,
#  'dirty south rap': 10,
#  'dirty texas rap': 4,
#  'disco': 24,
#  ...}

# %%
# create dict from wikidata_df
wikidata_dict = dict()

for idx, row in wikidata_df.iterrows():
    genre_id = row['genre_id']
    genre_name = row['genre_name']
    genre_name_edited = row['genre_name_edited']
    top_genre_id = row['top_genre_id']
    top_genre_name = row['top_genre_name']
    unique_top_genre = int(row['unique_top_genre'])
    everynoise_name = row['everynoise_name']
    discogs_style_name = row['discogs_style_name']
    discogs_genre_name = row['discogs_genre_name']
    
    if not pd.notna(everynoise_name):
        everynoise_name = ''
    if not pd.notna(discogs_style_name):
        discogs_style_name = ''
    
    try:
        wikidata_dict[genre_name]['top_genre'][top_genre_name] = {'top_genre_id': top_genre_id, 'unique_top_genre': unique_top_genre}
    except KeyError:    
        wikidata_dict[genre_name] = {
            'genre_id': genre_id,
            'genre_name_edited': genre_name_edited,
            'everynoise_name': everynoise_name,
            'discogs_style_name': discogs_style_name,
            'discogs_genre_name': discogs_genre_name,
            'top_genre': {
                top_genre_name: {
                    'top_genre_id': top_genre_id, 
                    'unique_top_genre': unique_top_genre,
                }}}   

print(len(wikidata_dict))
wikidata_dict
# Out:
# 4574
# {'2 tone': {'genre_id': 'Q209498',
#   'genre_name_edited': '2 tone',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ska': {'top_genre_id': 'Q54365', 'unique_top_genre': 0}}},
#  '2-step garage': {'genre_id': 'Q1751409',
#   'genre_name_edited': '2 step garage',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  '20th-century classical music': {'genre_id': 'Q1338153',
#   'genre_name_edited': '20th century classical',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0}}},
#  '21st-century classical music': {'genre_id': 'Q4631020',
#   'genre_name_edited': '21st century classical',
#   'everynoise_name': '21st century classical',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0}}},
#  '4-beat': {'genre_id': 'Q4637208',
#   'genre_name_edited': '4 beat',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  '60s pop/rock': {'genre_id': 'Q10397358',
#   'genre_name_edited': '60s pop/rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'60s pop/rock': {'top_genre_id': 'Q10397358',
#     'unique_top_genre': 1}}},
#  '8-bit music': {'genre_id': 'Q1980100',
#   'genre_name_edited': '8 bit',
#   'everynoise_name': '8-bit',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0}}},
#  'a capella rock': {'genre_id': 'Q10372501',
#   'genre_name_edited': 'a capella rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'vocal music': {'top_genre_id': 'Q685884', 'unique_top_genre': 0}}},
#  'a cappella': {'genre_id': 'Q185298',
#   'genre_name_edited': 'a cappella',
#   'everynoise_name': 'a cappella',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'vocal music': {'top_genre_id': 'Q685884',
#     'unique_top_genre': 0}}},
#  'aak': {'genre_id': 'Q710673',
#   'genre_name_edited': 'aak',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'abecedarian hymn': {'genre_id': 'Q4666464',
#   'genre_name_edited': 'abecedarian hymn',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hymn': {'top_genre_id': 'Q484692', 'unique_top_genre': 0}}},
#  'abendmusik': {'genre_id': 'Q318973',
#   'genre_name_edited': 'abendmusik',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0}}},
#  'abidat rma': {'genre_id': 'Q12224286',
#   'genre_name_edited': 'abidat rma',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'abidat rma': {'top_genre_id': 'Q12224286',
#     'unique_top_genre': 1}}},
#  'abkhazian folk music': {'genre_id': 'Q106538862',
#   'genre_name_edited': 'abkhazian folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'aboio': {'genre_id': 'Q6039799',
#   'genre_name_edited': 'aboio',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'aboio cantado': {'genre_id': 'Q106641524',
#   'genre_name_edited': 'aboio cantado',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'abozao': {'genre_id': 'Q5655239',
#   'genre_name_edited': 'abozao',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'abozao': {'top_genre_id': 'Q5655239',
#     'unique_top_genre': 1}}},
#  'absolute music': {'genre_id': 'Q332478',
#   'genre_name_edited': 'absolute',
#   'everynoise_name': 'abstract',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'absolute music': {'top_genre_id': 'Q332478',
#     'unique_top_genre': 1}}},
#  'abstract hip hop': {'genre_id': 'Q98528482',
#   'genre_name_edited': 'abstract hip hop',
#   'everynoise_name': 'abstract hip hop',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'abwe': {'genre_id': 'Q4670712',
#   'genre_name_edited': 'abwe',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'abwe': {'top_genre_id': 'Q4670712', 'unique_top_genre': 1}}},
#  'accentus': {'genre_id': 'Q338779',
#   'genre_name_edited': 'accentus',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0},
#    'vocal music': {'top_genre_id': 'Q685884', 'unique_top_genre': 0}}},
#  'acclamatio': {'genre_id': 'Q83390',
#   'genre_name_edited': 'acclamatio',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ancient music': {'top_genre_id': 'Q18846',
#     'unique_top_genre': 0}}},
#  'accordion music': {'genre_id': 'Q4672733',
#   'genre_name_edited': 'accordion',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'acoustic music': {'top_genre_id': 'Q286080',
#     'unique_top_genre': 0}}},
#  'achewiq': {'genre_id': 'Q21028652',
#   'genre_name_edited': 'achewiq',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'achewiq': {'top_genre_id': 'Q21028652',
#     'unique_top_genre': 1}}},
#  'acid blues': {'genre_id': 'Q2823181',
#   'genre_name_edited': 'acid blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0}}},
#  'acid breaks': {'genre_id': 'Q2634010',
#   'genre_name_edited': 'acid breaks',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  'acid croft': {'genre_id': 'Q106641525',
#   'genre_name_edited': 'acid croft',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0}}},
#  'acid house': {'genre_id': 'Q341364',
#   'genre_name_edited': 'acid house',
#   'everynoise_name': 'acid house',
#   'discogs_style_name': 'acid house',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  'acid jazz': {'genre_id': 'Q221772',
#   'genre_name_edited': 'acid jazz',
#   'everynoise_name': 'acid jazz',
#   'discogs_style_name': 'acid jazz',
#   'discogs_genre_name': nan,
#   'top_genre': {'rhythm and blues': {'top_genre_id': 'Q45981',
#     'unique_top_genre': 0},
#    'funk': {'top_genre_id': 'Q164444', 'unique_top_genre': 0}}},
#  'acid music': {'genre_id': 'Q106528337',
#   'genre_name_edited': 'acid',
#   'everynoise_name': '',
#   'discogs_style_name': 'acid',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0}}},
#  'acid rock': {'genre_id': 'Q236932',
#   'genre_name_edited': 'acid rock',
#   'everynoise_name': 'acid rock',
#   'discogs_style_name': 'acid rock',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'psychedelic music': {'top_genre_id': 'Q846119', 'unique_top_genre': 0}}},
#  'acid techno': {'genre_id': 'Q341395',
#   'genre_name_edited': 'acid techno',
#   'everynoise_name': 'acid techno',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'acid trance': {'genre_id': 'Q481900',
#   'genre_name_edited': 'acid trance',
#   'everynoise_name': 'acid trance',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'acidcore': {'genre_id': 'Q341396',
#   'genre_name_edited': 'acidcore',
#   'everynoise_name': 'acidcore',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'acousmatic music': {'genre_id': 'Q423918',
#   'genre_name_edited': 'acousmatic',
#   'everynoise_name': 'acousmatic',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'experimental music': {'top_genre_id': 'Q1640319',
#     'unique_top_genre': 0},
#    'art music': {'top_genre_id': 'Q1583807', 'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'acoustic blues': {'genre_id': 'Q65936357',
#   'genre_name_edited': 'acoustic blues',
#   'everynoise_name': 'acoustic blues',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0}}},
#  'acoustic chicago blues': {'genre_id': 'Q106641530',
#   'genre_name_edited': 'acoustic chicago blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0}}},
#  'acoustic louisiana blues': {'genre_id': 'Q106877999',
#   'genre_name_edited': 'acoustic louisiana blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0}}},
#  'acoustic memphis blues': {'genre_id': 'Q106878000',
#   'genre_name_edited': 'acoustic memphis blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0}}},
#  'acoustic music': {'genre_id': 'Q286080',
#   'genre_name_edited': 'acoustic',
#   'everynoise_name': '',
#   'discogs_style_name': 'acoustic',
#   'discogs_genre_name': nan,
#   'top_genre': {'acoustic music': {'top_genre_id': 'Q286080',
#     'unique_top_genre': 0}}},
#  'acoustic new orleans blues': {'genre_id': 'Q106878001',
#   'genre_name_edited': 'acoustic new orleans blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0}}},
#  'acoustic rock': {'genre_id': 'Q65936391',
#   'genre_name_edited': 'acoustic rock',
#   'everynoise_name': 'acoustic rock',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'acoustic texas blues': {'genre_id': 'Q98528141',
#   'genre_name_edited': 'acoustic texas blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'country music': {'top_genre_id': 'Q83440',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0},
#    'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  "actor's song": {'genre_id': 'Q11817196',
#   'genre_name_edited': "actor's song",
#   'everynoise_name': 'actors',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {"actor's song": {'top_genre_id': 'Q11817196',
#     'unique_top_genre': 1}}},
#  'adhunik geet': {'genre_id': 'Q55642856',
#   'genre_name_edited': 'adhunik geet',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'adhunik geet': {'top_genre_id': 'Q55642856',
#     'unique_top_genre': 1}}},
#  'adjukru music': {'genre_id': 'Q3328577',
#   'genre_name_edited': 'adjukru',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'adult contemporary music': {'genre_id': 'Q378988',
#   'genre_name_edited': 'adult contemporary',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073',
#     'unique_top_genre': 0}}},
#  'adult hits': {'genre_id': 'Q2510800',
#   'genre_name_edited': 'adult hits',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'adult hits': {'top_genre_id': 'Q2510800',
#     'unique_top_genre': 1}}},
#  'adult-oriented pop music': {'genre_id': 'Q4685875',
#   'genre_name_edited': 'adult oriented pop',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'adult-oriented pop music': {'top_genre_id': 'Q4685875',
#     'unique_top_genre': 1}}},
#  'adult-oriented rock': {'genre_id': 'Q16527140',
#   'genre_name_edited': 'adult oriented rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'aegean islands folk music': {'genre_id': 'Q106538881',
#   'genre_name_edited': 'aegean islands folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'afoxê': {'genre_id': 'Q383530',
#   'genre_name_edited': 'afoxê',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'afoxê': {'top_genre_id': 'Q383530', 'unique_top_genre': 1}}},
#  'african blues': {'genre_id': 'Q2907328',
#   'genre_name_edited': 'african blues',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'blues': {'top_genre_id': 'Q9759', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'african folk music': {'genre_id': 'Q98528185',
#   'genre_name_edited': 'african folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'african gospel': {'genre_id': 'Q384064',
#   'genre_name_edited': 'african gospel',
#   'everynoise_name': 'african gospel',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0}}},
#  'african heavy metal': {'genre_id': 'Q17510016',
#   'genre_name_edited': 'african heavy metal',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'african hip hop': {'genre_id': 'Q387236',
#   'genre_name_edited': 'african hip hop',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'african jazz': {'genre_id': 'Q6168369',
#   'genre_name_edited': 'african jazz',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'african popular music': {'genre_id': 'Q972634',
#   'genre_name_edited': 'african popular',
#   'everynoise_name': 'afropop',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'african reggae': {'genre_id': 'Q4690039',
#   'genre_name_edited': 'african reggae',
#   'everynoise_name': 'african reggae',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'music of jamaica': {'top_genre_id': 'Q572717',
#     'unique_top_genre': 0}}},
#  'african-american music': {'genre_id': 'Q388207',
#   'genre_name_edited': 'african american',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'afro': {'genre_id': 'Q25339858',
#   'genre_name_edited': 'afro',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'afro': {'top_genre_id': 'Q25339858', 'unique_top_genre': 1}}},
#  'afro-caribbean music': {'genre_id': 'Q4690168',
#   'genre_name_edited': 'afro caribbean',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'afro-caribbean music': {'top_genre_id': 'Q4690168',
#     'unique_top_genre': 1}}},
#  'afro-cuban jazz': {'genre_id': 'Q3163340',
#   'genre_name_edited': 'afro cuban jazz',
#   'everynoise_name': '',
#   'discogs_style_name': 'afro-cuban jazz',
#   'discogs_genre_name': nan,
#   'top_genre': {'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'afro-funk': {'genre_id': 'Q106641536',
#   'genre_name_edited': 'afro funk',
#   'everynoise_name': 'afro-funk',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'funk': {'top_genre_id': 'Q164444', 'unique_top_genre': 0},
#    'rhythm and blues': {'top_genre_id': 'Q45981', 'unique_top_genre': 0}}},
#  'afro-house': {'genre_id': 'Q388100',
#   'genre_name_edited': 'afro house',
#   'everynoise_name': 'afro house',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'afro-peruvian music': {'genre_id': 'Q16993565',
#   'genre_name_edited': 'afro peruvian',
#   'everynoise_name': 'musica afroperuana',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'afro-peruvian music': {'top_genre_id': 'Q16993565',
#     'unique_top_genre': 1}}},
#  'afro-punk': {'genre_id': 'Q2621049',
#   'genre_name_edited': 'afro punk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'afro-punk': {'top_genre_id': 'Q2621049',
#     'unique_top_genre': 1}}},
#  'afro-rock': {'genre_id': 'Q3606268',
#   'genre_name_edited': 'afro rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'afro-soul': {'genre_id': 'Q16024685',
#   'genre_name_edited': 'afro soul',
#   'everynoise_name': 'afro soul',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rhythm and blues': {'top_genre_id': 'Q45981',
#     'unique_top_genre': 0},
#    'soul music': {'top_genre_id': 'Q131272', 'unique_top_genre': 0}}},
#  'afro-trap': {'genre_id': 'Q26234147',
#   'genre_name_edited': 'afro trap',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'hip hop music': {'top_genre_id': 'Q11401', 'unique_top_genre': 0}}},
#  'afrobeat': {'genre_id': 'Q388296',
#   'genre_name_edited': 'afrobeat',
#   'everynoise_name': 'afrobeat',
#   'discogs_style_name': 'afrobeat',
#   'discogs_genre_name': nan,
#   'top_genre': {'rhythm and blues': {'top_genre_id': 'Q45981',
#     'unique_top_genre': 0},
#    'funk': {'top_genre_id': 'Q164444', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'afrobeats': {'genre_id': 'Q81089861',
#   'genre_name_edited': 'afrobeats',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073', 'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  'afroswing': {'genre_id': 'Q85740017',
#   'genre_name_edited': 'afroswing',
#   'everynoise_name': 'afroswing',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'aggrotech': {'genre_id': 'Q1091450',
#   'genre_name_edited': 'aggrotech',
#   'everynoise_name': 'aggrotech',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0},
#    'experimental music': {'top_genre_id': 'Q1640319', 'unique_top_genre': 0}}},
#  'aguinaldo': {'genre_id': 'Q4694554',
#   'genre_name_edited': 'aguinaldo',
#   'everynoise_name': '',
#   'discogs_style_name': 'aguinaldo',
#   'discogs_genre_name': nan,
#   'top_genre': {'aguinaldo': {'top_genre_id': 'Q4694554',
#     'unique_top_genre': 1}}},
#  'ahellil': {'genre_id': 'Q1406136',
#   'genre_name_edited': 'ahellil',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'ahidous': {'genre_id': 'Q2635155',
#   'genre_name_edited': 'ahidous',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ahidous': {'top_genre_id': 'Q2635155',
#     'unique_top_genre': 1}}},
#  'ahwash': {'genre_id': 'Q4696445',
#   'genre_name_edited': 'ahwash',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ahwash': {'top_genre_id': 'Q4696445',
#     'unique_top_genre': 1}}},
#  'aikawa ondo': {'genre_id': 'Q108430097',
#   'genre_name_edited': 'aikawa ondo',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'ainam': {'genre_id': 'Q84433946',
#   'genre_name_edited': 'ainam',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ainam': {'top_genre_id': 'Q84433946',
#     'unique_top_genre': 1}}},
#  'ainu folk music': {'genre_id': 'Q3735537',
#   'genre_name_edited': 'ainu folk',
#   'everynoise_name': 'ainu folk',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'air': {'genre_id': 'Q406714',
#   'genre_name_edited': 'air',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'air': {'top_genre_id': 'Q406714', 'unique_top_genre': 1}}},
#  'air de cour': {'genre_id': 'Q407916',
#   'genre_name_edited': 'air de cour',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0},
#    'vocal music': {'top_genre_id': 'Q685884', 'unique_top_genre': 0}}},
#  'air à boire': {'genre_id': 'Q4698401',
#   'genre_name_edited': 'air à boire',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'air à boire': {'top_genre_id': 'Q4698401',
#     'unique_top_genre': 1}}},
#  'aire': {'genre_id': 'Q5661311',
#   'genre_name_edited': 'aire',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'aire': {'top_genre_id': 'Q5661311', 'unique_top_genre': 1}}},
#  'aita': {'genre_id': 'Q22949256',
#   'genre_name_edited': 'aita',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'aiyai': {'genre_id': 'Q97774967',
#   'genre_name_edited': 'aiyai',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'aiyai': {'top_genre_id': 'Q97774967',
#     'unique_top_genre': 1}}},
#  'ajisari': {'genre_id': 'Q4699758',
#   'genre_name_edited': 'ajisari',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0}}},
#  'akamoji-kei': {'genre_id': 'Q16687400',
#   'genre_name_edited': 'akamoji kei',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'akan music': {'genre_id': 'Q106641570',
#   'genre_name_edited': 'akan',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'akiba-pop': {'genre_id': 'Q10846275',
#   'genre_name_edited': 'akiba pop',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073',
#     'unique_top_genre': 0}}},
#  'akishibu-kei': {'genre_id': 'Q11282754',
#   'genre_name_edited': 'akishibu kei',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0},
#    'pop music': {'top_genre_id': 'Q37073', 'unique_top_genre': 0}}},
#  'akzhelen': {'genre_id': 'Q12531757',
#   'genre_name_edited': 'akzhelen',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'al ala': {'genre_id': 'Q97277870',
#   'genre_name_edited': 'al ala',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'al ala': {'top_genre_id': 'Q97277870',
#     'unique_top_genre': 1}}},
#  'al jeel': {'genre_id': 'Q2610186',
#   'genre_name_edited': 'al jeel',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'al-hawizi maqam': {'genre_id': 'Q16119301',
#   'genre_name_edited': 'al hawizi maqam',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'al-hawizi maqam': {'top_genre_id': 'Q16119301',
#     'unique_top_genre': 1}}},
#  'alalá': {'genre_id': 'Q8192992',
#   'genre_name_edited': 'alalá',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'albanian folk music': {'genre_id': 'Q106641595',
#   'genre_name_edited': 'albanian folk',
#   'everynoise_name': 'albanian folk',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'albanian hip hop': {'genre_id': 'Q16357920',
#   'genre_name_edited': 'albanian hip hop',
#   'everynoise_name': 'albanian hip hop',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'albanian iso-polyphony': {'genre_id': 'Q47112',
#   'genre_name_edited': 'albanian iso polyphony',
#   'everynoise_name': 'albanian iso polyphony',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'vocal music': {'top_genre_id': 'Q685884',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'albanian rock': {'genre_id': 'Q4709224',
#   'genre_name_edited': 'albanian rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'rock music': {'top_genre_id': 'Q11399', 'unique_top_genre': 0}}},
#  'albanian urban lyric song': {'genre_id': 'Q4709178',
#   'genre_name_edited': 'albanian urban lyric song',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'albazo': {'genre_id': 'Q5662534',
#   'genre_name_edited': 'albazo',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'album-oriented rock': {'genre_id': 'Q428656',
#   'genre_name_edited': 'album oriented rock',
#   'everynoise_name': 'album rock',
#   'discogs_style_name': 'aor',
#   'discogs_genre_name': nan,
#   'top_genre': {'album-oriented rock': {'top_genre_id': 'Q428656',
#     'unique_top_genre': 1}}},
#  'aleatoric music': {'genre_id': 'Q623715',
#   'genre_name_edited': 'aleatoric',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'aleatoric music': {'top_genre_id': 'Q623715',
#     'unique_top_genre': 1}}},
#  'alevi folk music': {'genre_id': 'Q107024911',
#   'genre_name_edited': 'alevi folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'algerian chaabi': {'genre_id': 'Q2961766',
#   'genre_name_edited': 'algerian chaabi',
#   'everynoise_name': 'chaabi algerien',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'algerian hip hop': {'genre_id': 'Q3135790',
#   'genre_name_edited': 'algerian hip hop',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'algerian jazz': {'genre_id': 'Q3163344',
#   'genre_name_edited': 'algerian jazz',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0}}},
#  'algerian rock': {'genre_id': 'Q3437798',
#   'genre_name_edited': 'algerian rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'rock music': {'top_genre_id': 'Q11399', 'unique_top_genre': 0}}},
#  'algorave': {'genre_id': 'Q16002495',
#   'genre_name_edited': 'algorave',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'algorave': {'top_genre_id': 'Q16002495',
#     'unique_top_genre': 1}}},
#  'algysh': {'genre_id': 'Q106626501',
#   'genre_name_edited': 'algysh',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'allaoui': {'genre_id': 'Q12213606',
#   'genre_name_edited': 'allaoui',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'allaoui': {'top_genre_id': 'Q12213606',
#     'unique_top_genre': 1}}},
#  'almlieder': {'genre_id': 'Q37731261',
#   'genre_name_edited': 'almlieder',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0},
#    'vocal music': {'top_genre_id': 'Q685884', 'unique_top_genre': 0}}},
#  'alpenrock': {'genre_id': 'Q5389389',
#   'genre_name_edited': 'alpenrock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'alphabetical psalm': {'genre_id': 'Q59616856',
#   'genre_name_edited': 'alphabetical psalm',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0}}},
#  'alphorn music': {'genre_id': 'Q64140730',
#   'genre_name_edited': 'alphorn',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'instrumental music': {'top_genre_id': 'Q639197',
#     'unique_top_genre': 0}}},
#  'alpine folk music': {'genre_id': 'Q252833',
#   'genre_name_edited': 'alpine folk',
#   'everynoise_name': '',
#   'discogs_style_name': 'volksmusik',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'alsatian folk music': {'genre_id': 'Q107024927',
#   'genre_name_edited': 'alsatian folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'altai folk music': {'genre_id': 'Q107024983',
#   'genre_name_edited': 'altai folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'alternative': {'genre_id': 'Q1695023',
#   'genre_name_edited': 'alternative',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'alternative': {'top_genre_id': 'Q1695023',
#     'unique_top_genre': 0}}},
#  'alternative country': {'genre_id': 'Q438476',
#   'genre_name_edited': 'alternative country',
#   'everynoise_name': 'alternative country',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'country music': {'top_genre_id': 'Q83440', 'unique_top_genre': 0}}},
#  'alternative dance': {'genre_id': 'Q2187392',
#   'genre_name_edited': 'alternative dance',
#   'everynoise_name': 'alternative dance',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'alternative': {'top_genre_id': 'Q1695023',
#     'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0},
#    'rock music': {'top_genre_id': 'Q11399', 'unique_top_genre': 0}}},
#  'alternative electronic': {'genre_id': 'Q4736507',
#   'genre_name_edited': 'alternative electronic',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0}}},
#  'alternative folk': {'genre_id': 'Q28401204',
#   'genre_name_edited': 'alternative folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0}}},
#  'alternative hip hop': {'genre_id': 'Q438503',
#   'genre_name_edited': 'alternative hip hop',
#   'everynoise_name': 'alternative hip hop',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'alternative metal': {'genre_id': 'Q20378',
#   'genre_name_edited': 'alternative metal',
#   'everynoise_name': 'alternative metal',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'alternative': {'top_genre_id': 'Q1695023', 'unique_top_genre': 0}}},
#  'alternative pop': {'genre_id': 'Q105338947',
#   'genre_name_edited': 'alternative pop',
#   'everynoise_name': 'alternative pop',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073',
#     'unique_top_genre': 0}}},
#  'alternative punk': {'genre_id': 'Q65936979',
#   'genre_name_edited': 'alternative punk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'alternative r&b': {'genre_id': 'Q7118426',
#   'genre_name_edited': 'alternative r&b',
#   'everynoise_name': 'alternative r&b',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rhythm and blues': {'top_genre_id': 'Q45981',
#     'unique_top_genre': 0}}},
#  'alternative reggaeton': {'genre_id': 'Q4736555',
#   'genre_name_edited': 'alternative reggaeton',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'music of jamaica': {'top_genre_id': 'Q572717',
#     'unique_top_genre': 0}}},
#  'alternative rock': {'genre_id': 'Q11366',
#   'genre_name_edited': 'alternative rock',
#   'everynoise_name': 'alternative rock',
#   'discogs_style_name': 'alternative rock',
#   'discogs_genre_name': nan,
#   'top_genre': {'alternative': {'top_genre_id': 'Q1695023',
#     'unique_top_genre': 0},
#    'rock music': {'top_genre_id': 'Q11399', 'unique_top_genre': 0}}},
#  'alternative singer/songwriter': {'genre_id': 'Q98528298',
#   'genre_name_edited': 'alternative singer/songwriter',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'amapiano': {'genre_id': 'Q85741139',
#   'genre_name_edited': 'amapiano',
#   'everynoise_name': 'amapiano',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  'ambasse bey': {'genre_id': 'Q4741152',
#   'genre_name_edited': 'ambasse bey',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ambasse bey': {'top_genre_id': 'Q4741152',
#     'unique_top_genre': 1}}},
#  'ambient black metal': {'genre_id': 'Q8197165',
#   'genre_name_edited': 'ambient black metal',
#   'everynoise_name': 'ambient black metal',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0},
#    'experimental music': {'top_genre_id': 'Q1640319', 'unique_top_genre': 0},
#    'new age music': {'top_genre_id': 'Q213121', 'unique_top_genre': 0}}},
#  'ambient breakbeat': {'genre_id': 'Q106653596',
#   'genre_name_edited': 'ambient breakbeat',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  'ambient dub': {'genre_id': 'Q3613770',
#   'genre_name_edited': 'ambient dub',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'new age music': {'top_genre_id': 'Q213121',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0},
#    'music of jamaica': {'top_genre_id': 'Q572717', 'unique_top_genre': 0}}},
#  'ambient house': {'genre_id': 'Q2465085',
#   'genre_name_edited': 'ambient house',
#   'everynoise_name': 'ambient house',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'new age music': {'top_genre_id': 'Q213121', 'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'ambient industrial': {'genre_id': 'Q1440196',
#   'genre_name_edited': 'ambient industrial',
#   'everynoise_name': 'ambient industrial',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'new age music': {'top_genre_id': 'Q213121',
#     'unique_top_genre': 0},
#    'experimental music': {'top_genre_id': 'Q1640319', 'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'ambient jungle': {'genre_id': 'Q2842043',
#   'genre_name_edited': 'ambient jungle',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'new age music': {'top_genre_id': 'Q213121',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'ambient music': {'genre_id': 'Q193207',
#   'genre_name_edited': 'ambient',
#   'everynoise_name': 'ambient',
#   'discogs_style_name': 'ambient',
#   'discogs_genre_name': nan,
#   'top_genre': {'new age music': {'top_genre_id': 'Q213121',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'ambient noise': {'genre_id': 'Q9149798',
#   'genre_name_edited': 'ambient noise',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'ambient noise': {'top_genre_id': 'Q9149798',
#     'unique_top_genre': 1}}},
#  'ambient noise wall': {'genre_id': 'Q107389985',
#   'genre_name_edited': 'ambient noise wall',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'experimental music': {'top_genre_id': 'Q1640319',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'ambient pop': {'genre_id': 'Q33160145',
#   'genre_name_edited': 'ambient pop',
#   'everynoise_name': 'ambient pop',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073', 'unique_top_genre': 0},
#    'rock music': {'top_genre_id': 'Q11399', 'unique_top_genre': 0},
#    'alternative': {'top_genre_id': 'Q1695023', 'unique_top_genre': 0}}},
#  'ambient techno': {'genre_id': 'Q9149801',
#   'genre_name_edited': 'ambient techno',
#   'everynoise_name': 'ambient techno',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'new age music': {'top_genre_id': 'Q213121', 'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'ambient trance': {'genre_id': 'Q4993553',
#   'genre_name_edited': 'ambient trance',
#   'everynoise_name': 'ambient trance',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'new age music': {'top_genre_id': 'Q213121',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0},
#    'dance music': {'top_genre_id': 'Q316930', 'unique_top_genre': 0}}},
#  'ambrosian chant': {'genre_id': 'Q1428162',
#   'genre_name_edited': 'ambrosian chant',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0},
#    'vocal music': {'top_genre_id': 'Q685884', 'unique_top_genre': 0}}},
#  'american art song': {'genre_id': 'Q4745427',
#   'genre_name_edited': 'american art song',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'american art song': {'top_genre_id': 'Q4745427',
#     'unique_top_genre': 1}}},
#  'american classical music': {'genre_id': 'Q3328618',
#   'genre_name_edited': 'american classical',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0}}},
#  'american fiddle': {'genre_id': 'Q4745455',
#   'genre_name_edited': 'american fiddle',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'american fiddle': {'top_genre_id': 'Q4745455',
#     'unique_top_genre': 1}}},
#  'american folk music': {'genre_id': 'Q1541229',
#   'genre_name_edited': 'american folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'american gamelan': {'genre_id': 'Q4745477',
#   'genre_name_edited': 'american gamelan',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'american hip hop': {'genre_id': 'Q3135787',
#   'genre_name_edited': 'american hip hop',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'hip hop music': {'top_genre_id': 'Q11401',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'american indian opera': {'genre_id': 'Q4744117',
#   'genre_name_edited': 'american indian opera',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'art music': {'top_genre_id': 'Q1583807', 'unique_top_genre': 0},
#    'opera': {'top_genre_id': 'Q1344', 'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0}}},
#  'american jazz': {'genre_id': 'Q1684501',
#   'genre_name_edited': 'american jazz',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0}}},
#  'american march music': {'genre_id': 'Q16820420',
#   'genre_name_edited': 'american march',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'march': {'top_genre_id': 'Q211025', 'unique_top_genre': 0}}},
#  'american metal': {'genre_id': 'Q2782580',
#   'genre_name_edited': 'american metal',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'american minstrel music': {'genre_id': 'Q1937548',
#   'genre_name_edited': 'american minstrel',
#   'everynoise_name': '',
#   'discogs_style_name': '',
# ...
#   'top_genre': {'colossal baroque': {'top_genre_id': 'Q5149108',
#     'unique_top_genre': 1}}},
#  'colour bass': {'genre_id': 'Q108197774',
#   'genre_name_edited': 'colour bass',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'electronic music': {'top_genre_id': 'Q9778',
#     'unique_top_genre': 0}}},
#  'columbia': {'genre_id': 'Q5778054',
#   'genre_name_edited': 'columbia',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'colá': {'genre_id': 'Q18473388',
#   'genre_name_edited': 'colá',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'combat folk': {'genre_id': 'Q3683985',
#   'genre_name_edited': 'combat folk',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'protest song': {'top_genre_id': 'Q829147', 'unique_top_genre': 0}}},
#  'combined rhythm': {'genre_id': 'Q5150913',
#   'genre_name_edited': 'combined rhythm',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'combined rhythm': {'top_genre_id': 'Q5150913',
#     'unique_top_genre': 1}}},
#  'comedy hip hop': {'genre_id': 'Q602646',
#   'genre_name_edited': 'comedy hip hop',
#   'everynoise_name': 'comedy rap',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'comedy music': {'top_genre_id': 'Q5151495',
#     'unique_top_genre': 0},
#    'hip hop music': {'top_genre_id': 'Q11401', 'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'comedy music': {'genre_id': 'Q5151495',
#   'genre_name_edited': 'comedy',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'comedy music': {'top_genre_id': 'Q5151495',
#     'unique_top_genre': 0}}},
#  'comedy rock': {'genre_id': 'Q1391336',
#   'genre_name_edited': 'comedy rock',
#   'everynoise_name': 'comedy rock',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0},
#    'comedy music': {'top_genre_id': 'Q5151495', 'unique_top_genre': 0}}},
#  'comic opera': {'genre_id': 'Q13220650',
#   'genre_name_edited': 'comic opera',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0},
#    'opera': {'top_genre_id': 'Q1344', 'unique_top_genre': 0}}},
#  'communist rock': {'genre_id': 'Q3437825',
#   'genre_name_edited': 'communist rock',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'rock music': {'top_genre_id': 'Q11399',
#     'unique_top_genre': 0}}},
#  'compas': {'genre_id': 'Q2726026',
#   'genre_name_edited': 'compas',
#   'everynoise_name': 'kompa',
#   'discogs_style_name': 'compas',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'compass': {'genre_id': 'Q104473253',
#   'genre_name_edited': 'compass',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'compass': {'top_genre_id': 'Q104473253',
#     'unique_top_genre': 1}}},
#  'complextro': {'genre_id': 'Q11691380',
#   'genre_name_edited': 'complextro',
#   'everynoise_name': 'complextro',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'dance music': {'top_genre_id': 'Q316930',
#     'unique_top_genre': 0},
#    'electronic music': {'top_genre_id': 'Q9778', 'unique_top_genre': 0}}},
#  'composer tributes': {'genre_id': 'Q5156725',
#   'genre_name_edited': 'composer tributes',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'composer tributes': {'top_genre_id': 'Q5156725',
#     'unique_top_genre': 1}}},
#  'comédie en vaudevilles': {'genre_id': 'Q17084138',
#   'genre_name_edited': 'comédie en vaudevilles',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0},
#    'opera': {'top_genre_id': 'Q1344', 'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0}}},
#  "comédie mêlée d'ariettes": {'genre_id': 'Q2650956',
#   'genre_name_edited': "comédie mêlée d'ariettes",
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'opera': {'top_genre_id': 'Q1344', 'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0},
#    'art music': {'top_genre_id': 'Q1583807', 'unique_top_genre': 0}}},
#  'concept musical': {'genre_id': 'Q5158398',
#   'genre_name_edited': 'concept musical',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'musical theater': {'top_genre_id': 'Q1370345',
#     'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0}}},
#  'concert aria': {'genre_id': 'Q5158512',
#   'genre_name_edited': 'concert aria',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'aria': {'top_genre_id': 'Q178122', 'unique_top_genre': 0}}},
#  'concert march': {'genre_id': 'Q5158522',
#   'genre_name_edited': 'concert march',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'concert march': {'top_genre_id': 'Q5158522',
#     'unique_top_genre': 1}}},
#  'concert overture': {'genre_id': 'Q11565443',
#   'genre_name_edited': 'concert overture',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'instrumental music': {'top_genre_id': 'Q639197',
#     'unique_top_genre': 0}}},
#  'concert polka': {'genre_id': 'Q64151977',
#   'genre_name_edited': 'concert polka',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'concert polka': {'top_genre_id': 'Q64151977',
#     'unique_top_genre': 1}}},
#  'concert waltz': {'genre_id': 'Q1464124',
#   'genre_name_edited': 'concert waltz',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0}}},
#  'concerted madrigal': {'genre_id': 'Q5158538',
#   'genre_name_edited': 'concerted madrigal',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'concerted madrigal': {'top_genre_id': 'Q5158538',
#     'unique_top_genre': 1}}},
#  'concerto': {'genre_id': 'Q9748',
#   'genre_name_edited': 'concerto',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'concerto': {'top_genre_id': 'Q9748', 'unique_top_genre': 1}}},
#  'concerto grosso': {'genre_id': 'Q210216',
#   'genre_name_edited': 'concerto grosso',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'concerto grosso': {'top_genre_id': 'Q210216',
#     'unique_top_genre': 1}}},
#  'conducted improvisation': {'genre_id': 'Q108297220',
#   'genre_name_edited': 'conducted improvisation',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'experimental music': {'top_genre_id': 'Q1640319',
#     'unique_top_genre': 0}}},
#  'conductus': {'genre_id': 'Q846748',
#   'genre_name_edited': 'conductus',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'medieval music': {'top_genre_id': 'Q163775',
#     'unique_top_genre': 0}}},
#  'conga': {'genre_id': 'Q1125657',
#   'genre_name_edited': 'conga',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0}}},
#  'congada': {'genre_id': 'Q1125678',
#   'genre_name_edited': 'congada',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0}}},
#  'congdut': {'genre_id': 'Q12479445',
#   'genre_name_edited': 'congdut',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'congdut': {'top_genre_id': 'Q12479445',
#     'unique_top_genre': 1}}},
#  'congolese rumba': {'genre_id': 'Q3453150',
#   'genre_name_edited': 'congolese rumba',
#   'everynoise_name': 'rumba congolaise',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'congolese rumba': {'top_genre_id': 'Q3453150',
#     'unique_top_genre': 0}}},
#  'congos': {'genre_id': 'Q5783033',
#   'genre_name_edited': 'congos',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'congos': {'top_genre_id': 'Q5783033',
#     'unique_top_genre': 1}}},
#  'congregational singing': {'genre_id': 'Q5160756',
#   'genre_name_edited': 'congregational singing',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0},
#    'vocal music': {'top_genre_id': 'Q685884', 'unique_top_genre': 0}}},
#  'conjunto': {'genre_id': 'Q4797',
#   'genre_name_edited': 'conjunto',
#   'everynoise_name': '',
#   'discogs_style_name': 'conjunto',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'conjunto andino': {'genre_id': 'Q108419648',
#   'genre_name_edited': 'conjunto andino',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'folk music': {'top_genre_id': 'Q43343', 'unique_top_genre': 0}}},
#  'conscious hip hop': {'genre_id': 'Q141459',
#   'genre_name_edited': 'conscious hip hop',
#   'everynoise_name': 'conscious hip hop',
#   'discogs_style_name': 'conscious',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'hip hop music': {'top_genre_id': 'Q11401', 'unique_top_genre': 0}}},
#  'contemporary catholic liturgical music': {'genre_id': 'Q16610474',
#   'genre_name_edited': 'contemporary catholic liturgical',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'pop music': {'top_genre_id': 'Q37073', 'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0}}},
#  'contemporary christian music': {'genre_id': 'Q1379958',
#   'genre_name_edited': 'contemporary christian',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0},
#    'pop music': {'top_genre_id': 'Q37073', 'unique_top_genre': 0}}},
#  'contemporary classical music': {'genre_id': 'Q612024',
#   'genre_name_edited': 'contemporary classical',
#   'everynoise_name': 'contemporary classical',
#   'discogs_style_name': 'contemporary',
#   'discogs_genre_name': nan,
#   'top_genre': {'art music': {'top_genre_id': 'Q1583807',
#     'unique_top_genre': 0}}},
#  'contemporary commercial music': {'genre_id': 'Q5165023',
#   'genre_name_edited': 'contemporary commercial',
#   'everynoise_name': 'ccm',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'contemporary commercial music': {'top_genre_id': 'Q5165023',
#     'unique_top_genre': 1}}},
#  'contemporary country': {'genre_id': 'Q98528145',
#   'genre_name_edited': 'contemporary country',
#   'everynoise_name': 'contemporary country',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'country music': {'top_genre_id': 'Q83440',
#     'unique_top_genre': 0},
#    'world music': {'top_genre_id': 'Q205049', 'unique_top_genre': 0}}},
#  'contemporary folk music': {'genre_id': 'Q106298881',
#   'genre_name_edited': 'contemporary folk',
#   'everynoise_name': 'contemporary folk',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'folk music': {'top_genre_id': 'Q43343',
#     'unique_top_genre': 0}}},
#  'contemporary jazz': {'genre_id': 'Q5928480',
#   'genre_name_edited': 'contemporary jazz',
#   'everynoise_name': 'contemporary jazz',
#   'discogs_style_name': 'contemporary jazz',
#   'discogs_genre_name': nan,
#   'top_genre': {'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0}}},
#  'contemporary jewish religious music': {'genre_id': 'Q12408914',
#   'genre_name_edited': 'contemporary jewish religious',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'world music': {'top_genre_id': 'Q205049',
#     'unique_top_genre': 0},
#    'functional music': {'top_genre_id': 'Q26897135', 'unique_top_genre': 0}}},
#  'contemporary music': {'genre_id': 'Q3328797',
#   'genre_name_edited': 'contemporary',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'contemporary music': {'top_genre_id': 'Q3328797',
#     'unique_top_genre': 1}}},
#  'contemporary opera': {'genre_id': 'Q21086501',
#   'genre_name_edited': 'contemporary opera',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0},
#    'opera': {'top_genre_id': 'Q1344', 'unique_top_genre': 0},
#    'art music': {'top_genre_id': 'Q1583807', 'unique_top_genre': 0}}},
#  'contemporary popular music': {'genre_id': 'Q12046406',
#   'genre_name_edited': 'contemporary popular',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'contemporary popular music': {'top_genre_id': 'Q12046406',
#     'unique_top_genre': 1}}},
#  'contemporary r&b': {'genre_id': 'Q850412',
#   'genre_name_edited': 'contemporary r&b',
#   'everynoise_name': '',
#   'discogs_style_name': 'rnb/swing',
#   'discogs_genre_name': nan,
#   'top_genre': {'rhythm and blues': {'top_genre_id': 'Q45981',
#     'unique_top_genre': 0}}},
#  'contemporary vocal music': {'genre_id': 'Q186017',
#   'genre_name_edited': 'contemporary vocal',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'vocal music': {'top_genre_id': 'Q685884',
#     'unique_top_genre': 0}}},
#  'contemporary worship music': {'genre_id': 'Q1339121',
#   'genre_name_edited': 'contemporary worship',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'functional music': {'top_genre_id': 'Q26897135',
#     'unique_top_genre': 0}}},
#  'continental jazz': {'genre_id': 'Q5165334',
#   'genre_name_edited': 'continental jazz',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'jazz': {'top_genre_id': 'Q8341', 'unique_top_genre': 0}}},
#  'contra dance music': {'genre_id': 'Q89423571',
#   'genre_name_edited': 'contra dance',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'contra dance music': {'top_genre_id': 'Q89423571',
#     'unique_top_genre': 1}}},
#  'contradanza': {'genre_id': 'Q1775526',
#   'genre_name_edited': 'contradanza',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'contradanza': {'top_genre_id': 'Q1775526',
#     'unique_top_genre': 1}}},
#  'cool cymru': {'genre_id': 'Q31358818',
#   'genre_name_edited': 'cool cymru',
#   'everynoise_name': '',
#   'discogs_style_name': '',
#   'discogs_genre_name': nan,
#   'top_genre': {'cool cymru': {'top_genre_id': 'Q31358818',
#     'unique_top_genre': 1}}},
#  ...}

# %%
# print sample of result dict

def print_sample_dict(spotify_genres_match_dict):
    print(len(spotify_genres_match_dict))
    counter = 0
    for spotify_genre, wikidata_data in spotify_genres_match_dict.items():
        print(spotify_genre)
        print(wikidata_data)
        print('-------------')
        counter += 1
        if counter > 10:
            break

# %%
match_counter = 0
spotify_genres_match_dict = dict()

for spotify_genre, occurrences in tqdm(spotify_dict.items()):
    spotify_genres_match_dict[spotify_genre] = {'occurrences': occurrences}
    matched = False
    
    for wiki_genre_name, wikidata_genre_data in wikidata_dict.items():
        wiki_genre_id = wikidata_genre_data['genre_id']
        wiki_genre_name_edited = wikidata_genre_data['genre_name_edited']
        wiki_everynoise_name = wikidata_genre_data['everynoise_name']
        wiki_discogs_style_name = wikidata_genre_data['discogs_style_name']
        wiki_discogs_genre_name = wikidata_genre_data['discogs_genre_name']
        wiki_top_genre_list = list(wikidata_genre_data['top_genre'].keys())
        
        # find if a wiki genre name exists within spotify genre name
        pattern_matched = False
        for name in [wiki_genre_name, wiki_genre_name_edited, wiki_everynoise_name, wiki_discogs_genre_name, wiki_discogs_style_name]:
            if pd.notna(name) and len(name) > 0:
                pattern = r'\b' + name + r'\b'
                result = re.search(pattern, spotify_genre)
                if result:
                    pattern_matched = True
        
        if spotify_genre in [wiki_genre_name, wiki_genre_name_edited, wiki_everynoise_name, wiki_discogs_genre_name, wiki_discogs_style_name] :
            #print(spotify_genre, '======', genre_name)
            spotify_genres_match_dict[spotify_genre] = {'occurrences': occurrences, wiki_genre_name: wiki_top_genre_list}
            matched = True
            break
        elif pattern_matched:
            #print(spotify_genre, '-', genre_name_edited)
            spotify_genres_match_dict[spotify_genre][wiki_genre_name] = wiki_top_genre_list
            matched = True
            
    if matched:
        match_counter += 1

print(match_counter)
print_sample_dict(spotify_genres_match_dict)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3684/3684 [20:11<00:00,  3.04it/s]
# 2972

# %%
# get top genres for each spotify genre

def get_spotify_top_genres(spotify_genres_match_dict):
    spotify_top_genres_dict = dict()

    for spotify_genre, wiki_genre_data in spotify_genres_match_dict.items():
        spotify_top_genres_dict[spotify_genre] = set()
        for wiki_genre_name in wiki_genre_data.keys():
            if wiki_genre_name == 'occurrences':
                continue
            else:
                [spotify_top_genres_dict[spotify_genre].add(top_genre) for top_genre in wiki_genre_data[wiki_genre_name]]
    
    return spotify_top_genres_dict

# %%
# get list of spotify genres without a match

def get_no_match(spotify_genres_match_dict):
    no_match_dict = dict()

    for spotify_genre, genre_data in spotify_genres_match_dict.items():
        if len(genre_data) < 2:
            occurrences = genre_data['occurrences']
            no_match_dict[spotify_genre] = occurrences
    
    return no_match_dict

# %%
with open('data/data_spotify_artists.csv', encoding='utf-8') as artists_file:
    spotify_artists_df = pd.read_csv(artists_file, index_col=0)

# get dataframe of all genres for all spotify artists
columns_list = ['spotify_genre_' + str(x) for x in range(1, 20)]
genres_df = spotify_artists_df[spotify_artists_df.columns.intersection(columns_list)]

# %%
# for unmatched genre, get the top genres of related genres (genres associated with artists linked to unmatched genre)

spotify_top_genres_dict = get_spotify_top_genres(spotify_genres_match_dict)
no_match_dict = get_no_match(spotify_genres_match_dict)
remaining_no_match_genres_dict = dict()

# for each unmatched genre
for no_match_genre, no_match_occurrences in tqdm(no_match_dict.items()):
    #print(no_match_genre)
    
    # get rows of spotify artists with current unmatched genre
    no_match_genre_df = genres_df[(genres_df == no_match_genre).any(axis=1)]
    
    # get all genres related to current unmatched genre (= genres associated to same artists linked to current unmatched genre)
    related_genres_dict = no_match_genre_df.stack().value_counts().to_dict()
    
    # remove current unmatched genre from dict of related genres
    related_genres_dict.pop(no_match_genre)
    
    # if there is at least one genre related to current unmatched genre
    if related_genres_dict:
        top_genres_dict = dict()
        
        # get the top genre for current unmatched genre (= most frequent top genre in related genres)
        for genre_name, occurrences in related_genres_dict.items():
            # get the list of top genres for current related genre
            top_genres_set = spotify_top_genres_dict[genre_name]
            
            # if there is at least one top genre for current related genre
            if top_genres_set:
                # get the occurrences of that top genre
                for top_genre in top_genres_set:
                    try:
                        top_genre_occurrences = top_genres_dict[top_genre]
                        top_genres_dict[top_genre] = top_genre_occurrences + occurrences
                    except KeyError:
                        top_genres_dict[top_genre] = occurrences
                
        # if at least one related genre has a top genre (= it is not in no_match list)
        if top_genres_dict:
            # sort dict of top genres by most occurrences (= most frequent top genres among related genres)
            top_genres_list = sorted(top_genres_dict.items(), key = lambda kv:(kv[1], kv[0]), reverse=True)
            
            # add most frequent top genre to a list
            most_frequent_top_genres_set = {top_genres_list[0][0]}
            
            # if the most frequent top genre is 'world music', add second top genre, if there is one ('world music' is very frequent and broad)
            if top_genres_list[0][0] == 'world music' and len(top_genres_list) > 1:
                most_frequent_top_genres_set.add(top_genres_list[1][0])
            
            # if the most frequent top genre has same occurrence as others, add all top genres with same occurrence
            for top_genre in top_genres_list:
                if top_genre[1] == top_genres_list[0][1]:
                    most_frequent_top_genres_set.add(top_genre[0])
            
            for most_frequent_genre in most_frequent_top_genres_set:
                spotify_genres_match_dict[no_match_genre][most_frequent_genre] = [most_frequent_genre]
            
        # if no related genre has a top genre (= related genre is in no_match list)
        else:
            #print('xxxxxxxxxxxxxxxxxxxxxxxxx')
            remaining_no_match_genres_dict[no_match_genre] = no_match_occurrences
    else:
        #print('-------------------------------')
        remaining_no_match_genres_dict[no_match_genre] = no_match_occurrences

print(len(remaining_no_match_genres_dict))
print(len(get_spotify_top_genres(spotify_genres_match_dict)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 93/93 [00:01<00:00, 49.41it/s]
# 93
# 3684

# %%
spotify_top_genres_dict = get_spotify_top_genres(spotify_genres_match_dict)
spotify_top_genres_df = pd.DataFrame.from_dict(spotify_top_genres_dict, orient='index')
spotify_top_genres_df.to_csv('data/data_spotify_top_genres.csv', encoding='utf-8')
spotify_top_genres_df
# Out:
#                                        0                 1  \
# 21st century classical         art music              None
# 5th wave emo                 world music  electronic music
# a cappella                   vocal music              None
# aarhus indie                  rock music              None
# aberdeen indie                rock music              None
# ...                                  ...               ...
# zolo                          rock music              None
# zouglou                          zouglou              None
# zouk                         world music              None
# zouk riddim             electronic music       world music
# zurich indie                 world music        rock music
#
#                                          2                   3           4  \
# 21st century classical                None                None        None
# 5th wave emo                 hip hop music  experimental music  rock music
# a cappella                            None                None        None
# aarhus indie                          None                None        None
# aberdeen indie                        None                None        None
# ...                                    ...                 ...         ...
# zolo                                  None                None        None
# zouglou                               None                None        None
# zouk                                  None                None        None
# zouk riddim             instrumental music         dance music        None
# zurich indie                          None                None        None
#
#                            5
# 21st century classical  None
# 5th wave emo            None
# a cappella              None
# aarhus indie            None
# aberdeen indie          None
# ...                      ...
# zolo                    None
# zouglou                 None
# zouk                    None
# zouk riddim             None
# zurich indie            None
#
# [3684 rows x 6 columns]

# %%
with open('data/data_wikidata_bigcities.csv', encoding='utf-8') as file_city:
    city_df = pd.read_csv(file_city)
    
with open('data/data_wikidata_demonyms.csv', encoding='utf-8') as file_demonym:
    demonym_df = pd.read_csv(file_demonym)

with open('data/data_wikidata_usstates.csv', encoding='utf-8') as file_us_state:
    us_state_df = pd.read_csv(file_us_state)
    
us_state_df
# Out:
#    state_id          state abbrev
# 0      Q173        Alabama     AL
# 1      Q173        Alabama   Ala.
# 2      Q797         Alaska     AK
# 3      Q816        Arizona     AZ
# 4      Q816        Arizona  Ariz.
# ..      ...            ...    ...
# 91    Q1371  West Virginia  W.Va.
# 92    Q1537      Wisconsin     WI
# 93    Q1537      Wisconsin   Wis.
# 94    Q1214        Wyoming     WY
# 95    Q1214        Wyoming   Wyo.
#
# [96 rows x 3 columns]

# %%
"""
SPARQL query for Wikidata items with demonym property:

SELECT (SAMPLE(?item) AS ?item) ?demonym WHERE {
  # ?item wdt:P1549 ?demonym.
  FILTER((LANG(?demonym)) = "en")
}
GROUP BY ?demonym

"""

demonym_list = sorted(set(demonym_df['demonym']))
demonym_list = [demonym.lower() for demonym in demonym_list]
print(len(demonym_list))
demonym_list[:10]
# Out:
# 796
# ['/b/tards',
#  '/pol/acks',
#  '/v/ermin',
#  '/v/irgins',
#  'abidjanese',
#  'abkhaz',
#  'abkhazian',
#  'abu dhabian',
#  'accran',
#  'achaemenian']

# %%
"""
SPARQL query for Wikidata items with big city instance:

SELECT DISTINCT ?item ?itemLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". }
  {
    SELECT DISTINCT ?item WHERE {
      # ?item p:P31 ?statement0.
      # ?statement0 (ps:P31/(wdt:P279*)) wd:Q1549591.
    }
  }
}
"""
city_list = sorted(set(city_df['city']))
city_list = [city.lower() for city in city_list]
print(len(city_list))
city_list[:10]
# Out:
# 3548
# ["'s-hertogenbosch",
#  '6th of october city',
#  'a coruña',
#  'aachen',
#  'aalborg',
#  'aarhus',
#  'aba',
#  'abadan',
#  'abaetetuba',
#  'abakan']

# %%
"""
SPARQL query for Wikidata items with US State instance:

SELECT DISTINCT ?item ?itemLabel WHERE {
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". }
  {
    SELECT DISTINCT ?item WHERE {
      # ?item p:P31 ?statement0.
      # ?statement0 (ps:P31/(wdt:P279*)) wd:Q30.
    }
  }
}
"""
us_state_set = set(us_state_df['abbrev'])
us_state_set.update(us_state_df['state'])
us_state_list = sorted(us_state_set)
us_state_list = [state.lower() for state in us_state_list]
print(len(us_state_list))
us_state_list[:10]
# Out:
# 145
# ['ak',
#  'al',
#  'ar',
#  'az',
#  'ala.',
#  'alabama',
#  'alaska',
#  'ariz.',
#  'arizona',
#  'ark.']

# %%
words_no_match_dict = dict()
city_set = set()
demonym_set = set()
state_set = set()
words_set = set()

for genre, occurences in remaining_no_match_genres_dict.items():
    words = re.findall(r'\b[\w&-]+\b', genre)
    for word in words:
        words_set.add(word)
        if word in city_list :
            city_set.add(word)
            continue
        elif word in demonym_list:
            demonym_set.add(word)
            continue
        elif word in us_state_list:
            state_set.add(word)
            continue
        else:
            try:
                counter = words_no_match_dict[word]['counter']
                word_occurrences = words_no_match_dict[word]['occurrences']
                
                words_no_match_dict[word]['counter'] = counter + 1
                words_no_match_dict[word]['occurrences'] = word_occurrences + occurrences
                words_no_match_dict[word]['genres'].append(genre)
            except KeyError:
                words_no_match_dict[word] = {'counter': 1, 'occurrences': occurences}
                words_no_match_dict[word] = {'counter': 1, 'occurrences': occurences, 'genres': [genre]}
            
print('nbr words no match', len(words_no_match_dict))
print('nbr city words', len(city_set))
print('nbr demonym words', len(demonym_set))
print('nbr state words', len(state_set))
print('nbr total words:', len(words_set))
words_no_match_dict
# Out:
# nbr words no match 127
# nbr city words 8
# nbr demonym words 9
# nbr state words 5
# nbr total words: 149
# {'afrikaans': {'counter': 1, 'occurrences': 1, 'genres': ['afrikaans']},
#  'backing': {'counter': 1, 'occurrences': 1, 'genres': ['backing track']},
#  'track': {'counter': 1, 'occurrences': 1, 'genres': ['backing track']},
#  'barnmusik': {'counter': 1, 'occurrences': 2, 'genres': ['barnmusik']},
#  'belo': {'counter': 1, 'occurrences': 1, 'genres': ['belo horizonte indie']},
#  'horizonte': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['belo horizonte indie']},
#  'indie': {'counter': 33,
#   'occurrences': 33,
#   'genres': ['belo horizonte indie',
#    'bulgarian indie',
#    'charlotte nc indie',
#    'cornwall indie',
#    'delaware indie',
#    'euskal indie',
#    'galway indie',
#    'hong kong indie',
#    'hungarian indie',
#    'indie boliviano',
#    'indie liguria',
#    'indie rockism',
#    'indie tico',
#    'indie triste',
#    'kansai indie',
#    'limerick indie',
#    'lincoln ne indie',
#    'milwaukee indie',
#    'minneapolis indie',
#    'missouri indie',
#    'normal indie',
#    'north dakota indie',
#    'ottawa indie',
#    'pakistani indie',
#    'perth indie',
#    'portsmouth indie',
#    'san antonio indie',
#    'sardinia indie',
#    'slc indie',
#    'svensk indie',
#    'trondheim indie',
#    'venezuelan indie',
#    'west yorkshire indie']},
#  'bemani': {'counter': 1, 'occurrences': 2, 'genres': ['bemani']},
#  'binaural': {'counter': 1, 'occurrences': 1, 'genres': ['binaural']},
#  'birdsong': {'counter': 1, 'occurrences': 2, 'genres': ['birdsong']},
#  'blaskapelle': {'counter': 1, 'occurrences': 5, 'genres': ['blaskapelle']},
#  'cancion': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['cancion infantil latinoamericana']},
#  'infantil': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['cancion infantil latinoamericana']},
#  'latinoamericana': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['cancion infantil latinoamericana']},
#  'cantautora': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['cantautora argentina']},
#  'argentina': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['cantautora argentina']},
#  'worship': {'counter': 2,
#   'occurrences': 2,
#   'genres': ['chinese worship', 'swiss worship']},
#  'cimbalom': {'counter': 1, 'occurrences': 1, 'genres': ['cimbalom']},
#  'classic': {'counter': 1, 'occurrences': 1, 'genres': ['classic eurovision']},
#  'eurovision': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['classic eurovision']},
#  'classify': {'counter': 1, 'occurrences': 3, 'genres': ['classify']},
#  'combos': {'counter': 1, 'occurrences': 1, 'genres': ['combos nacionales']},
#  'nacionales': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['combos nacionales']},
#  'comptine': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['comptine africaine']},
#  'africaine': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['comptine africaine']},
#  'cornwall': {'counter': 1, 'occurrences': 3, 'genres': ['cornwall indie']},
#  'coverchill': {'counter': 1, 'occurrences': 2, 'genres': ['coverchill']},
#  'covertrance': {'counter': 1, 'occurrences': 2, 'genres': ['covertrance']},
#  'deep': {'counter': 2,
#   'occurrences': 2,
#   'genres': ['deep discofox', 'deep flow']},
#  'discofox': {'counter': 1, 'occurrences': 1, 'genres': ['deep discofox']},
#  'flow': {'counter': 1, 'occurrences': 1, 'genres': ['deep flow']},
#  'demoscene': {'counter': 1, 'occurrences': 1, 'genres': ['demoscene']},
#  'duduk': {'counter': 1, 'occurrences': 1, 'genres': ['duduk']},
#  'euskal': {'counter': 1, 'occurrences': 1, 'genres': ['euskal indie']},
#  'fake': {'counter': 1, 'occurrences': 5, 'genres': ['fake']},
#  'finlandssvenska': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['finlandssvenska musik']},
#  'musik': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['finlandssvenska musik']},
#  'folclor': {'counter': 1,
#   'occurrences': 2,
#   'genres': ['folclor afrocolombiano']},
#  'afrocolombiano': {'counter': 1,
#   'occurrences': 2,
#   'genres': ['folclor afrocolombiano']},
#  'folclore': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['folclore portugues']},
#  'portugues': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['folclore portugues']},
#  'folklore': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['folklore quebecois']},
#  'quebecois': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['folklore quebecois']},
#  'galway': {'counter': 1, 'occurrences': 1, 'genres': ['galway indie']},
#  'guqin': {'counter': 1, 'occurrences': 1, 'genres': ['guqin']},
#  'harpsichord': {'counter': 1, 'occurrences': 3, 'genres': ['harpsichord']},
#  'hinos': {'counter': 1, 'occurrences': 1, 'genres': ['hinos ccb']},
#  'ccb': {'counter': 1, 'occurrences': 1, 'genres': ['hinos ccb']},
#  'hong': {'counter': 1, 'occurrences': 1, 'genres': ['hong kong indie']},
#  'kong': {'counter': 1, 'occurrences': 1, 'genres': ['hong kong indie']},
#  'hopebeat': {'counter': 1, 'occurrences': 3, 'genres': ['hopebeat']},
#  'boliviano': {'counter': 1, 'occurrences': 1, 'genres': ['indie boliviano']},
#  'liguria': {'counter': 1, 'occurrences': 1, 'genres': ['indie liguria']},
#  'rockism': {'counter': 1, 'occurrences': 1, 'genres': ['indie rockism']},
#  'tico': {'counter': 1, 'occurrences': 2, 'genres': ['indie tico']},
#  'triste': {'counter': 2,
#   'occurrences': 2,
#   'genres': ['indie triste', 'musica triste brasileira']},
#  'jaw': {'counter': 1, 'occurrences': 1, 'genres': ['jaw harp']},
#  'harp': {'counter': 1, 'occurrences': 1, 'genres': ['jaw harp']},
#  'jugendchor': {'counter': 1, 'occurrences': 1, 'genres': ['jugendchor']},
#  'kansai': {'counter': 1, 'occurrences': 2, 'genres': ['kansai indie']},
#  'karneval': {'counter': 1, 'occurrences': 1, 'genres': ['karneval']},
#  'roots': {'counter': 1, 'occurrences': 1, 'genres': ['kentucky roots']},
#  'kindermusik': {'counter': 1, 'occurrences': 2, 'genres': ['kindermusik']},
#  'kleine': {'counter': 1, 'occurrences': 2, 'genres': ['kleine hoerspiel']},
#  'hoerspiel': {'counter': 1, 'occurrences': 2, 'genres': ['kleine hoerspiel']},
#  'superband': {'counter': 1, 'occurrences': 1, 'genres': ['korean superband']},
#  'lagu': {'counter': 1, 'occurrences': 1, 'genres': ['lagu iban']},
#  'iban': {'counter': 1, 'occurrences': 1, 'genres': ['lagu iban']},
#  'lesen': {'counter': 1, 'occurrences': 2, 'genres': ['lesen']},
#  'limerick': {'counter': 1, 'occurrences': 1, 'genres': ['limerick indie']},
#  'louvor': {'counter': 1, 'occurrences': 1, 'genres': ['louvor']},
#  'marching': {'counter': 1, 'occurrences': 1, 'genres': ['marching band']},
#  'band': {'counter': 1, 'occurrences': 1, 'genres': ['marching band']},
#  'melodipop': {'counter': 1, 'occurrences': 1, 'genres': ['melodipop']},
#  'messianic': {'counter': 1, 'occurrences': 1, 'genres': ['messianic praise']},
#  'praise': {'counter': 1, 'occurrences': 1, 'genres': ['messianic praise']},
#  'mgp': {'counter': 1, 'occurrences': 3, 'genres': ['mgp']},
#  'musica': {'counter': 4,
#   'occurrences': 4,
#   'genres': ['musica mato-grossense',
#    'musica para ninos',
#    'musica portuguesa contemporanea',
#    'musica triste brasileira']},
#  'mato-grossense': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['musica mato-grossense']},
#  'para': {'counter': 1, 'occurrences': 1, 'genres': ['musica para ninos']},
#  'ninos': {'counter': 1, 'occurrences': 1, 'genres': ['musica para ninos']},
#  'portuguesa': {'counter': 1,
#   'occurrences': 3,
#   'genres': ['musica portuguesa contemporanea']},
#  'contemporanea': {'counter': 1,
#   'occurrences': 3,
#   'genres': ['musica portuguesa contemporanea']},
#  'brasileira': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['musica triste brasileira']},
#  'normal': {'counter': 1, 'occurrences': 1, 'genres': ['normal indie']},
#  'north': {'counter': 1, 'occurrences': 2, 'genres': ['north dakota indie']},
#  'dakota': {'counter': 1, 'occurrences': 2, 'genres': ['north dakota indie']},
#  'nursery': {'counter': 1, 'occurrences': 1, 'genres': ['nursery']},
#  'old': {'counter': 1, 'occurrences': 1, 'genres': ['old west']},
#  'west': {'counter': 2,
#   'occurrences': 2,
#   'genres': ['old west', 'west yorkshire indie']},
#  'perreo': {'counter': 1, 'occurrences': 1, 'genres': ['perreo']},
#  'piano': {'counter': 1, 'occurrences': 2, 'genres': ['piano cover']},
#  'cover': {'counter': 1, 'occurrences': 2, 'genres': ['piano cover']},
#  'psychedelia': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['polish psychedelia']},
#  'pony': {'counter': 1, 'occurrences': 1, 'genres': ['pony']},
#  'psicodelia': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['psicodelia mexicana']},
#  'mexicana': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['psicodelia mexicana']},
#  'quartetto': {'counter': 1,
#   'occurrences': 2,
#   'genres': ["quartetto d'archi"]},
#  'd': {'counter': 1, 'occurrences': 2, 'genres': ["quartetto d'archi"]},
#  'archi': {'counter': 1, 'occurrences': 2, 'genres': ["quartetto d'archi"]},
#  'rain': {'counter': 1, 'occurrences': 2, 'genres': ['rain']},
#  'rare': {'counter': 1, 'occurrences': 1, 'genres': ['rare groove']},
#  'groove': {'counter': 1, 'occurrences': 1, 'genres': ['rare groove']},
#  'rhythm': {'counter': 1, 'occurrences': 1, 'genres': ['rhythm game']},
#  'game': {'counter': 1, 'occurrences': 1, 'genres': ['rhythm game']},
#  'rkt': {'counter': 1, 'occurrences': 1, 'genres': ['rkt']},
#  'san': {'counter': 1, 'occurrences': 1, 'genres': ['san antonio indie']},
#  'antonio': {'counter': 1, 'occurrences': 1, 'genres': ['san antonio indie']},
#  'sardinia': {'counter': 1, 'occurrences': 1, 'genres': ['sardinia indie']},
#  'slc': {'counter': 1, 'occurrences': 1, 'genres': ['slc indie']},
#  'sleep': {'counter': 1, 'occurrences': 1, 'genres': ['sleep']},
#  'sound': {'counter': 1, 'occurrences': 2, 'genres': ['sound effects']},
#  'effects': {'counter': 1, 'occurrences': 2, 'genres': ['sound effects']},
#  'invasion': {'counter': 1, 'occurrences': 1, 'genres': ['spanish invasion']},
#  'spoken': {'counter': 1, 'occurrences': 1, 'genres': ['spoken word']},
#  'word': {'counter': 1, 'occurrences': 1, 'genres': ['spoken word']},
#  'svensk': {'counter': 1, 'occurrences': 1, 'genres': ['svensk indie']},
#  'taiko': {'counter': 1, 'occurrences': 2, 'genres': ['taiko']},
#  'tribute': {'counter': 1, 'occurrences': 4, 'genres': ['tribute']},
#  'ukulele': {'counter': 1, 'occurrences': 2, 'genres': ['ukulele']},
#  'viola': {'counter': 2,
#   'occurrences': 5,
#   'genres': ['viola', 'viola da gamba']},
#  'da': {'counter': 1, 'occurrences': 1, 'genres': ['viola da gamba']},
#  'gamba': {'counter': 1, 'occurrences': 1, 'genres': ['viola da gamba']},
#  'washboard': {'counter': 1, 'occurrences': 1, 'genres': ['washboard']},
#  'yorkshire': {'counter': 1,
#   'occurrences': 1,
#   'genres': ['west yorkshire indie']},
#  'workout': {'counter': 1, 'occurrences': 1, 'genres': ['workout product']},
#  'product': {'counter': 1, 'occurrences': 1, 'genres': ['workout product']}}

# %%
words_no_match_df = pd.DataFrame.from_dict(words_no_match_dict, orient='index')
words_no_match_df.sort_values(by=['occurrences'], ascending=False, inplace=True)
words_no_match_df.to_csv('data/data_spotify_genres_no_match.csv', encoding='utf-8')
words_no_match_df.index.name = 'word'
words_no_match_df.reset_index(inplace=True)
words_no_match_df
# Out:
#             word  counter  occurrences  \
# 0          indie       33           33
# 1    blaskapelle        1            5
# 2           fake        1            5
# 3          viola        2            5
# 4        tribute        1            4
# ..           ...      ...          ...
# 122          ccb        1            1
# 123        hinos        1            1
# 124        guqin        1            1
# 125       galway        1            1
# 126      product        1            1
#
#                                                 genres
# 0    [belo horizonte indie, bulgarian indie, charlo...
# 1                                        [blaskapelle]
# 2                                               [fake]
# 3                              [viola, viola da gamba]
# 4                                            [tribute]
# ..                                                 ...
# 122                                        [hinos ccb]
# 123                                        [hinos ccb]
# 124                                            [guqin]
# 125                                     [galway indie]
# 126                                  [workout product]
#
# [127 rows x 4 columns]

# %%
# create dict from discogs_df
# keep only discogs styles linked to a discogs genre

discogs_dict = dict()
        
for idx, row in discogs_df.iterrows():
    genre_name = row['genre_name']
    genre_url = row['genre_url']
    style_name = row['style_name']
    style_url = idx
    
    if pd.notna(genre_url):
        style_name = style_name.lower()  # convert name to lowercase
        genre_name = genre_name.lower()
        discogs_dict[style_name] = {'type': 'style', 'genre_name': genre_name}
        discogs_dict[genre_name] = {'type': 'genre', 'genre_name': genre_name}

print(len(spotify_list), len(wikidata_dict), len(discogs_dict))
# Out:
# 3684 4574 460

# %%
discogs_counter = 0
wikidata_counter = 0
genres_matches_dict = dict()

for spotify_genre in spotify_genres_list[:]:
    genres_matches_dict[spotify_genre] = {'discogs': dict(), 'wikidata': dict(),}
    
    for discogs_style_name, discogs_style_info in discogs_dict.items():
        discogs_genre_name = discogs_style_info['genre_name']
        
        if spotify_genre == discogs_style_name:    
            genres_matches_dict[spotify_genre]['discogs'] = {discogs_style_name: discogs_genre_name}
            discogs_counter += 1
            break
        
        # find if discogs style name exists within spotify genre name
        pattern = r'\b' + discogs_style_name + r'\b'
        match = re.search(pattern, spotify_genre)
        
        if match:
            genres_matches_dict[spotify_genre]['discogs'][discogs_style_name] = discogs_genre_name
            discogs_counter += 1
            
    for wikidata_genre_name, wikidata_genre_info in wikidata_dict.items():
        wikidata_genre_id = wikidata_genre_info['genre_id']
        wikidata_top_genre_list = list(wikidata_genre_info['top_genre'].keys())
        
        if spotify_genre == wikidata_genre_name:
            genres_matches_dict[spotify_genre]['wikidata'] = {wikidata_genre_name: wikidata_top_genre_list}
            wikidata_counter += 1
            break
                
print(discogs_counter, wikidata_counter)
genres_matches_dict
# Out:
# 2755 769
# {'21st century classical': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  '5th wave emo': {'discogs': {'emo': 'rock'}, 'wikidata': {}},
#  'a cappella': {'discogs': {}, 'wikidata': {'a cappella': ['vocal music']}},
#  'aarhus indie': {'discogs': {}, 'wikidata': {}},
#  'aberdeen indie': {'discogs': {}, 'wikidata': {}},
#  'abstract': {'discogs': {'abstract': 'electronic'}, 'wikidata': {}},
#  'abstract beats': {'discogs': {'abstract': 'electronic'}, 'wikidata': {}},
#  'abstract hip hop': {'discogs': {'abstract': 'electronic',
#    'hip hop': 'hip hop'},
#   'wikidata': {'abstract hip hop': ['hip hop music', 'world music']}},
#  'abstract idm': {'discogs': {'abstract': 'electronic', 'idm': 'electronic'},
#   'wikidata': {}},
#  'abstractro': {'discogs': {}, 'wikidata': {}},
#  'accordeon': {'discogs': {}, 'wikidata': {}},
#  'accordion': {'discogs': {}, 'wikidata': {}},
#  'acid house': {'discogs': {'acid house': 'electronic'},
#   'wikidata': {'acid house': ['dance music', 'electronic music']}},
#  'acid idm': {'discogs': {'acid': 'electronic', 'idm': 'electronic'},
#   'wikidata': {}},
#  'acid jazz': {'discogs': {'acid jazz': 'electronic'},
#   'wikidata': {'acid jazz': ['rhythm and blues', 'funk']}},
#  'acid rock': {'discogs': {'acid rock': 'rock'},
#   'wikidata': {'acid rock': ['rock music', 'psychedelic music']}},
#  'acid techno': {'discogs': {'acid': 'electronic', 'techno': 'electronic'},
#   'wikidata': {'acid techno': ['electronic music', 'dance music']}},
#  'acid trance': {'discogs': {'acid': 'electronic', 'trance': 'electronic'},
#   'wikidata': {'acid trance': ['electronic music', 'dance music']}},
#  'acousmatic': {'discogs': {}, 'wikidata': {}},
#  'acoustic blues': {'discogs': {'acoustic': 'rock', 'blues': 'blues'},
#   'wikidata': {'acoustic blues': ['blues']}},
#  'acoustic cover': {'discogs': {'acoustic': 'rock'}, 'wikidata': {}},
#  'acoustic pop': {'discogs': {'acoustic': 'rock', 'pop': 'pop'},
#   'wikidata': {}},
#  'acoustic punk': {'discogs': {'acoustic': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'acoustic rock': {'discogs': {'rock': 'rock', 'acoustic': 'rock'},
#   'wikidata': {'acoustic rock': ['rock music']}},
#  'action rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'adoracao': {'discogs': {}, 'wikidata': {}},
#  'adult standards': {'discogs': {}, 'wikidata': {}},
#  'aesthetic rap': {'discogs': {}, 'wikidata': {}},
#  'afghan rap': {'discogs': {}, 'wikidata': {}},
#  'african electronic': {'discogs': {'electronic': 'electronic',
#    'african': 'folk, world, & country'},
#   'wikidata': {}},
#  'african experimental': {'discogs': {'african': 'folk, world, & country',
#    'experimental': 'electronic'},
#   'wikidata': {}},
#  'african metal': {'discogs': {'african': 'folk, world, & country'},
#   'wikidata': {}},
#  'african percussion': {'discogs': {'african': 'folk, world, & country'},
#   'wikidata': {}},
#  'african reggae': {'discogs': {'african': 'folk, world, & country',
#    'reggae': 'reggae'},
#   'wikidata': {'african reggae': ['music of jamaica']}},
#  'african rock': {'discogs': {'rock': 'rock',
#    'african': 'folk, world, & country'},
#   'wikidata': {}},
#  'african-american classical': {'discogs': {'african': 'folk, world, & country',
#    'classical': 'classical'},
#   'wikidata': {}},
#  'afrikaans': {'discogs': {}, 'wikidata': {}},
#  'afro dancehall': {'discogs': {'dancehall': 'reggae'}, 'wikidata': {}},
#  'afro house': {'discogs': {'house': 'electronic'}, 'wikidata': {}},
#  'afro psych': {'discogs': {}, 'wikidata': {}},
#  'afro r&b': {'discogs': {}, 'wikidata': {}},
#  'afro soul': {'discogs': {'soul': 'funk / soul'}, 'wikidata': {}},
#  'afro-cuban percussion': {'discogs': {'afro-cuban': 'latin'}, 'wikidata': {}},
#  'afro-funk': {'discogs': {'funk': 'funk / soul'},
#   'wikidata': {'afro-funk': ['funk', 'world music', 'rhythm and blues']}},
#  'afrobeat': {'discogs': {'afrobeat': 'funk / soul'},
#   'wikidata': {'afrobeat': ['world music',
#     'folk music',
#     'rhythm and blues',
#     'funk']}},
#  'afrobeat brasileiro': {'discogs': {'afrobeat': 'funk / soul'},
#   'wikidata': {}},
#  'afrobeat fusion': {'discogs': {'afrobeat': 'funk / soul', 'fusion': 'jazz'},
#   'wikidata': {}},
#  'afrofuturism': {'discogs': {}, 'wikidata': {}},
#  'afrofuturismo brasileiro': {'discogs': {}, 'wikidata': {}},
#  'afropop': {'discogs': {}, 'wikidata': {}},
#  'afroswing': {'discogs': {},
#   'wikidata': {'afroswing': ['world music', 'hip hop music']}},
#  'aggrotech': {'discogs': {},
#   'wikidata': {'aggrotech': ['experimental music',
#     'dance music',
#     'electronic music']}},
#  'ai': {'discogs': {}, 'wikidata': {}},
#  'alabama indie': {'discogs': {}, 'wikidata': {}},
#  'alabama metal': {'discogs': {}, 'wikidata': {}},
#  'alabama rap': {'discogs': {}, 'wikidata': {}},
#  'alaska indie': {'discogs': {}, 'wikidata': {}},
#  'albanian folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'albanian hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'albanian hip hop': ['world music', 'hip hop music']}},
#  'albanian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'albany ny indie': {'discogs': {}, 'wikidata': {}},
#  'alberta country': {'discogs': {'country': 'folk, world, & country'},
#   'wikidata': {}},
#  'alberta hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'album rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'albuquerque indie': {'discogs': {}, 'wikidata': {}},
#  'algerian folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'alphorn': {'discogs': {}, 'wikidata': {}},
#  'alpine yodeling': {'discogs': {}, 'wikidata': {}},
#  'alt z': {'discogs': {}, 'wikidata': {}},
#  'alternative americana': {'discogs': {}, 'wikidata': {}},
#  'alternative country': {'discogs': {'country': 'folk, world, & country'},
#   'wikidata': {'alternative country': ['country music', 'world music']}},
#  'alternative dance': {'discogs': {},
#   'wikidata': {'alternative dance': ['rock music',
#     'dance music',
#     'alternative']}},
#  'alternative emo': {'discogs': {'emo': 'rock'}, 'wikidata': {}},
#  'alternative hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {}},
#  'alternative hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'alternative hip hop': ['world music',
#     'rap',
#     'hip hop music']}},
#  'alternative metal': {'discogs': {'alternative metal': 'rock'},
#   'wikidata': {'alternative metal': ['rock music', 'alternative']}},
#  'alternative metalcore': {'discogs': {'metalcore': 'rock'}, 'wikidata': {}},
#  'alternative pop': {'discogs': {'pop': 'pop'},
#   'wikidata': {'alternative pop': ['pop music']}},
#  'alternative pop rock': {'discogs': {'rock': 'rock',
#    'pop': 'pop',
#    'pop rock': 'rock'},
#   'wikidata': {}},
#  'alternative r&b': {'discogs': {},
#   'wikidata': {'alternative r&b': ['rhythm and blues']}},
#  'alternative rock': {'discogs': {'alternative rock': 'rock'},
#   'wikidata': {'alternative rock': ['rock music', 'alternative']}},
#  'alternative roots rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'ambeat': {'discogs': {}, 'wikidata': {}},
#  'ambient': {'discogs': {'ambient': 'electronic'}, 'wikidata': {}},
#  'ambient black metal': {'discogs': {'ambient': 'electronic',
#    'black metal': 'rock'},
#   'wikidata': {'ambient black metal': ['electronic music',
#     'rock music',
#     'new age music',
#     'experimental music']}},
#  'ambient folk': {'discogs': {'ambient': 'electronic',
#    'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'ambient house': {'discogs': {'ambient': 'electronic', 'house': 'electronic'},
#   'wikidata': {'ambient house': ['dance music',
#     'new age music',
#     'electronic music']}},
#  'ambient idm': {'discogs': {'ambient': 'electronic', 'idm': 'electronic'},
#   'wikidata': {}},
#  'ambient industrial': {'discogs': {'ambient': 'electronic',
#    'industrial': 'electronic'},
#   'wikidata': {'ambient industrial': ['electronic music',
#     'experimental music',
#     'new age music']}},
#  'ambient pop': {'discogs': {'ambient': 'electronic', 'pop': 'pop'},
#   'wikidata': {'ambient pop': ['alternative', 'rock music', 'pop music']}},
#  'ambient post-rock': {'discogs': {'rock': 'rock', 'ambient': 'electronic'},
#   'wikidata': {}},
#  'ambient psychill': {'discogs': {'ambient': 'electronic'}, 'wikidata': {}},
#  'ambient techno': {'discogs': {'ambient': 'electronic',
#    'techno': 'electronic'},
#   'wikidata': {'ambient techno': ['dance music',
#     'new age music',
#     'electronic music']}},
#  'ambient trance': {'discogs': {'ambient': 'electronic',
#    'trance': 'electronic'},
#   'wikidata': {'ambient trance': ['electronic music',
#     'new age music',
#     'dance music']}},
#  'american 21st century classical': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'american classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'american contemporary classical': {'discogs': {'classical': 'classical',
#    'contemporary': 'classical'},
#   'wikidata': {}},
#  'american folk revival': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'american grindcore': {'discogs': {'grindcore': 'rock'}, 'wikidata': {}},
#  'american melodeath': {'discogs': {}, 'wikidata': {}},
#  'american metalcore': {'discogs': {'metalcore': 'rock'}, 'wikidata': {}},
#  'american oi': {'discogs': {'oi': 'rock'}, 'wikidata': {}},
#  'american orchestra': {'discogs': {}, 'wikidata': {}},
#  'american post-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'american primitive': {'discogs': {}, 'wikidata': {}},
#  'american shoegaze': {'discogs': {'shoegaze': 'rock'}, 'wikidata': {}},
#  'amharic pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'anarcho-punk': {'discogs': {'punk': 'rock'},
#   'wikidata': {'anarcho-punk': ['rock music']}},
#  'anime': {'discogs': {}, 'wikidata': {}},
#  'anime latino': {'discogs': {}, 'wikidata': {}},
#  'anime lo-fi': {'discogs': {}, 'wikidata': {}},
#  'anime rap': {'discogs': {}, 'wikidata': {}},
#  'anime rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'ann arbor indie': {'discogs': {}, 'wikidata': {}},
#  'anthem emo': {'discogs': {'emo': 'rock'}, 'wikidata': {}},
#  'anthem worship': {'discogs': {}, 'wikidata': {}},
#  'anti-folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {'anti-folk': ['folk music']}},
#  'antideutsche': {'discogs': {}, 'wikidata': {}},
#  'appenzeller folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'arab alternative': {'discogs': {}, 'wikidata': {}},
#  'arab electronic': {'discogs': {'electronic': 'electronic'}, 'wikidata': {}},
#  'arab experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'arab folk': {'discogs': {'folk': 'folk, world, & country'}, 'wikidata': {}},
#  'arab groove': {'discogs': {}, 'wikidata': {}},
#  'arab metal': {'discogs': {}, 'wikidata': {}},
#  'arab pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'arabesk': {'discogs': {}, 'wikidata': {}},
#  'arabic hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'arabic hip hop': ['hip hop music', 'world music']}},
#  'arabic jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'arabic jazz': ['jazz', 'world music']}},
#  'argentine ambient': {'discogs': {'ambient': 'electronic'}, 'wikidata': {}},
#  'argentine hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'argentine indie': {'discogs': {}, 'wikidata': {}},
#  'argentine jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'argentine metal': {'discogs': {}, 'wikidata': {}},
#  'argentine punk': {'discogs': {'punk': 'rock'},
#   'wikidata': {'argentine punk': ['argentine punk']}},
#  'argentine reggae': {'discogs': {'reggae': 'reggae'}, 'wikidata': {}},
#  'argentine rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'argentine rock': ['world music', 'rock music']}},
#  'argentine telepop': {'discogs': {}, 'wikidata': {}},
#  'arizona punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'arkansas country': {'discogs': {'country': 'folk, world, & country'},
#   'wikidata': {}},
#  'arkansas indie': {'discogs': {}, 'wikidata': {}},
#  'arkansas metal': {'discogs': {}, 'wikidata': {}},
#  'art pop': {'discogs': {'pop': 'pop'},
#   'wikidata': {'art pop': ['pop music']}},
#  'art punk': {'discogs': {'punk': 'rock'},
#   'wikidata': {'art punk': ['rock music']}},
#  'art rock': {'discogs': {'art rock': 'rock'},
#   'wikidata': {'art rock': ['rock music']}},
#  'art song': {'discogs': {},
#   'wikidata': {'art song': ['art music', 'vocal music', 'art song']}},
#  'asbury park indie': {'discogs': {}, 'wikidata': {}},
#  'asheville indie': {'discogs': {}, 'wikidata': {}},
#  'asian american hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'asian american hip hop': ['asian american hip hop']}},
#  'athens indie': {'discogs': {}, 'wikidata': {}},
#  'atl hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'atl trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'atlanta indie': {'discogs': {}, 'wikidata': {}},
#  'atlanta metal': {'discogs': {}, 'wikidata': {}},
#  'atlanta punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'atmosphere': {'discogs': {}, 'wikidata': {}},
#  'atmospheric black metal': {'discogs': {'black metal': 'rock'},
#   'wikidata': {'atmospheric black metal': ['rock music']}},
#  'atmospheric dnb': {'discogs': {}, 'wikidata': {}},
#  'atmospheric doom': {'discogs': {}, 'wikidata': {}},
#  'atmospheric post-metal': {'discogs': {}, 'wikidata': {}},
#  'atmospheric post-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'atmospheric sludge': {'discogs': {}, 'wikidata': {}},
#  'auckland indie': {'discogs': {}, 'wikidata': {}},
#  'audiophile vocal': {'discogs': {'vocal': 'pop'}, 'wikidata': {}},
#  'aussie drill': {'discogs': {}, 'wikidata': {}},
#  'aussie emo': {'discogs': {'emo': 'rock'}, 'wikidata': {}},
#  'aussietronica': {'discogs': {}, 'wikidata': {}},
#  'austin americana': {'discogs': {}, 'wikidata': {}},
#  'austin rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'austin singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'austindie': {'discogs': {}, 'wikidata': {}},
#  'australian alternative pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'australian alternative rock': {'discogs': {'rock': 'rock',
#    'alternative rock': 'rock'},
#   'wikidata': {}},
#  'australian ambient': {'discogs': {'ambient': 'electronic'}, 'wikidata': {}},
#  'australian americana': {'discogs': {}, 'wikidata': {}},
#  'australian black metal': {'discogs': {'black metal': 'rock'},
#   'wikidata': {}},
#  'australian blues': {'discogs': {'blues': 'blues'}, 'wikidata': {}},
#  'australian classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'australian country': {'discogs': {'country': 'folk, world, & country'},
#   'wikidata': {}},
#  'australian dance': {'discogs': {}, 'wikidata': {}},
#  'australian death metal': {'discogs': {'death metal': 'rock'},
#   'wikidata': {}},
#  'australian electropop': {'discogs': {}, 'wikidata': {}},
#  'australian experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'australian garage punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'australian hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {'australian hardcore': ['rock music', 'world music']}},
#  'australian hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'australian hip hop': ['world music', 'hip hop music']}},
#  'australian house': {'discogs': {'house': 'electronic'}, 'wikidata': {}},
#  'australian indie': {'discogs': {}, 'wikidata': {}},
#  'australian indie folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'australian indie rock': {'discogs': {'rock': 'rock', 'indie rock': 'rock'},
#   'wikidata': {'australian indie rock': ['world music',
#     'rock music',
#     'alternative',
#     'independent music']}},
#  'australian indigenous': {'discogs': {}, 'wikidata': {}},
#  'australian jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'australian jazz': ['jazz', 'world music']}},
#  'australian metal': {'discogs': {}, 'wikidata': {}},
#  'australian metalcore': {'discogs': {'metalcore': 'rock'}, 'wikidata': {}},
#  'australian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'australian post-hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {}},
#  'australian post-punk': {'discogs': {'post-punk': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'australian post-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'australian psych': {'discogs': {}, 'wikidata': {}},
#  'australian r&b': {'discogs': {}, 'wikidata': {}},
#  'australian reggae fusion': {'discogs': {'reggae': 'reggae',
#    'fusion': 'jazz'},
#   'wikidata': {}},
#  'australian rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'australian rock': ['world music', 'rock music']}},
#  'australian shoegaze': {'discogs': {'shoegaze': 'rock'}, 'wikidata': {}},
#  'australian singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'australian ska': {'discogs': {'ska': 'reggae'},
#   'wikidata': {'australian ska': ['ska', 'world music']}},
#  'australian talent show': {'discogs': {}, 'wikidata': {}},
#  'australian techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'australian thrash metal': {'discogs': {'thrash': 'rock'},
#   'wikidata': {'australian thrash metal': ['rock music', 'world music']}},
#  'australian trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'australian underground hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {}},
#  'austrian black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'austrian classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'austrian contemporary classical': {'discogs': {'classical': 'classical',
#    'contemporary': 'classical'},
#   'wikidata': {}},
#  'austrian dnb': {'discogs': {}, 'wikidata': {}},
#  'austrian hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'austrian hip hop': ['world music', 'hip hop music']}},
#  'austrian indie': {'discogs': {}, 'wikidata': {}},
#  'austrian jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'austrian metal': {'discogs': {}, 'wikidata': {}},
#  'austrian orchestra': {'discogs': {}, 'wikidata': {}},
#  'austrian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'austrian punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'austrian stoner rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'austrian techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'austropop': {'discogs': {}, 'wikidata': {'austropop': ['pop music']}},
#  'auteur-compositeur-interprete quebecois': {'discogs': {}, 'wikidata': {}},
#  'autoharp': {'discogs': {}, 'wikidata': {}},
#  'autonomous black metal': {'discogs': {'black metal': 'rock'},
#   'wikidata': {}},
#  'avant-garde': {'discogs': {}, 'wikidata': {}},
#  'avant-garde black metal': {'discogs': {'black metal': 'rock'},
#   'wikidata': {}},
#  'avant-garde jazz': {'discogs': {'avant-garde jazz': 'jazz'},
#   'wikidata': {'avant-garde jazz': ['jazz', 'art music']}},
#  'avant-garde metal': {'discogs': {},
#   'wikidata': {'avant-garde metal': ['rock music']}},
#  'avant-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'axe': {'discogs': {}, 'wikidata': {}},
#  'azeri pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'azeri rap': {'discogs': {}, 'wikidata': {}},
#  'azeri traditional': {'discogs': {}, 'wikidata': {}},
#  'azonto': {'discogs': {}, 'wikidata': {'azonto': ['azonto']}},
#  'azontobeats': {'discogs': {}, 'wikidata': {}},
#  'bachata': {'discogs': {'bachata': 'latin'},
#   'wikidata': {'bachata': ['world music',
#     'dance music',
#     'music of the dominican republic']}},
#  'bachata dominicana': {'discogs': {'bachata': 'latin'}, 'wikidata': {}},
#  'background jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'background music': {'discogs': {},
#   'wikidata': {'background music': ['functional music']}},
#  'background piano': {'discogs': {}, 'wikidata': {}},
#  'backing track': {'discogs': {}, 'wikidata': {}},
#  'bagpipe': {'discogs': {}, 'wikidata': {}},
#  'baiao': {'discogs': {}, 'wikidata': {}},
#  'bakersfield sound': {'discogs': {},
#   'wikidata': {'bakersfield sound': ['world music', 'country music']}},
#  'bal-musette': {'discogs': {},
#   'wikidata': {'bal-musette': ['world music', 'folk music', 'bal-musette']}},
#  'balafon': {'discogs': {}, 'wikidata': {}},
#  'balearic': {'discogs': {}, 'wikidata': {}},
#  'balfolk': {'discogs': {}, 'wikidata': {}},
#  'balkan beats': {'discogs': {},
#   'wikidata': {'balkan beats': ['balkan beats']}},
#  'balkan brass': {'discogs': {},
#   'wikidata': {'balkan brass': ['balkan brass']}},
#  'balkan classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'balkan folk metal': {'discogs': {'folk': 'folk, world, & country',
#    'folk metal': 'rock'},
#   'wikidata': {}},
#  'balkan hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'balkan trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'ballroom': {'discogs': {'ballroom': 'electronic'},
#   'wikidata': {'ballroom': ['dance music', 'electronic music']}},
#  'baltic black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'baltic classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'baltic folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'baltic post-punk': {'discogs': {'post-punk': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'baltimore indie': {'discogs': {}, 'wikidata': {}},
#  'banda caliente': {'discogs': {}, 'wikidata': {}},
#  'bandolim': {'discogs': {}, 'wikidata': {}},
#  'bandoneon': {'discogs': {}, 'wikidata': {}},
#  'bangalore indie': {'discogs': {}, 'wikidata': {}},
#  'bangladeshi rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'bangladeshi rock': ['world music', 'rock music']}},
#  'banjo': {'discogs': {}, 'wikidata': {}},
#  'barbadian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'barbershop': {'discogs': {}, 'wikidata': {}},
#  'bard': {'discogs': {}, 'wikidata': {}},
#  'bardcore': {'discogs': {}, 'wikidata': {'bardcore': ['bardcore']}},
#  'barnmusik': {'discogs': {}, 'wikidata': {}},
#  'barockinterpreten': {'discogs': {}, 'wikidata': {}},
#  'baroque': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'baroque brass': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'baroque cello': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'baroque ensemble': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'baroque pop': {'discogs': {'pop': 'pop', 'baroque': 'classical'},
#   'wikidata': {'baroque pop': ['art music', 'pop music']}},
#  'baroque singing': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'baroque violin': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'baroque woodwind': {'discogs': {'baroque': 'classical'}, 'wikidata': {}},
#  'basel indie': {'discogs': {}, 'wikidata': {}},
#  'bass house': {'discogs': {'house': 'electronic'},
#   'wikidata': {'bass house': ['electronic music', 'dance music']}},
#  'bass music': {'discogs': {'bass music': 'electronic'},
#   'wikidata': {'bass music': ['hip hop music',
#     'world music',
#     'electronic music']}},
#  'bass trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'bass trip': {'discogs': {}, 'wikidata': {}},
#  'basshall': {'discogs': {}, 'wikidata': {}},
#  'bassline': {'discogs': {'bassline': 'electronic'},
#   'wikidata': {'bassline': ['electronic music', 'dance music']}},
#  'bath indie': {'discogs': {}, 'wikidata': {}},
#  'batida': {'discogs': {},
#   'wikidata': {'batida': ['electronic music', 'dance music', 'world music']}},
#  'baton rouge rap': {'discogs': {}, 'wikidata': {}},
#  'battle rap': {'discogs': {},
#   'wikidata': {'battle rap': ['world music',
#     'rap',
#     'hip hop music',
#     'battle rap']}},
#  'bay area hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'bay area indie': {'discogs': {}, 'wikidata': {}},
#  'bayerischer rap': {'discogs': {}, 'wikidata': {}},
#  'bboy': {'discogs': {}, 'wikidata': {}},
#  'bc underground hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'beat italiano': {'discogs': {'beat': 'rock'}, 'wikidata': {}},
#  'beatboxing': {'discogs': {}, 'wikidata': {'beatboxing': ['beatboxing']}},
#  'beatdown': {'discogs': {'beatdown': 'electronic'},
#   'wikidata': {'beatdown': ['beatdown', 'electronic music']}},
#  'beatlesque': {'discogs': {}, 'wikidata': {}},
#  'bebop': {'discogs': {}, 'wikidata': {'bebop': ['jazz']}},
#  'bedroom pop': {'discogs': {'pop': 'pop'},
#   'wikidata': {'bedroom pop': ['lo-fi music', 'pop music']}},
#  'bedroom soul': {'discogs': {'soul': 'funk / soul'}, 'wikidata': {}},
#  'belarusian indie': {'discogs': {}, 'wikidata': {}},
#  'belarusian metal': {'discogs': {}, 'wikidata': {}},
#  'belfast indie': {'discogs': {}, 'wikidata': {}},
#  'belfast metal': {'discogs': {}, 'wikidata': {}},
#  'belgian black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'belgian blues': {'discogs': {'blues': 'blues'}, 'wikidata': {}},
#  'belgian dance': {'discogs': {}, 'wikidata': {}},
#  'belgian death metal': {'discogs': {'death metal': 'rock'}, 'wikidata': {}},
#  'belgian edm': {'discogs': {}, 'wikidata': {}},
#  'belgian electronic': {'discogs': {'electronic': 'electronic'},
#   'wikidata': {}},
#  'belgian experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'belgian hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'belgian hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'belgian hip hop': ['hip hop music', 'world music']}},
#  'belgian indie': {'discogs': {}, 'wikidata': {}},
#  'belgian indie rock': {'discogs': {'rock': 'rock', 'indie rock': 'rock'},
#   'wikidata': {}},
#  'belgian jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'belgian jazz': ['belgian jazz']}},
#  'belgian metal': {'discogs': {}, 'wikidata': {}},
#  'belgian modern jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'belgian new wave': {'discogs': {}, 'wikidata': {}},
#  'belgian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'belgian post-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'belgian rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'belgian rock': ['world music', 'rock music']}},
#  'belgian singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'belgian stoner rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'belgian techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'belly dance': {'discogs': {}, 'wikidata': {}},
#  'belo horizonte indie': {'discogs': {}, 'wikidata': {}},
#  'bemani': {'discogs': {}, 'wikidata': {}},
#  'benga': {'discogs': {}, 'wikidata': {}},
#  'beninese pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'bergamo indie': {'discogs': {}, 'wikidata': {}},
#  'bergen indie': {'discogs': {}, 'wikidata': {}},
#  'berlin minimal techno': {'discogs': {'minimal': 'electronic',
#    'minimal techno': 'electronic',
#    'techno': 'electronic'},
#   'wikidata': {}},
#  'berlin school': {'discogs': {}, 'wikidata': {}},
#  'bern indie': {'discogs': {}, 'wikidata': {}},
#  'bhangra': {'discogs': {'bhangra': 'folk, world, & country'},
#   'wikidata': {'bhangra': ['bhangra']}},
#  'big band': {'discogs': {'big band': 'jazz'}, 'wikidata': {}},
#  'big beat': {'discogs': {'big beat': 'electronic'},
#   'wikidata': {'big beat': ['electronic music', 'dance music']}},
#  'big room': {'discogs': {}, 'wikidata': {}},
#  'binaural': {'discogs': {}, 'wikidata': {}},
#  'birdsong': {'discogs': {}, 'wikidata': {}},
#  'birmingham grime': {'discogs': {'grime': 'hip hop'}, 'wikidata': {}},
#  'birmingham hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'birmingham indie': {'discogs': {}, 'wikidata': {}},
#  'birmingham metal': {'discogs': {}, 'wikidata': {}},
#  'bitpop': {'discogs': {},
#   'wikidata': {'bitpop': ['pop music', 'electronic music']}},
#  "black 'n' roll": {'discogs': {},
#   'wikidata': {"black 'n' roll": ['rock music']}},
#  'black death': {'discogs': {}, 'wikidata': {}},
#  'black metal': {'discogs': {'black metal': 'rock'},
#   'wikidata': {'black metal': ['rock music']}},
#  'black metal argentino': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'black punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'black sludge': {'discogs': {}, 'wikidata': {}},
#  'black speed metal': {'discogs': {'speed metal': 'rock'}, 'wikidata': {}},
#  'black thrash': {'discogs': {'thrash': 'rock'}, 'wikidata': {}},
#  'blackened crust': {'discogs': {'crust': 'rock'},
#   'wikidata': {'blackened crust': ['rock music']}},
#  'blackened deathcore': {'discogs': {}, 'wikidata': {}},
#  'blackened hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'blackgaze': {'discogs': {},
#   'wikidata': {'blackgaze': ['rock music', 'alternative']}},
#  'blaskapelle': {'discogs': {}, 'wikidata': {}},
#  'blasmusik': {'discogs': {}, 'wikidata': {}},
#  'bleep techno': {'discogs': {'techno': 'electronic'},
#   'wikidata': {'bleep techno': ['electronic music', 'dance music']}},
#  'bluegrass': {'discogs': {'bluegrass': 'folk, world, & country'},
#   'wikidata': {}},
#  'bluegrass gospel': {'discogs': {'bluegrass': 'folk, world, & country',
#    'gospel': 'funk / soul'},
#   'wikidata': {'bluegrass gospel': ['folk music',
#     'country music',
#     'world music',
#     'american folk music',
#     'functional music']}},
#  'blues': {'discogs': {'blues': 'blues'}, 'wikidata': {'blues': ['blues']}},
#  'blues band': {'discogs': {'blues': 'blues'}, 'wikidata': {}},
#  'blues rock': {'discogs': {'blues rock': 'rock'},
#   'wikidata': {'blues rock': ['blues', 'rock music']}},
#  'blues-rock guitar': {'discogs': {'rock': 'rock', 'blues': 'blues'},
#   'wikidata': {}},
#  'bmore': {'discogs': {}, 'wikidata': {}},
#  'bolero': {'discogs': {'bolero': 'delete_7'},
#   'wikidata': {'bolero': ['world music', 'bolero']}},
#  'bolero cubano': {'discogs': {'bolero': 'delete_7', 'cubano': 'latin'},
#   'wikidata': {}},
#  'boogaloo': {'discogs': {'boogaloo': 'latin'},
#   'wikidata': {'boogaloo': ['world music', 'rhythm and blues', 'boogaloo']}},
#  'boogie': {'discogs': {'boogie': 'funk / soul'},
#   'wikidata': {'boogie': ['post-disco']}},
#  'boogie-woogie': {'discogs': {'boogie': 'funk / soul'},
#   'wikidata': {'boogie-woogie': ['boogie-woogie']}},
#  'boom bap': {'discogs': {'boom bap': 'hip hop'},
#   'wikidata': {'boom bap': ['world music', 'hip hop music']}},
#  'boom bap brasileiro': {'discogs': {'boom bap': 'hip hop'}, 'wikidata': {}},
#  'boom bap espanol': {'discogs': {'boom bap': 'hip hop'}, 'wikidata': {}},
#  'bosnian indie': {'discogs': {}, 'wikidata': {}},
#  'bossa nova': {'discogs': {'bossa nova': 'jazz'},
#   'wikidata': {'bossa nova': ['world music', 'bossa nova']}},
#  'bossa nova jazz': {'discogs': {'jazz': 'jazz', 'bossa nova': 'jazz'},
#   'wikidata': {}},
#  'boston electronic': {'discogs': {'electronic': 'electronic'},
#   'wikidata': {}},
#  'boston folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'boston hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'boston hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'boston indie': {'discogs': {}, 'wikidata': {}},
#  'boston metal': {'discogs': {}, 'wikidata': {}},
#  'boston punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'boston rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'bouncy house': {'discogs': {'house': 'electronic'}, 'wikidata': {}},
#  'bow pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'boy band': {'discogs': {}, 'wikidata': {}},
#  'braindance': {'discogs': {}, 'wikidata': {}},
#  'brass band': {'discogs': {'brass band': 'brass & military'}, 'wikidata': {}},
#  'brass band brasileiro': {'discogs': {'brass band': 'brass & military'},
#   'wikidata': {}},
#  'brass ensemble': {'discogs': {}, 'wikidata': {}},
#  'brass quintet': {'discogs': {}, 'wikidata': {}},
#  'brazilian bass': {'discogs': {},
#   'wikidata': {'brazilian bass': ['dance music', 'electronic music']}},
#  'brazilian black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'brazilian boogie': {'discogs': {'boogie': 'funk / soul'}, 'wikidata': {}},
#  'brazilian death metal': {'discogs': {'death metal': 'rock'}, 'wikidata': {}},
#  'brazilian dnb': {'discogs': {}, 'wikidata': {}},
#  'brazilian edm': {'discogs': {}, 'wikidata': {}},
#  'brazilian gospel': {'discogs': {'gospel': 'funk / soul'}, 'wikidata': {}},
#  'brazilian groove metal': {'discogs': {}, 'wikidata': {}},
#  'brazilian hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'brazilian hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'brazilian hip hop': ['world music', 'hip hop music']}},
#  'brazilian house': {'discogs': {'house': 'electronic'}, 'wikidata': {}},
#  'brazilian indie': {'discogs': {}, 'wikidata': {}},
#  'brazilian indie rock': {'discogs': {'rock': 'rock', 'indie rock': 'rock'},
#   'wikidata': {}},
#  'brazilian jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'brazilian jazz': ['jazz']}},
#  'brazilian metal': {'discogs': {}, 'wikidata': {}},
#  'brazilian modern jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'brazilian percussion': {'discogs': {}, 'wikidata': {}},
#  'brazilian post-hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {}},
#  'brazilian power metal': {'discogs': {'power metal': 'rock'}, 'wikidata': {}},
#  'brazilian progressive metal': {'discogs': {}, 'wikidata': {}},
#  'brazilian punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'brazilian punk rock': {'discogs': {'rock': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'brazilian reggae': {'discogs': {'reggae': 'reggae'}, 'wikidata': {}},
#  'brazilian rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'brazilian rock': ['rock music', 'world music']}},
#  'brazilian rockabilly': {'discogs': {'rockabilly': 'rock'}, 'wikidata': {}},
#  'brazilian soul': {'discogs': {'soul': 'funk / soul'}, 'wikidata': {}},
#  'brazilian stoner rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'brazilian surf rock': {'discogs': {'rock': 'rock', 'surf': 'rock'},
#   'wikidata': {}},
#  'brazilian techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'brazilian thrash metal': {'discogs': {'thrash': 'rock'},
#   'wikidata': {'brazilian thrash metal': ['rock music']}},
#  'breakbeat': {'discogs': {'breakbeat': 'electronic'},
#   'wikidata': {'breakbeat': ['dance music', 'electronic music']}},
#  'breakcore': {'discogs': {'breakcore': 'electronic'},
#   'wikidata': {'breakcore': ['electronic music', 'dance music']}},
#  'breaks': {'discogs': {'breaks': 'electronic'},
#   'wikidata': {'breaks': ['breaks']}},
#  'brega romantico': {'discogs': {}, 'wikidata': {}},
#  'breton folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'brighton indie': {'discogs': {}, 'wikidata': {}},
#  'brill building pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'brisbane indie': {'discogs': {}, 'wikidata': {}},
#  'bristol electronic': {'discogs': {'electronic': 'electronic'},
#   'wikidata': {}},
#  'bristol indie': {'discogs': {}, 'wikidata': {}},
#  'brit funk': {'discogs': {'funk': 'funk / soul'},
#   'wikidata': {'brit funk': ['funk', 'rhythm and blues']}},
#  'british alternative rock': {'discogs': {'rock': 'rock',
#    'alternative rock': 'rock'},
#   'wikidata': {}},
#  'british black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'british blues': {'discogs': {'blues': 'blues'},
#   'wikidata': {'british blues': ['blues']}},
#  'british brass band': {'discogs': {'brass band': 'brass & military'},
#   'wikidata': {}},
#  'british choir': {'discogs': {}, 'wikidata': {}},
#  'british classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'british contemporary classical': {'discogs': {'classical': 'classical',
#    'contemporary': 'classical'},
#   'wikidata': {}},
#  'british country': {'discogs': {'country': 'folk, world, & country'},
#   'wikidata': {}},
#  'british death metal': {'discogs': {'death metal': 'rock'}, 'wikidata': {}},
#  'british experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'british folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'british grindcore': {'discogs': {'grindcore': 'rock'}, 'wikidata': {}},
#  'british indie rock': {'discogs': {'rock': 'rock', 'indie rock': 'rock'},
#   'wikidata': {}},
#  'british industrial': {'discogs': {'industrial': 'electronic'},
#   'wikidata': {}},
#  'british invasion': {'discogs': {},
#   'wikidata': {'british invasion': ['british invasion']}},
#  'british jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'british jazz': ['world music', 'jazz']}},
#  'british math rock': {'discogs': {'rock': 'rock', 'math rock': 'rock'},
#   'wikidata': {}},
#  'british orchestra': {'discogs': {}, 'wikidata': {}},
#  'british post-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'british power metal': {'discogs': {'power metal': 'rock'}, 'wikidata': {}},
#  'british singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'british soul': {'discogs': {'soul': 'funk / soul'},
#   'wikidata': {'british soul': ['british soul']}},
#  'british soundtrack': {'discogs': {'soundtrack': 'stage & screen'},
#   'wikidata': {}},
#  'britpop': {'discogs': {'britpop': 'rock'},
#   'wikidata': {'britpop': ['rock music', 'alternative', 'pop music']}},
#  'broken beat': {'discogs': {'broken beat': 'electronic'},
#   'wikidata': {'broken beat': ['dance music', 'electronic music']}},
#  'bronx hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'brooklyn drill': {'discogs': {},
#   'wikidata': {'brooklyn drill': ['world music', 'hip hop music']}},
#  'brooklyn indie': {'discogs': {}, 'wikidata': {}},
#  'brostep': {'discogs': {}, 'wikidata': {'brostep': ['electronic music']}},
#  'brutal death metal': {'discogs': {'death metal': 'rock'},
#   'wikidata': {'brutal death metal': ['rock music']}},
#  'brutal deathcore': {'discogs': {}, 'wikidata': {}},
#  'bubble trance': {'discogs': {'trance': 'electronic'}, 'wikidata': {}},
#  'bubblegrunge': {'discogs': {}, 'wikidata': {}},
#  'bubblegum dance': {'discogs': {'bubblegum': 'pop'},
#   'wikidata': {'bubblegum dance': ['electronic music', 'dance music']}},
#  'bubblegum pop': {'discogs': {'pop': 'pop', 'bubblegum': 'pop'},
#   'wikidata': {'bubblegum pop': ['pop music',
#     'electronic music',
#     'rock music']}},
#  'buffalo ny indie': {'discogs': {}, 'wikidata': {}},
#  'buffalo ny metal': {'discogs': {}, 'wikidata': {}},
#  'bulgarian electronic': {'discogs': {'electronic': 'electronic'},
#   'wikidata': {}},
#  'bulgarian experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'bulgarian folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'bulgarian indie': {'discogs': {}, 'wikidata': {}},
#  'bulgarian metal': {'discogs': {}, 'wikidata': {}},
#  'bulgarian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'bulgarian rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'burkinabe pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'burkinabe traditional': {'discogs': {}, 'wikidata': {}},
#  'burundian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'bury st edmunds indie': {'discogs': {}, 'wikidata': {}},
#  'c-pop': {'discogs': {'pop': 'pop'},
#   'wikidata': {'c-pop': ['pop music', 'world music']}},
#  'c86': {'discogs': {},
#   'wikidata': {'c86': ['alternative',
#     'independent music',
#     'rock music',
#     'pop music']}},
#  'cabaret': {'discogs': {},
#   'wikidata': {'cabaret': ['musical theater', 'cabaret']}},
#  'calgary indie': {'discogs': {}, 'wikidata': {}},
#  'cali rap': {'discogs': {}, 'wikidata': {}},
#  'california hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {}},
#  'calming instrumental': {'discogs': {'instrumental': 'hip hop'},
#   'wikidata': {}},
#  'cambodian rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'cambodian rock': ['rock music', 'world music']}},
#  'cambridge choir': {'discogs': {}, 'wikidata': {}},
#  'cambridgeshire indie': {'discogs': {}, 'wikidata': {}},
#  'cameroonian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'canadian americana': {'discogs': {}, 'wikidata': {}},
#  'canadian black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'canadian blues': {'discogs': {'blues': 'blues'},
#   'wikidata': {'canadian blues': ['blues', 'world music']}},
#  'canadian ccm': {'discogs': {}, 'wikidata': {}},
#  'canadian celtic': {'discogs': {'celtic': 'folk, world, & country'},
#   'wikidata': {}},
#  'canadian classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'canadian contemporary country': {'discogs': {'contemporary': 'classical',
#    'country': 'folk, world, & country'},
#   'wikidata': {}},
#  'canadian contemporary r&b': {'discogs': {'contemporary': 'classical',
#    'contemporary r&b': 'funk / soul'},
#   'wikidata': {}},
#  'canadian country': {'discogs': {'country': 'folk, world, & country'},
#   'wikidata': {}},
#  'canadian death metal': {'discogs': {'death metal': 'rock'}, 'wikidata': {}},
#  'canadian drill': {'discogs': {}, 'wikidata': {}},
#  'canadian electronic': {'discogs': {'electronic': 'electronic'},
#   'wikidata': {}},
#  'canadian electropop': {'discogs': {}, 'wikidata': {}},
#  'canadian experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'canadian folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'canadian garage rock': {'discogs': {'rock': 'rock', 'garage rock': 'rock'},
#   'wikidata': {}},
#  'canadian hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'canadian hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'canadian hip hop': ['world music', 'hip hop music']}},
#  'canadian house': {'discogs': {'house': 'electronic'}, 'wikidata': {}},
#  'canadian indie': {'discogs': {}, 'wikidata': {}},
#  'canadian indie folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'canadian indigenous': {'discogs': {}, 'wikidata': {}},
#  'canadian latin': {'discogs': {'latin': 'latin'}, 'wikidata': {}},
#  'canadian metal': {'discogs': {}, 'wikidata': {}},
#  'canadian metalcore': {'discogs': {'metalcore': 'rock'}, 'wikidata': {}},
#  'canadian modern jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'canadian old school hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {}},
#  'canadian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'canadian pop punk': {'discogs': {'pop': 'pop',
#    'pop punk': 'rock',
#    'punk': 'rock'},
#   'wikidata': {}},
#  'canadian post-hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {}},
#  'canadian post-punk': {'discogs': {'post-punk': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'canadian post-rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'canadian psychedelic': {'discogs': {'psychedelic': 'funk / soul'},
#   'wikidata': {}},
#  'canadian psychedelic rock': {'discogs': {'rock': 'rock',
#    'psychedelic': 'funk / soul',
#    'psychedelic rock': 'rock'},
#   'wikidata': {}},
#  'canadian punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'canadian rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'canadian rock': ['rock music', 'world music']}},
#  'canadian rockabilly': {'discogs': {'rockabilly': 'rock'}, 'wikidata': {}},
#  'canadian shoegaze': {'discogs': {'shoegaze': 'rock'}, 'wikidata': {}},
#  'canadian singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'canadian stoner rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'canadian trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'canadian underground hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {}},
#  'cancion infantil latinoamericana': {'discogs': {}, 'wikidata': {}},
#  'cancion melodica': {'discogs': {}, 'wikidata': {}},
#  'candomble': {'discogs': {}, 'wikidata': {}},
#  'candy pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'cantautor': {'discogs': {}, 'wikidata': {}},
#  'cantautora argentina': {'discogs': {}, 'wikidata': {}},
#  'cante flamenco': {'discogs': {'flamenco': 'latin'}, 'wikidata': {}},
#  'canterbury scene': {'discogs': {},
#   'wikidata': {'canterbury scene': ['rock music']}},
#  "canzone d'autore": {'discogs': {},
#   'wikidata': {"canzone d'autore": ['vocal music',
#     'acoustic music',
#     'folk music',
#     'world music']}},
#  'canzone genovese': {'discogs': {}, 'wikidata': {}},
#  'canzone napoletana': {'discogs': {'canzone napoletana': 'folk, world, & country'},
#   'wikidata': {'canzone napoletana': ['canzone napoletana']}},
#  'cape breton folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'cape breton indie': {'discogs': {}, 'wikidata': {}},
#  'cape town indie': {'discogs': {}, 'wikidata': {}},
#  'cape verdean folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'caracas indie': {'discogs': {}, 'wikidata': {}},
#  'cardiff indie': {'discogs': {}, 'wikidata': {}},
#  'carnatic': {'discogs': {'carnatic': 'folk, world, & country'},
#   'wikidata': {}},
#  'carnatic instrumental': {'discogs': {'carnatic': 'folk, world, & country',
#    'instrumental': 'hip hop'},
#   'wikidata': {}},
#  'cascadian black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'caucasian classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'cavernous death metal': {'discogs': {'death metal': 'rock'}, 'wikidata': {}},
#  'ccm': {'discogs': {}, 'wikidata': {}},
#  'cedm': {'discogs': {}, 'wikidata': {}},
#  'cello': {'discogs': {}, 'wikidata': {}},
#  'celtic': {'discogs': {'celtic': 'folk, world, & country'}, 'wikidata': {}},
#  'celtic metal': {'discogs': {'celtic': 'folk, world, & country'},
#   'wikidata': {'celtic metal': ['rock music']}},
#  'celtic punk': {'discogs': {'celtic': 'folk, world, & country',
#    'punk': 'rock'},
#   'wikidata': {'celtic punk': ['rock music', 'folk music']}},
#  'celtic rock': {'discogs': {'rock': 'rock',
#    'celtic': 'folk, world, & country'},
#   'wikidata': {'celtic rock': ['rock music', 'folk music']}},
#  'chalga': {'discogs': {},
#   'wikidata': {'chalga': ['pop music', 'folk music']}},
#  'chamber choir': {'discogs': {}, 'wikidata': {}},
#  'chamber ensemble': {'discogs': {}, 'wikidata': {}},
#  'chamber folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {'chamber folk': ['folk music']}},
#  'chamber orchestra': {'discogs': {}, 'wikidata': {}},
#  'chamber pop': {'discogs': {'pop': 'pop'},
#   'wikidata': {'chamber pop': ['rock music',
#     'pop music',
#     'art music',
#     'alternative',
#     'independent music']}},
#  'chamber psych': {'discogs': {}, 'wikidata': {}},
#  'champeta': {'discogs': {}, 'wikidata': {'champeta': ['world music']}},
#  'channel islands indie': {'discogs': {}, 'wikidata': {}},
#  'channel pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'chanson': {'discogs': {'chanson': 'pop'},
#   'wikidata': {'chanson': ['folk music', 'world music']}},
#  'chanson paillarde': {'discogs': {'chanson': 'pop'}, 'wikidata': {}},
#  'chanson quebecois': {'discogs': {'chanson': 'pop'}, 'wikidata': {}},
#  'chanson virale': {'discogs': {'chanson': 'pop'}, 'wikidata': {}},
#  'chaotic black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'chaotic hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {'chaotic hardcore': ['rock music']}},
#  'chapman stick': {'discogs': {}, 'wikidata': {}},
#  'charanga': {'discogs': {'charanga': 'latin'}, 'wikidata': {}},
#  'charango': {'discogs': {}, 'wikidata': {}},
#  'charlotte nc indie': {'discogs': {}, 'wikidata': {}},
#  'charlottesville indie': {'discogs': {}, 'wikidata': {}},
#  'charred death': {'discogs': {}, 'wikidata': {}},
#  'chicago blues': {'discogs': {'chicago blues': 'blues'},
#   'wikidata': {'chicago blues': ['blues']}},
#  'chicago bop': {'discogs': {'bop': 'jazz'}, 'wikidata': {}},
#  'chicago drill': {'discogs': {}, 'wikidata': {}},
#  'chicago hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {'chicago hardcore': ['rock music']}},
#  'chicago house': {'discogs': {'house': 'electronic'},
#   'wikidata': {'chicago house': ['electronic music', 'dance music']}},
#  'chicago indie': {'discogs': {}, 'wikidata': {}},
#  'chicago pop punk': {'discogs': {'pop': 'pop',
#    'pop punk': 'rock',
#    'punk': 'rock'},
#   'wikidata': {}},
#  'chicago punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'chicago rap': {'discogs': {}, 'wikidata': {}},
#  'chicano punk': {'discogs': {'punk': 'rock'},
#   'wikidata': {'chicano punk': ['rock music']}},
#  'chicano rap': {'discogs': {}, 'wikidata': {'chicano rap': ['chicano rap']}},
#  'chicha': {'discogs': {}, 'wikidata': {'chicha': ['world music']}},
#  'chihuahua indie': {'discogs': {}, 'wikidata': {}},
#  "children's choir": {'discogs': {"children's": "children's"}, 'wikidata': {}},
#  "children's music": {'discogs': {"children's": "children's"},
#   'wikidata': {"children's music": ["children's music"]}},
# ...
#   'wikidata': {'croatian hip hop': ['croatian hip hop']}},
#  'croatian indie': {'discogs': {}, 'wikidata': {}},
#  'croatian metal': {'discogs': {}, 'wikidata': {}},
#  'croatian pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'croatian rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'croatian rock': ['croatian rock']}},
#  'crossover prog': {'discogs': {},
#   'wikidata': {'crossover prog': ['rock music']}},
#  'crossover thrash': {'discogs': {'thrash': 'rock'},
#   'wikidata': {'crossover thrash': ['rock music']}},
#  'crunk': {'discogs': {'crunk': 'hip hop'},
#   'wikidata': {'crunk': ['hip hop music', 'world music']}},
#  'crust punk': {'discogs': {'crust': 'rock', 'punk': 'rock'},
#   'wikidata': {'crust punk': ['rock music']}},
#  'cryptic black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'cuarteto': {'discogs': {}, 'wikidata': {'cuarteto': ['world music']}},
#  'cuatro venezolano': {'discogs': {'cuatro': 'latin'}, 'wikidata': {}},
#  'cuban alternative': {'discogs': {}, 'wikidata': {}},
#  'cuban rumba': {'discogs': {'rumba': 'latin'},
#   'wikidata': {'cuban rumba': ['world music', 'music of cuba']}},
#  'cubaton': {'discogs': {},
#   'wikidata': {'cubaton': ['world music',
#     'music of cuba',
#     'music of jamaica']}},
#  'cumbia': {'discogs': {'cumbia': 'latin'},
#   'wikidata': {'cumbia': ['world music']}},
#  'cumbia chilena': {'discogs': {'cumbia': 'latin'}, 'wikidata': {}},
#  'cumbia colombiana regia': {'discogs': {'cumbia': 'latin'}, 'wikidata': {}},
#  'cumbia peruana': {'discogs': {'cumbia': 'latin'}, 'wikidata': {}},
#  'cumbia pop': {'discogs': {'pop': 'pop', 'cumbia': 'latin'},
#   'wikidata': {'cumbia pop': ['world music', 'pop music']}},
#  'cumbia ranchera': {'discogs': {'cumbia': 'latin', 'ranchera': 'latin'},
#   'wikidata': {}},
#  'cumbia sonorense': {'discogs': {'cumbia': 'latin'}, 'wikidata': {}},
#  'cumbia villera': {'discogs': {'cumbia': 'latin'},
#   'wikidata': {'cumbia villera': ['cumbia villera']}},
#  'cyber metal': {'discogs': {},
#   'wikidata': {'cyber metal': ['electronic music',
#     'experimental music',
#     'rock music']}},
#  'cybergrind': {'discogs': {}, 'wikidata': {'cybergrind': ['rock music']}},
#  'cyberpunk': {'discogs': {}, 'wikidata': {}},
#  'czech classical piano': {'discogs': {'classical': 'classical'},
#   'wikidata': {}},
#  'czech electronic': {'discogs': {'electronic': 'electronic'}, 'wikidata': {}},
#  'czech folk': {'discogs': {'folk': 'folk, world, & country'}, 'wikidata': {}},
#  'czech hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'czech hip hop': ['world music', 'hip hop music']}},
#  'czech indie': {'discogs': {}, 'wikidata': {}},
#  'czech metal': {'discogs': {}, 'wikidata': {}},
#  'czech pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'czech pop rock': {'discogs': {'rock': 'rock',
#    'pop': 'pop',
#    'pop rock': 'rock'},
#   'wikidata': {}},
#  'czech punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'czech rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'czech rock': ['czech rock']}},
#  'czech singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'czsk black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'czsk hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'czsk reggae': {'discogs': {'reggae': 'reggae'}, 'wikidata': {}},
#  'd-beat': {'discogs': {'beat': 'rock'},
#   'wikidata': {'d-beat': ['rock music']}},
#  'dabke': {'discogs': {}, 'wikidata': {'dabke': ['dabke', 'world music']}},
#  'dainuojamoji poezija': {'discogs': {}, 'wikidata': {}},
#  'dalarna indie': {'discogs': {}, 'wikidata': {}},
#  'dance pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'dance rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'dance-punk': {'discogs': {'punk': 'rock'},
#   'wikidata': {'dance-punk': ['rock music']}},
#  'dancefloor dnb': {'discogs': {}, 'wikidata': {}},
#  'dancehall': {'discogs': {'dancehall': 'reggae'},
#   'wikidata': {'dancehall': ['music of jamaica']}},
#  'danish alternative rock': {'discogs': {'rock': 'rock',
#    'alternative rock': 'rock'},
#   'wikidata': {}},
#  'danish black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'danish death metal': {'discogs': {'death metal': 'rock'}, 'wikidata': {}},
#  'danish electro': {'discogs': {'electro': 'hip hop'}, 'wikidata': {}},
#  'danish electronic': {'discogs': {'electronic': 'electronic'},
#   'wikidata': {}},
#  'danish electropop': {'discogs': {}, 'wikidata': {}},
#  'danish experimental': {'discogs': {'experimental': 'electronic'},
#   'wikidata': {}},
#  'danish folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {}},
#  'danish hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'danish hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'danish hip hop': ['hip hop music', 'world music']}},
#  'danish indie': {'discogs': {}, 'wikidata': {}},
#  'danish indie pop': {'discogs': {'pop': 'pop', 'indie pop': 'pop'},
#   'wikidata': {}},
#  'danish jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'danish jazz': ['world music', 'jazz']}},
#  'danish metal': {'discogs': {}, 'wikidata': {}},
#  'danish modern jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'danish pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'danish pop rock': {'discogs': {'rock': 'rock',
#    'pop': 'pop',
#    'pop rock': 'rock'},
#   'wikidata': {}},
#  'danish post-punk': {'discogs': {'post-punk': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'danish punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'danish rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'danish rock': ['rock music', 'world music']}},
#  'danish singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'danish techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'dansband': {'discogs': {}, 'wikidata': {}},
#  'danseband': {'discogs': {}, 'wikidata': {}},
#  'dansktop': {'discogs': {}, 'wikidata': {'dansktop': ['dansktop']}},
#  'danspunk': {'discogs': {}, 'wikidata': {}},
#  'darbuka': {'discogs': {}, 'wikidata': {}},
#  'dark ambient': {'discogs': {'dark ambient': 'electronic'},
#   'wikidata': {'dark ambient': ['electronic music',
#     'new age music',
#     'experimental music']}},
#  'dark black metal': {'discogs': {'black metal': 'rock'}, 'wikidata': {}},
#  'dark cabaret': {'discogs': {},
#   'wikidata': {'dark cabaret': ['cabaret', 'musical theater']}},
#  'dark clubbing': {'discogs': {}, 'wikidata': {}},
#  'dark disco': {'discogs': {'disco': 'funk / soul'}, 'wikidata': {}},
#  'dark electro': {'discogs': {'electro': 'hip hop'},
#   'wikidata': {'dark electro': ['electronic music',
#     'dance music',
#     'experimental music']}},
#  'dark folk': {'discogs': {'folk': 'folk, world, & country'},
#   'wikidata': {'dark folk': ['folk music']}},
#  'dark hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'dark jazz': {'discogs': {'jazz': 'jazz'},
#   'wikidata': {'dark jazz': ['new age music',
#     'electronic music',
#     'jazz',
#     'experimental music']}},
#  'dark minimal techno': {'discogs': {'minimal': 'electronic',
#    'minimal techno': 'electronic',
#    'techno': 'electronic'},
#   'wikidata': {}},
#  'dark post-punk': {'discogs': {'post-punk': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'dark psytrance': {'discogs': {},
#   'wikidata': {'dark psytrance': ['dance music', 'electronic music']}},
#  'dark rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'dark rock': ['rock music', 'alternative']}},
#  'dark techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'dark trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'dark wave': {'discogs': {}, 'wikidata': {'dark wave': ['rock music']}},
#  'darkstep': {'discogs': {},
#   'wikidata': {'darkstep': ['dance music', 'electronic music']}},
#  'darksynth': {'discogs': {}, 'wikidata': {'darksynth': ['electronic music']}},
#  'dayton indie': {'discogs': {}, 'wikidata': {}},
#  'dc hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'dc indie': {'discogs': {}, 'wikidata': {}},
#  "death 'n' roll": {'discogs': {},
#   'wikidata': {"death 'n' roll": ['rock music', 'rock and roll']}},
#  'death doom': {'discogs': {}, 'wikidata': {}},
#  'death industrial': {'discogs': {'industrial': 'electronic'},
#   'wikidata': {'death industrial': ['electronic music',
#     'experimental music']}},
#  'death metal': {'discogs': {'death metal': 'rock'},
#   'wikidata': {'death metal': ['rock music']}},
#  'deathcore': {'discogs': {},
#   'wikidata': {'deathcore': ['rock music',
#     'dance music',
#     'electronic music']}},
#  'deathgrass': {'discogs': {}, 'wikidata': {}},
#  'deathgrind': {'discogs': {}, 'wikidata': {'deathgrind': ['rock music']}},
#  'deathrash': {'discogs': {}, 'wikidata': {'deathrash': ['rock music']}},
#  'deathrock': {'discogs': {'deathrock': 'rock'}, 'wikidata': {}},
#  'deathstep': {'discogs': {}, 'wikidata': {'deathstep': ['electronic music']}},
#  'deconstructed club': {'discogs': {},
#   'wikidata': {'deconstructed club': ['electronic music',
#     'experimental music']}},
#  'deep acoustic pop': {'discogs': {'acoustic': 'rock', 'pop': 'pop'},
#   'wikidata': {}},
#  'deep big room': {'discogs': {}, 'wikidata': {}},
#  'deep breakcore': {'discogs': {'breakcore': 'electronic'}, 'wikidata': {}},
#  'deep ccm': {'discogs': {}, 'wikidata': {}},
#  'deep chill-out': {'discogs': {}, 'wikidata': {}},
#  'deep christian rock': {'discogs': {'rock': 'rock', 'christian': 'rock'},
#   'wikidata': {}},
#  'deep classic garage rock': {'discogs': {'rock': 'rock',
#    'garage rock': 'rock'},
#   'wikidata': {}},
#  'deep comedy': {'discogs': {'comedy': 'non-music'}, 'wikidata': {}},
#  'deep dance pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'deep darkpsy': {'discogs': {}, 'wikidata': {}},
#  'deep deep house': {'discogs': {'deep house': 'electronic',
#    'house': 'electronic'},
#   'wikidata': {}},
#  'deep disco house': {'discogs': {'disco': 'funk / soul',
#    'house': 'electronic'},
#   'wikidata': {}},
#  'deep discofox': {'discogs': {}, 'wikidata': {}},
#  'deep dnb': {'discogs': {}, 'wikidata': {}},
#  'deep dubstep': {'discogs': {'dubstep': 'electronic'}, 'wikidata': {}},
#  'deep east coast hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {}},
#  'deep euro house': {'discogs': {'euro house': 'electronic',
#    'house': 'electronic'},
#   'wikidata': {}},
#  'deep flow': {'discogs': {}, 'wikidata': {}},
#  'deep folk metal': {'discogs': {'folk': 'folk, world, & country',
#    'folk metal': 'rock'},
#   'wikidata': {}},
#  'deep funk': {'discogs': {'funk': 'funk / soul'},
#   'wikidata': {'deep funk': ['funk', 'rhythm and blues']}},
#  'deep german hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'deep german indie': {'discogs': {}, 'wikidata': {}},
#  'deep german punk': {'discogs': {'punk': 'rock'}, 'wikidata': {}},
#  'deep gothic post-punk': {'discogs': {'post-punk': 'rock', 'punk': 'rock'},
#   'wikidata': {}},
#  'deep groove house': {'discogs': {'house': 'electronic'}, 'wikidata': {}},
#  'deep hardcore': {'discogs': {'hardcore': 'electronic'}, 'wikidata': {}},
#  'deep house': {'discogs': {'deep house': 'electronic'},
#   'wikidata': {'deep house': ['electronic music', 'dance music']}},
#  'deep idm': {'discogs': {'idm': 'electronic'}, 'wikidata': {}},
#  'deep indie pop': {'discogs': {'pop': 'pop', 'indie pop': 'pop'},
#   'wikidata': {}},
#  'deep indie rock': {'discogs': {'rock': 'rock', 'indie rock': 'rock'},
#   'wikidata': {}},
#  'deep indie singer-songwriter': {'discogs': {}, 'wikidata': {}},
#  'deep italo disco': {'discogs': {'disco': 'funk / soul'}, 'wikidata': {}},
#  'deep jazz fusion': {'discogs': {'jazz': 'jazz', 'fusion': 'jazz'},
#   'wikidata': {}},
#  'deep latin alternative': {'discogs': {'latin': 'latin'}, 'wikidata': {}},
#  'deep latin christian': {'discogs': {'latin': 'latin', 'christian': 'rock'},
#   'wikidata': {}},
#  'deep latin jazz': {'discogs': {'latin': 'latin',
#    'jazz': 'jazz',
#    'latin jazz': 'jazz'},
#   'wikidata': {}},
#  'deep liquid': {'discogs': {}, 'wikidata': {}},
#  'deep liquid bass': {'discogs': {}, 'wikidata': {}},
#  'deep melodic death metal': {'discogs': {'death metal': 'rock'},
#   'wikidata': {}},
#  'deep melodic hard rock': {'discogs': {'rock': 'rock', 'hard rock': 'rock'},
#   'wikidata': {}},
#  'deep melodic metalcore': {'discogs': {'metalcore': 'rock'}, 'wikidata': {}},
#  'deep metalcore': {'discogs': {'metalcore': 'rock'}, 'wikidata': {}},
#  'deep minimal techno': {'discogs': {'minimal': 'electronic',
#    'minimal techno': 'electronic',
#    'techno': 'electronic'},
#   'wikidata': {}},
#  'deep motown': {'discogs': {}, 'wikidata': {}},
#  'deep new americana': {'discogs': {}, 'wikidata': {}},
#  'deep pop edm': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'deep pop emo': {'discogs': {'pop': 'pop', 'emo': 'rock'}, 'wikidata': {}},
#  'deep power-pop punk': {'discogs': {'pop': 'pop',
#    'pop punk': 'rock',
#    'punk': 'rock'},
#   'wikidata': {}},
#  'deep progressive rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'deep psychobilly': {'discogs': {'psychobilly': 'rock'}, 'wikidata': {}},
#  'deep rai': {'discogs': {}, 'wikidata': {}},
#  'deep regional mexican': {'discogs': {}, 'wikidata': {}},
#  'deep soft rock': {'discogs': {'rock': 'rock', 'soft rock': 'rock'},
#   'wikidata': {}},
#  'deep soul house': {'discogs': {'house': 'electronic', 'soul': 'funk / soul'},
#   'wikidata': {}},
#  'deep southern trap': {'discogs': {'trap': 'delete_5'}, 'wikidata': {}},
#  'deep space rock': {'discogs': {'rock': 'rock', 'space rock': 'rock'},
#   'wikidata': {}},
#  'deep surf music': {'discogs': {'surf': 'rock'}, 'wikidata': {}},
#  'deep swedish rock': {'discogs': {'rock': 'rock'}, 'wikidata': {}},
#  'deep talent show': {'discogs': {}, 'wikidata': {}},
#  'deep tech house': {'discogs': {'house': 'electronic',
#    'tech house': 'electronic'},
#   'wikidata': {}},
#  'deep techno': {'discogs': {'deep techno': 'electronic'},
#   'wikidata': {'deep techno': ['dance music', 'electronic music']}},
#  'deep tropical house': {'discogs': {'house': 'electronic',
#    'tropical house': 'electronic'},
#   'wikidata': {}},
#  'deep turkish pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'deep underground hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {}},
#  'deep uplifting trance': {'discogs': {'trance': 'electronic'},
#   'wikidata': {}},
#  'delaware indie': {'discogs': {}, 'wikidata': {}},
#  'dembow': {'discogs': {}, 'wikidata': {'dembow': ['dembow']}},
#  'demoscene': {'discogs': {}, 'wikidata': {}},
#  'denton tx indie': {'discogs': {}, 'wikidata': {}},
#  'denver indie': {'discogs': {}, 'wikidata': {}},
#  'denver metal': {'discogs': {}, 'wikidata': {}},
#  'depressive black metal': {'discogs': {'black metal': 'rock'},
#   'wikidata': {'depressive black metal': ['depressive black metal']}},
#  'derby indie': {'discogs': {}, 'wikidata': {}},
#  'derry indie': {'discogs': {}, 'wikidata': {}},
#  'desert blues': {'discogs': {'blues': 'blues'},
#   'wikidata': {'desert blues': ['blues', 'world music']}},
#  'desi hip hop': {'discogs': {'hip hop': 'hip hop'},
#   'wikidata': {'desi hip hop': ['desi hip hop']}},
#  'desi pop': {'discogs': {'pop': 'pop'}, 'wikidata': {}},
#  'destroy techno': {'discogs': {'techno': 'electronic'}, 'wikidata': {}},
#  'detroit hip hop': {'discogs': {'hip hop': 'hip hop'}, 'wikidata': {}},
#  'detroit house': {'discogs': {'house': 'electronic'},
#   'wikidata': {'detroit house': ['dance music', 'electronic music']}},
#  'detroit indie': {'discogs': {}, 'wikidata': {}},
#  'detroit rock': {'discogs': {'rock': 'rock'},
#   'wikidata': {'detroit rock': ['rock music', 'detroit rock']}},
#  'detroit techno': {'discogs': {'techno': 'electronic'},
#   'wikidata': {'detroit techno': ['dance music', 'electronic music']}},
#  'deutschrock': {'discogs': {}, 'wikidata': {}},
#  'devon indie': {'discogs': {}, 'wikidata': {}},
#  'dfw rap': {'discogs': {}, 'wikidata': {}},
#  'didgeridoo': {'discogs': {}, 'wikidata': {}},
#  'digital hardcore': {'discogs': {'hardcore': 'electronic'},
#   'wikidata': {'digital hardcore': ['digital hardcore']}},
#  'dinner jazz': {'discogs': {'jazz': 'jazz'}, 'wikidata': {}},
#  'dirty south rap': {'discogs': {}, 'wikidata': {}},
#  'dirty texas rap': {'discogs': {}, 'wikidata': {}},
#  'disco': {'discogs': {'disco': 'funk / soul'},
#   'wikidata': {'disco': ['dance music']}},
#  ...}

# %%
counter = 0
no_match_list = list()

for genre_name, genre_matches in genres_matches_dict.items():
    discogs_genre = genre_matches['discogs']
    wikidata_genre = genre_matches['wikidata']
    if not discogs_genre and not wikidata_genre:
        no_match_list.append(genre_name)
        counter += 1
        
print(counter)
no_match_list[:10]
# Out:
# 1295
# ['aarhus indie',
#  'aberdeen indie',
#  'abstractro',
#  'accordeon',
#  'accordion',
#  'acousmatic',
#  'adoracao',
#  'adult standards',
#  'aesthetic rap',
#  'afghan rap']

# %%
no_match_dict = dict()

for genre in no_match_list:
    words = re.findall(r'\b[\w&-]+\b', genre)
    for word in words:
        try:
            counter = no_match_dict[word]
            no_match_dict[word] = counter + 1
        except KeyError:
            no_match_dict[word] = 1
            
len(no_match_dict)
# Out:
# 1159

# %%
for word, count in no_match_dict.items():
    if count > 5:
        print({word: '',})
# Out:
# {'indie': ''}
# {'rap': ''}
# {'psych': ''}
# {'r&b': ''}
# {'metal': ''}
# {'alternative': ''}
# {'americana': ''}
# {'orchestra': ''}
# {'lo-fi': ''}
# {'worship': ''}
# {'groove': ''}
# {'dnb': ''}
# {'doom': ''}
# {'drill': ''}
# {'singer-songwriter': ''}
# {'australian': ''}
# {'dance': ''}
# {'electropop': ''}
# {'traditional': ''}
# {'belgian': ''}
# {'edm': ''}
# {'new': ''}
# {'wave': ''}
# {'room': ''}
# {'deathcore': ''}
# {'brazilian': ''}
# {'progressive': ''}
# {'canadian': ''}
# {'deep': ''}
# {'german': ''}
# {'dutch': ''}
# {'prog': ''}
# {'electronica': ''}
# {'finnish': ''}
# {'folklore': ''}
# {'world': ''}
# {'french': ''}
# {'synthpop': ''}
# {'irish': ''}
# {'italian': ''}
# {'modern': ''}
# {'japanese': ''}
# {'roots': ''}
# {'melodic': ''}
# {'musica': ''}
# {'musique': ''}
# {'polish': ''}
# {'russian': ''}
# {'scottish': ''}
# {'swedish': ''}

# %%
no_match_genres = {'indie': '/genre/rock',
'rap': '/genre/hip-hop',
'psych': '/genre/rock',
'r&b': '/genre/hip-hop',
'metal': '/genre/rock',
'alternative': '/genre/rock',
'americana': '/genre/folk-world-country',
'orchestra': '/genre/classical',
'lo-fi': '/genre/rock',
'worship': '/genre/folk-world-country',
'groove': '/genre/funk-soul',
'dnb': '/genre/electronic',
'doom': '/genre/electronic',
'drill': '/genre/hip-hop',
'singer-songwriter': '/genre/folk-world-country',
'dance': '/genre/electronic',
'electropop': '/genre/pop',
'traditional': '/genre/folk-world-country',
'edm': '/genre/electronic',
'deathcore': '/genre/rock',
'progressive': '/genre/rock',
'prog': '/genre/rock',
'electronica': '/genre/electronic',
'folklore': '/genre/folk-world-country',
'world': '/genre/folk-world-country',
'synthpop': '/genre/pop',
'roots': '/genre/folk-world-country'}

# %%
genres_matches_complete_dict = genres_matches_dict.copy()

for genre in no_match_list:
    words = re.findall(r'\b[\w&-]+\b', genre)
    for word in words:
        for key, value in no_match_genres.items():
            if word in key:
                genres_matches_complete_dict[genre]['discogs'][key] = value
                
genres_matches_dict
# Out:
# {'21st century classical': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  '5th wave emo': {'discogs': {'emo': '/style/emo'}, 'wikidata': {}},
#  'a cappella': {'discogs': {}, 'wikidata': {'a cappella': 'Q185298'}},
#  'aarhus indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'aberdeen indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'abstract': {'discogs': {'abstract': '/style/abstract'}, 'wikidata': {}},
#  'abstract beats': {'discogs': {'abstract': '/style/abstract'},
#   'wikidata': {}},
#  'abstract hip hop': {'discogs': {'abstract': '/style/abstract',
#    'hip hop': '/genre/hip-hop'},
#   'wikidata': {'abstract hip hop': 'Q98528482'}},
#  'abstract idm': {'discogs': {'abstract': '/style/abstract',
#    'idm': '/style/idm'},
#   'wikidata': {}},
#  'abstractro': {'discogs': {}, 'wikidata': {}},
#  'accordeon': {'discogs': {}, 'wikidata': {}},
#  'accordion': {'discogs': {}, 'wikidata': {}},
#  'acid house': {'discogs': {'acid house': '/style/acid-house'},
#   'wikidata': {'acid house': 'Q341364'}},
#  'acid idm': {'discogs': {'acid': '/style/acid', 'idm': '/style/idm'},
#   'wikidata': {}},
#  'acid jazz': {'discogs': {'acid jazz': '/style/acid-jazz'},
#   'wikidata': {'acid jazz': 'Q221772'}},
#  'acid rock': {'discogs': {'acid rock': '/style/acid-rock'},
#   'wikidata': {'acid rock': 'Q236932'}},
#  'acid techno': {'discogs': {'acid': '/style/acid', 'techno': '/style/techno'},
#   'wikidata': {'acid techno': 'Q341395'}},
#  'acid trance': {'discogs': {'acid': '/style/acid', 'trance': '/style/trance'},
#   'wikidata': {'acid trance': 'Q481900'}},
#  'acousmatic': {'discogs': {}, 'wikidata': {}},
#  'acoustic blues': {'discogs': {'acoustic': '/style/acoustic',
#    'blues': '/genre/blues'},
#   'wikidata': {'acoustic blues': 'Q65936357'}},
#  'acoustic cover': {'discogs': {'acoustic': '/style/acoustic'},
#   'wikidata': {}},
#  'acoustic pop': {'discogs': {'acoustic': '/style/acoustic',
#    'pop': '/genre/pop'},
#   'wikidata': {}},
#  'acoustic punk': {'discogs': {'acoustic': '/style/acoustic',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'acoustic rock': {'discogs': {'rock': '/genre/rock',
#    'acoustic': '/style/acoustic'},
#   'wikidata': {'acoustic rock': 'Q65936391'}},
#  'action rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'adoracao': {'discogs': {}, 'wikidata': {}},
#  'adult standards': {'discogs': {}, 'wikidata': {}},
#  'aesthetic rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'afghan rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'african electronic': {'discogs': {'electronic': '/genre/electronic',
#    'african': '/style/african'},
#   'wikidata': {}},
#  'african experimental': {'discogs': {'african': '/style/african',
#    'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'african metal': {'discogs': {'african': '/style/african'}, 'wikidata': {}},
#  'african percussion': {'discogs': {'african': '/style/african'},
#   'wikidata': {}},
#  'african reggae': {'discogs': {'african': '/style/african',
#    'reggae': '/genre/reggae'},
#   'wikidata': {'african reggae': 'Q4690039'}},
#  'african rock': {'discogs': {'rock': '/genre/rock',
#    'african': '/style/african'},
#   'wikidata': {}},
#  'african-american classical': {'discogs': {'african': '/style/african',
#    'classical': '/genre/classical'},
#   'wikidata': {}},
#  'afrikaans': {'discogs': {}, 'wikidata': {}},
#  'afro dancehall': {'discogs': {'dancehall': '/style/dancehall'},
#   'wikidata': {}},
#  'afro house': {'discogs': {'house': '/style/house'}, 'wikidata': {}},
#  'afro psych': {'discogs': {'psych': '/genre/rock'}, 'wikidata': {}},
#  'afro r&b': {'discogs': {'r&b': '/genre/hip-hop'}, 'wikidata': {}},
#  'afro soul': {'discogs': {'soul': '/style/soul'}, 'wikidata': {}},
#  'afro-cuban percussion': {'discogs': {'afro-cuban': '/style/afro-cuban'},
#   'wikidata': {}},
#  'afro-funk': {'discogs': {'funk': '/style/funk'},
#   'wikidata': {'afro-funk': 'Q106641536'}},
#  'afrobeat': {'discogs': {'afrobeat': '/style/afrobeat'},
#   'wikidata': {'afrobeat': 'Q388296'}},
#  'afrobeat brasileiro': {'discogs': {'afrobeat': '/style/afrobeat'},
#   'wikidata': {}},
#  'afrobeat fusion': {'discogs': {'afrobeat': '/style/afrobeat',
#    'fusion': '/style/fusion'},
#   'wikidata': {}},
#  'afrofuturism': {'discogs': {}, 'wikidata': {}},
#  'afrofuturismo brasileiro': {'discogs': {}, 'wikidata': {}},
#  'afropop': {'discogs': {}, 'wikidata': {}},
#  'afroswing': {'discogs': {}, 'wikidata': {'afroswing': 'Q85740017'}},
#  'aggrotech': {'discogs': {}, 'wikidata': {'aggrotech': 'Q1091450'}},
#  'ai': {'discogs': {}, 'wikidata': {}},
#  'alabama indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'alabama metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'alabama rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'alaska indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'albanian folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'albanian hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'albanian hip hop': 'Q16357920'}},
#  'albanian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'albany ny indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'alberta country': {'discogs': {'country': '/style/country'}, 'wikidata': {}},
#  'alberta hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'album rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'albuquerque indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'algerian folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'alphorn': {'discogs': {}, 'wikidata': {}},
#  'alpine yodeling': {'discogs': {}, 'wikidata': {}},
#  'alt z': {'discogs': {'alternative': '/genre/rock'}, 'wikidata': {}},
#  'alternative americana': {'discogs': {'alternative': '/genre/rock',
#    'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'alternative country': {'discogs': {'country': '/style/country'},
#   'wikidata': {'alternative country': 'Q438476'}},
#  'alternative dance': {'discogs': {},
#   'wikidata': {'alternative dance': 'Q2187392'}},
#  'alternative emo': {'discogs': {'emo': '/style/emo'}, 'wikidata': {}},
#  'alternative hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'alternative hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'alternative hip hop': 'Q438503'}},
#  'alternative metal': {'discogs': {'alternative metal': '/style/alternative-metal'},
#   'wikidata': {'alternative metal': 'Q20378'}},
#  'alternative metalcore': {'discogs': {'metalcore': '/style/metalcore'},
#   'wikidata': {}},
#  'alternative pop': {'discogs': {'pop': '/genre/pop'},
#   'wikidata': {'alternative pop': 'Q105338947'}},
#  'alternative pop rock': {'discogs': {'rock': '/genre/rock',
#    'pop': '/genre/pop',
#    'pop rock': '/style/pop-rock'},
#   'wikidata': {}},
#  'alternative r&b': {'discogs': {},
#   'wikidata': {'alternative r&b': 'Q7118426'}},
#  'alternative rock': {'discogs': {'alternative rock': '/style/alternative-rock'},
#   'wikidata': {'alternative rock': 'Q11366'}},
#  'alternative roots rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {}},
#  'ambeat': {'discogs': {}, 'wikidata': {}},
#  'ambient': {'discogs': {'ambient': '/style/ambient'}, 'wikidata': {}},
#  'ambient black metal': {'discogs': {'ambient': '/style/ambient',
#    'black metal': '/style/black-metal'},
#   'wikidata': {'ambient black metal': 'Q8197165'}},
#  'ambient folk': {'discogs': {'ambient': '/style/ambient',
#    'folk': '/style/folk'},
#   'wikidata': {}},
#  'ambient house': {'discogs': {'ambient': '/style/ambient',
#    'house': '/style/house'},
#   'wikidata': {'ambient house': 'Q2465085'}},
#  'ambient idm': {'discogs': {'ambient': '/style/ambient', 'idm': '/style/idm'},
#   'wikidata': {}},
#  'ambient industrial': {'discogs': {'ambient': '/style/ambient',
#    'industrial': '/style/industrial'},
#   'wikidata': {'ambient industrial': 'Q1440196'}},
#  'ambient pop': {'discogs': {'ambient': '/style/ambient', 'pop': '/genre/pop'},
#   'wikidata': {'ambient pop': 'Q33160145'}},
#  'ambient post-rock': {'discogs': {'rock': '/genre/rock',
#    'ambient': '/style/ambient'},
#   'wikidata': {}},
#  'ambient psychill': {'discogs': {'ambient': '/style/ambient'},
#   'wikidata': {}},
#  'ambient techno': {'discogs': {'ambient': '/style/ambient',
#    'techno': '/style/techno'},
#   'wikidata': {'ambient techno': 'Q9149801'}},
#  'ambient trance': {'discogs': {'ambient': '/style/ambient',
#    'trance': '/style/trance'},
#   'wikidata': {'ambient trance': 'Q4993553'}},
#  'american 21st century classical': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'american classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'american contemporary classical': {'discogs': {'classical': '/genre/classical',
#    'contemporary': '/style/contemporary'},
#   'wikidata': {}},
#  'american folk revival': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'american grindcore': {'discogs': {'grindcore': '/style/grindcore'},
#   'wikidata': {}},
#  'american melodeath': {'discogs': {'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'american metalcore': {'discogs': {'metalcore': '/style/metalcore'},
#   'wikidata': {}},
#  'american oi': {'discogs': {'oi': '/style/oi'}, 'wikidata': {}},
#  'american orchestra': {'discogs': {'americana': '/genre/folk-world-country',
#    'orchestra': '/genre/classical'},
#   'wikidata': {}},
#  'american post-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'american primitive': {'discogs': {'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'american shoegaze': {'discogs': {'shoegaze': '/style/shoegaze'},
#   'wikidata': {}},
#  'amharic pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'anarcho-punk': {'discogs': {'punk': '/style/punk'},
#   'wikidata': {'anarcho-punk': 'Q486365'}},
#  'anime': {'discogs': {}, 'wikidata': {}},
#  'anime latino': {'discogs': {}, 'wikidata': {}},
#  'anime lo-fi': {'discogs': {'lo-fi': '/genre/rock'}, 'wikidata': {}},
#  'anime rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'anime rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'ann arbor indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'anthem emo': {'discogs': {'emo': '/style/emo'}, 'wikidata': {}},
#  'anthem worship': {'discogs': {'worship': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'anti-folk': {'discogs': {'folk': '/style/folk'},
#   'wikidata': {'anti-folk': 'Q574651'}},
#  'antideutsche': {'discogs': {}, 'wikidata': {}},
#  'appenzeller folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'arab alternative': {'discogs': {'alternative': '/genre/rock'},
#   'wikidata': {}},
#  'arab electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'arab experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'arab folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'arab groove': {'discogs': {'groove': '/genre/funk-soul'}, 'wikidata': {}},
#  'arab metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'arab pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'arabesk': {'discogs': {}, 'wikidata': {}},
#  'arabic hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'arabic hip hop': 'Q624221'}},
#  'arabic jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'arabic jazz': 'Q107267759'}},
#  'argentine ambient': {'discogs': {'ambient': '/style/ambient'},
#   'wikidata': {}},
#  'argentine hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'argentine indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'argentine jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'argentine metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'argentine punk': {'discogs': {'punk': '/style/punk'},
#   'wikidata': {'argentine punk': 'Q21713208'}},
#  'argentine reggae': {'discogs': {'reggae': '/genre/reggae'}, 'wikidata': {}},
#  'argentine rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'argentine rock': 'Q646026'}},
#  'argentine telepop': {'discogs': {}, 'wikidata': {}},
#  'arizona punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'arkansas country': {'discogs': {'country': '/style/country'},
#   'wikidata': {}},
#  'arkansas indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'arkansas metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'art pop': {'discogs': {'pop': '/genre/pop'},
#   'wikidata': {'art pop': 'Q25094849'}},
#  'art punk': {'discogs': {'punk': '/style/punk'},
#   'wikidata': {'art punk': 'Q659599'}},
#  'art rock': {'discogs': {'art rock': '/style/art-rock'},
#   'wikidata': {'art rock': 'Q217467'}},
#  'art song': {'discogs': {}, 'wikidata': {'art song': 'Q4797274'}},
#  'asbury park indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'asheville indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'asian american hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'asian american hip hop': 'Q55604305'}},
#  'athens indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'atl hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'atl trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'atlanta indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'atlanta metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'atlanta punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'atmosphere': {'discogs': {}, 'wikidata': {}},
#  'atmospheric black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {'atmospheric black metal': 'Q65937017'}},
#  'atmospheric dnb': {'discogs': {'dnb': '/genre/electronic'}, 'wikidata': {}},
#  'atmospheric doom': {'discogs': {'doom': '/genre/electronic'},
#   'wikidata': {}},
#  'atmospheric post-metal': {'discogs': {}, 'wikidata': {}},
#  'atmospheric post-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'atmospheric sludge': {'discogs': {}, 'wikidata': {}},
#  'auckland indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'audiophile vocal': {'discogs': {'vocal': '/style/vocal'}, 'wikidata': {}},
#  'aussie drill': {'discogs': {'drill': '/genre/hip-hop'}, 'wikidata': {}},
#  'aussie emo': {'discogs': {'emo': '/style/emo'}, 'wikidata': {}},
#  'aussietronica': {'discogs': {}, 'wikidata': {}},
#  'austin americana': {'discogs': {'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'austin rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'austin singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'austindie': {'discogs': {}, 'wikidata': {}},
#  'australian alternative pop': {'discogs': {'pop': '/genre/pop'},
#   'wikidata': {}},
#  'australian alternative rock': {'discogs': {'rock': '/genre/rock',
#    'alternative rock': '/style/alternative-rock'},
#   'wikidata': {}},
#  'australian ambient': {'discogs': {'ambient': '/style/ambient'},
#   'wikidata': {}},
#  'australian americana': {'discogs': {'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'australian black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'australian blues': {'discogs': {'blues': '/genre/blues'}, 'wikidata': {}},
#  'australian classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'australian country': {'discogs': {'country': '/style/country'},
#   'wikidata': {}},
#  'australian dance': {'discogs': {'dance': '/genre/electronic'},
#   'wikidata': {}},
#  'australian death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'australian electropop': {'discogs': {'electropop': '/genre/pop'},
#   'wikidata': {}},
#  'australian experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'australian garage punk': {'discogs': {'punk': '/style/punk'},
#   'wikidata': {}},
#  'australian hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {'australian hardcore': 'Q4825017'}},
#  'australian hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'australian hip hop': 'Q783243'}},
#  'australian house': {'discogs': {'house': '/style/house'}, 'wikidata': {}},
#  'australian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'australian indie folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'australian indie rock': {'discogs': {'rock': '/genre/rock',
#    'indie rock': '/style/indie-rock'},
#   'wikidata': {'australian indie rock': 'Q4825029'}},
#  'australian indigenous': {'discogs': {}, 'wikidata': {}},
#  'australian jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'australian jazz': 'Q4825034'}},
#  'australian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'australian metalcore': {'discogs': {'metalcore': '/style/metalcore'},
#   'wikidata': {}},
#  'australian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'australian post-hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'australian post-punk': {'discogs': {'post-punk': '/style/post-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'australian post-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'australian psych': {'discogs': {'psych': '/genre/rock'}, 'wikidata': {}},
#  'australian r&b': {'discogs': {'r&b': '/genre/hip-hop'}, 'wikidata': {}},
#  'australian reggae fusion': {'discogs': {'reggae': '/genre/reggae',
#    'fusion': '/style/fusion'},
#   'wikidata': {}},
#  'australian rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'australian rock': 'Q3437817'}},
#  'australian shoegaze': {'discogs': {'shoegaze': '/style/shoegaze'},
#   'wikidata': {}},
#  'australian singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'australian ska': {'discogs': {'ska': '/style/ska'},
#   'wikidata': {'australian ska': 'Q4825221'}},
#  'australian talent show': {'discogs': {}, 'wikidata': {}},
#  'australian techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'australian thrash metal': {'discogs': {'thrash': '/style/thrash'},
#   'wikidata': {'australian thrash metal': 'Q4825229'}},
#  'australian trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'australian underground hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'austrian black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'austrian classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'austrian contemporary classical': {'discogs': {'classical': '/genre/classical',
#    'contemporary': '/style/contemporary'},
#   'wikidata': {}},
#  'austrian dnb': {'discogs': {'dnb': '/genre/electronic'}, 'wikidata': {}},
#  'austrian hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'austrian hip hop': 'Q122772'}},
#  'austrian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'austrian jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'austrian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'austrian orchestra': {'discogs': {'orchestra': '/genre/classical'},
#   'wikidata': {}},
#  'austrian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'austrian punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'austrian stoner rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'austrian techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'austropop': {'discogs': {}, 'wikidata': {'austropop': 'Q700423'}},
#  'auteur-compositeur-interprete quebecois': {'discogs': {}, 'wikidata': {}},
#  'autoharp': {'discogs': {}, 'wikidata': {}},
#  'autonomous black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'avant-garde': {'discogs': {}, 'wikidata': {}},
#  'avant-garde black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'avant-garde jazz': {'discogs': {'avant-garde jazz': '/style/avant-garde-jazz'},
#   'wikidata': {'avant-garde jazz': 'Q790188'}},
#  'avant-garde metal': {'discogs': {},
#   'wikidata': {'avant-garde metal': 'Q641357'}},
#  'avant-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'axe': {'discogs': {}, 'wikidata': {}},
#  'azeri pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'azeri rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'azeri traditional': {'discogs': {'traditional': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'azonto': {'discogs': {}, 'wikidata': {'azonto': 'Q4832826'}},
#  'azontobeats': {'discogs': {}, 'wikidata': {}},
#  'bachata': {'discogs': {'bachata': '/style/bachata'},
#   'wikidata': {'bachata': 'Q40461'}},
#  'bachata dominicana': {'discogs': {'bachata': '/style/bachata'},
#   'wikidata': {}},
#  'background jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'background music': {'discogs': {},
#   'wikidata': {'background music': 'Q1353390'}},
#  'background piano': {'discogs': {}, 'wikidata': {}},
#  'backing track': {'discogs': {}, 'wikidata': {}},
#  'bagpipe': {'discogs': {}, 'wikidata': {}},
#  'baiao': {'discogs': {}, 'wikidata': {}},
#  'bakersfield sound': {'discogs': {},
#   'wikidata': {'bakersfield sound': 'Q804401'}},
#  'bal-musette': {'discogs': {}, 'wikidata': {'bal-musette': 'Q7770873'}},
#  'balafon': {'discogs': {}, 'wikidata': {}},
#  'balearic': {'discogs': {}, 'wikidata': {}},
#  'balfolk': {'discogs': {}, 'wikidata': {}},
#  'balkan beats': {'discogs': {}, 'wikidata': {'balkan beats': 'Q2197508'}},
#  'balkan brass': {'discogs': {}, 'wikidata': {'balkan brass': 'Q805044'}},
#  'balkan classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'balkan folk metal': {'discogs': {'folk': '/style/folk',
#    'folk metal': '/style/folk-metal'},
#   'wikidata': {}},
#  'balkan hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'balkan trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'ballroom': {'discogs': {'ballroom': '/style/ballroom'},
#   'wikidata': {'ballroom': 'Q106522098'}},
#  'baltic black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'baltic classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'baltic folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'baltic post-punk': {'discogs': {'post-punk': '/style/post-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'baltimore indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'banda caliente': {'discogs': {}, 'wikidata': {}},
#  'bandolim': {'discogs': {}, 'wikidata': {}},
#  'bandoneon': {'discogs': {}, 'wikidata': {}},
#  'bangalore indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bangladeshi rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'bangladeshi rock': 'Q4855483'}},
#  'banjo': {'discogs': {}, 'wikidata': {}},
#  'barbadian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'barbershop': {'discogs': {}, 'wikidata': {}},
#  'bard': {'discogs': {}, 'wikidata': {}},
#  'bardcore': {'discogs': {}, 'wikidata': {'bardcore': 'Q96647680'}},
#  'barnmusik': {'discogs': {}, 'wikidata': {}},
#  'barockinterpreten': {'discogs': {}, 'wikidata': {}},
#  'baroque': {'discogs': {'baroque': '/style/baroque'}, 'wikidata': {}},
#  'baroque brass': {'discogs': {'baroque': '/style/baroque'}, 'wikidata': {}},
#  'baroque cello': {'discogs': {'baroque': '/style/baroque'}, 'wikidata': {}},
#  'baroque ensemble': {'discogs': {'baroque': '/style/baroque'},
#   'wikidata': {}},
#  'baroque pop': {'discogs': {'pop': '/genre/pop', 'baroque': '/style/baroque'},
#   'wikidata': {'baroque pop': 'Q46046'}},
#  'baroque singing': {'discogs': {'baroque': '/style/baroque'}, 'wikidata': {}},
#  'baroque violin': {'discogs': {'baroque': '/style/baroque'}, 'wikidata': {}},
#  'baroque woodwind': {'discogs': {'baroque': '/style/baroque'},
#   'wikidata': {}},
#  'basel indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bass house': {'discogs': {'house': '/style/house'},
#   'wikidata': {'bass house': 'Q27345019'}},
#  'bass music': {'discogs': {'bass music': '/style/bass-music'},
#   'wikidata': {'bass music': 'Q96740854'}},
#  'bass trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'bass trip': {'discogs': {}, 'wikidata': {}},
#  'basshall': {'discogs': {}, 'wikidata': {}},
#  'bassline': {'discogs': {'bassline': '/style/bassline'},
#   'wikidata': {'bassline': 'Q4846346'}},
#  'bath indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'batida': {'discogs': {}, 'wikidata': {'batida': 'Q108297194'}},
#  'baton rouge rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'battle rap': {'discogs': {}, 'wikidata': {'battle rap': 'Q12302979'}},
#  'bay area hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'bay area indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bayerischer rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'bboy': {'discogs': {}, 'wikidata': {}},
#  'bc underground hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'beat italiano': {'discogs': {'beat': '/style/beat'}, 'wikidata': {}},
#  'beatboxing': {'discogs': {}, 'wikidata': {'beatboxing': 'Q213608'}},
#  'beatdown': {'discogs': {'beatdown': '/style/beatdown'}, 'wikidata': {}},
#  'beatlesque': {'discogs': {}, 'wikidata': {}},
#  'bebop': {'discogs': {}, 'wikidata': {'bebop': 'Q105513'}},
#  'bedroom pop': {'discogs': {'pop': '/genre/pop'},
#   'wikidata': {'bedroom pop': 'Q28746819'}},
#  'bedroom soul': {'discogs': {'soul': '/style/soul'}, 'wikidata': {}},
#  'belarusian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'belarusian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'belfast indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'belfast metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'belgian black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'belgian blues': {'discogs': {'blues': '/genre/blues'}, 'wikidata': {}},
#  'belgian dance': {'discogs': {'dance': '/genre/electronic'}, 'wikidata': {}},
#  'belgian death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'belgian edm': {'discogs': {'edm': '/genre/electronic'}, 'wikidata': {}},
#  'belgian electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'belgian experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'belgian hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'belgian hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'belgian hip hop': 'Q815536'}},
#  'belgian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'belgian indie rock': {'discogs': {'rock': '/genre/rock',
#    'indie rock': '/style/indie-rock'},
#   'wikidata': {}},
#  'belgian jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'belgian jazz': 'Q2473848'}},
#  'belgian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'belgian modern jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'belgian new wave': {'discogs': {}, 'wikidata': {}},
#  'belgian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'belgian post-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'belgian rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'belgian rock': 'Q3437819'}},
#  'belgian singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'belgian stoner rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'belgian techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'belly dance': {'discogs': {'dance': '/genre/electronic'}, 'wikidata': {}},
#  'belo horizonte indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bemani': {'discogs': {}, 'wikidata': {}},
#  'benga': {'discogs': {}, 'wikidata': {}},
#  'beninese pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'bergamo indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bergen indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'berlin minimal techno': {'discogs': {'minimal': '/style/minimal',
#    'minimal techno': '/style/minimal-techno',
#    'techno': '/style/techno'},
#   'wikidata': {}},
#  'berlin school': {'discogs': {}, 'wikidata': {}},
#  'bern indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bhangra': {'discogs': {'bhangra': '/style/bhangra'},
#   'wikidata': {'bhangra': 'Q854844'}},
#  'big band': {'discogs': {'big band': '/style/big-band'}, 'wikidata': {}},
#  'big beat': {'discogs': {'big beat': '/style/big-beat'},
#   'wikidata': {'big beat': 'Q858579'}},
#  'big room': {'discogs': {}, 'wikidata': {}},
#  'binaural': {'discogs': {}, 'wikidata': {}},
#  'birdsong': {'discogs': {}, 'wikidata': {}},
#  'birmingham grime': {'discogs': {'grime': '/style/grime'}, 'wikidata': {}},
#  'birmingham hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'birmingham indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'birmingham metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'bitpop': {'discogs': {}, 'wikidata': {'bitpop': 'Q773880'}},
#  "black 'n' roll": {'discogs': {},
#   'wikidata': {"black 'n' roll": 'Q108297198'}},
#  'black death': {'discogs': {'deathcore': '/genre/rock'}, 'wikidata': {}},
#  'black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {'black metal': 'Q132438'}},
#  'black metal argentino': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'black punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'black sludge': {'discogs': {}, 'wikidata': {}},
#  'black speed metal': {'discogs': {'speed metal': '/style/speed-metal'},
#   'wikidata': {}},
#  'black thrash': {'discogs': {'thrash': '/style/thrash'}, 'wikidata': {}},
#  'blackened crust': {'discogs': {'crust': '/style/crust'},
#   'wikidata': {'blackened crust': 'Q28070612'}},
#  'blackened deathcore': {'discogs': {'deathcore': '/genre/rock'},
#   'wikidata': {}},
#  'blackened hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'blackgaze': {'discogs': {}, 'wikidata': {'blackgaze': 'Q16855754'}},
#  'blaskapelle': {'discogs': {}, 'wikidata': {}},
#  'blasmusik': {'discogs': {}, 'wikidata': {}},
#  'bleep techno': {'discogs': {'techno': '/style/techno'},
#   'wikidata': {'bleep techno': 'Q106522080'}},
#  'bluegrass': {'discogs': {'bluegrass': '/style/bluegrass'}, 'wikidata': {}},
#  'bluegrass gospel': {'discogs': {'bluegrass': '/style/bluegrass',
#    'gospel': '/style/gospel'},
#   'wikidata': {'bluegrass gospel': 'Q21327441'}},
#  'blues': {'discogs': {'blues': '/genre/blues'},
#   'wikidata': {'blues': 'Q9759'}},
#  'blues band': {'discogs': {'blues': '/genre/blues'}, 'wikidata': {}},
#  'blues rock': {'discogs': {'blues rock': '/style/blues-rock'},
#   'wikidata': {'blues rock': 'Q193355'}},
#  'blues-rock guitar': {'discogs': {'rock': '/genre/rock',
#    'blues': '/genre/blues'},
#   'wikidata': {}},
#  'bmore': {'discogs': {}, 'wikidata': {}},
#  'bolero': {'discogs': {'bolero': '/style/bolero'},
#   'wikidata': {'bolero': 'Q15830404'}},
#  'bolero cubano': {'discogs': {'bolero': '/style/bolero',
#    'cubano': '/style/cubano'},
#   'wikidata': {}},
#  'boogaloo': {'discogs': {'boogaloo': '/style/boogaloo'},
#   'wikidata': {'boogaloo': 'Q892958'}},
#  'boogie': {'discogs': {'boogie': '/style/boogie'},
#   'wikidata': {'boogie': 'Q4942839'}},
#  'boogie-woogie': {'discogs': {'boogie': '/style/boogie'},
#   'wikidata': {'boogie-woogie': 'Q212952'}},
#  'boom bap': {'discogs': {'boom bap': '/style/boom-bap'},
#   'wikidata': {'boom bap': 'Q529742'}},
#  'boom bap brasileiro': {'discogs': {'boom bap': '/style/boom-bap'},
#   'wikidata': {}},
#  'boom bap espanol': {'discogs': {'boom bap': '/style/boom-bap'},
#   'wikidata': {}},
#  'bosnian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bossa nova': {'discogs': {'bossa nova': '/style/bossa-nova'},
#   'wikidata': {'bossa nova': 'Q486263'}},
#  'bossa nova jazz': {'discogs': {'jazz': '/genre/jazz',
#    'bossa nova': '/style/bossa-nova'},
#   'wikidata': {}},
#  'boston electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'boston folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'boston hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'boston hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'boston indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'boston metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'boston punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'boston rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'bouncy house': {'discogs': {'house': '/style/house'}, 'wikidata': {}},
#  'bow pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'boy band': {'discogs': {}, 'wikidata': {}},
#  'braindance': {'discogs': {}, 'wikidata': {}},
#  'brass band': {'discogs': {'brass band': '/style/brass-band'},
#   'wikidata': {}},
#  'brass band brasileiro': {'discogs': {'brass band': '/style/brass-band'},
#   'wikidata': {}},
#  'brass ensemble': {'discogs': {}, 'wikidata': {}},
#  'brass quintet': {'discogs': {}, 'wikidata': {}},
#  'brazilian bass': {'discogs': {},
#   'wikidata': {'brazilian bass': 'Q85748774'}},
#  'brazilian black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'brazilian boogie': {'discogs': {'boogie': '/style/boogie'}, 'wikidata': {}},
#  'brazilian death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'brazilian dnb': {'discogs': {'dnb': '/genre/electronic'}, 'wikidata': {}},
#  'brazilian edm': {'discogs': {'edm': '/genre/electronic'}, 'wikidata': {}},
#  'brazilian gospel': {'discogs': {'gospel': '/style/gospel'}, 'wikidata': {}},
#  'brazilian groove metal': {'discogs': {'groove': '/genre/funk-soul',
#    'metal': '/genre/rock'},
#   'wikidata': {}},
#  'brazilian hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'brazilian hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'brazilian hip hop': 'Q3135796'}},
#  'brazilian house': {'discogs': {'house': '/style/house'}, 'wikidata': {}},
#  'brazilian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'brazilian indie rock': {'discogs': {'rock': '/genre/rock',
#    'indie rock': '/style/indie-rock'},
#   'wikidata': {}},
#  'brazilian jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'brazilian jazz': 'Q106508649'}},
#  'brazilian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'brazilian modern jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'brazilian percussion': {'discogs': {}, 'wikidata': {}},
#  'brazilian post-hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'brazilian power metal': {'discogs': {'power metal': '/style/power-metal'},
#   'wikidata': {}},
#  'brazilian progressive metal': {'discogs': {'progressive': '/genre/rock',
#    'metal': '/genre/rock'},
#   'wikidata': {}},
#  'brazilian punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'brazilian punk rock': {'discogs': {'rock': '/genre/rock',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'brazilian reggae': {'discogs': {'reggae': '/genre/reggae'}, 'wikidata': {}},
#  'brazilian rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'brazilian rock': 'Q2631396'}},
#  'brazilian rockabilly': {'discogs': {'rockabilly': '/style/rockabilly'},
#   'wikidata': {}},
#  'brazilian soul': {'discogs': {'soul': '/style/soul'}, 'wikidata': {}},
#  'brazilian stoner rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'brazilian surf rock': {'discogs': {'rock': '/genre/rock',
#    'surf': '/style/surf'},
#   'wikidata': {}},
#  'brazilian techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'brazilian thrash metal': {'discogs': {'thrash': '/style/thrash'},
#   'wikidata': {'brazilian thrash metal': 'Q4958927'}},
#  'breakbeat': {'discogs': {'breakbeat': '/style/breakbeat'},
#   'wikidata': {'breakbeat': 'Q663519'}},
#  'breakcore': {'discogs': {'breakcore': '/style/breakcore'},
#   'wikidata': {'breakcore': 'Q903735'}},
#  'breaks': {'discogs': {'breaks': '/style/breaks'},
#   'wikidata': {'breaks': 'Q65937774'}},
#  'brega romantico': {'discogs': {}, 'wikidata': {}},
#  'breton folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'brighton indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'brill building pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'brisbane indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bristol electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'bristol indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'brit funk': {'discogs': {'funk': '/style/funk'},
#   'wikidata': {'brit funk': 'Q4969182'}},
#  'british alternative rock': {'discogs': {'rock': '/genre/rock',
#    'alternative rock': '/style/alternative-rock'},
#   'wikidata': {}},
#  'british black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'british blues': {'discogs': {'blues': '/genre/blues'},
#   'wikidata': {'british blues': 'Q918542'}},
#  'british brass band': {'discogs': {'brass band': '/style/brass-band'},
#   'wikidata': {}},
#  'british choir': {'discogs': {}, 'wikidata': {}},
#  'british classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'british contemporary classical': {'discogs': {'classical': '/genre/classical',
#    'contemporary': '/style/contemporary'},
#   'wikidata': {}},
#  'british country': {'discogs': {'country': '/style/country'}, 'wikidata': {}},
#  'british death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'british experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'british folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'british grindcore': {'discogs': {'grindcore': '/style/grindcore'},
#   'wikidata': {}},
#  'british indie rock': {'discogs': {'rock': '/genre/rock',
#    'indie rock': '/style/indie-rock'},
#   'wikidata': {}},
#  'british industrial': {'discogs': {'industrial': '/style/industrial'},
#   'wikidata': {}},
#  'british invasion': {'discogs': {},
#   'wikidata': {'british invasion': 'Q211418'}},
#  'british jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'british jazz': 'Q4971384'}},
#  'british math rock': {'discogs': {'rock': '/genre/rock',
#    'math rock': '/style/math-rock'},
#   'wikidata': {}},
#  'british orchestra': {'discogs': {'orchestra': '/genre/classical'},
#   'wikidata': {}},
#  'british post-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'british power metal': {'discogs': {'power metal': '/style/power-metal'},
#   'wikidata': {}},
#  'british singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'british soul': {'discogs': {'soul': '/style/soul'},
#   'wikidata': {'british soul': 'Q4971454'}},
#  'british soundtrack': {'discogs': {'soundtrack': '/style/soundtrack'},
#   'wikidata': {}},
#  'britpop': {'discogs': {'britpop': '/style/britpop'},
#   'wikidata': {'britpop': 'Q189045'}},
#  'broken beat': {'discogs': {'broken beat': '/style/broken-beat'},
#   'wikidata': {'broken beat': 'Q2406633'}},
#  'bronx hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'brooklyn drill': {'discogs': {},
#   'wikidata': {'brooklyn drill': 'Q104847359'}},
#  'brooklyn indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'brostep': {'discogs': {}, 'wikidata': {'brostep': 'Q20903'}},
#  'brutal death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {'brutal death metal': 'Q2265866'}},
#  'brutal deathcore': {'discogs': {'deathcore': '/genre/rock'}, 'wikidata': {}},
#  'bubble trance': {'discogs': {'trance': '/style/trance'}, 'wikidata': {}},
#  'bubblegrunge': {'discogs': {}, 'wikidata': {}},
#  'bubblegum dance': {'discogs': {'bubblegum': '/style/bubblegum'},
#   'wikidata': {'bubblegum dance': 'Q2076779'}},
#  'bubblegum pop': {'discogs': {'pop': '/genre/pop',
#    'bubblegum': '/style/bubblegum'},
#   'wikidata': {'bubblegum pop': 'Q997481'}},
#  'buffalo ny indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'buffalo ny metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'bulgarian electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'bulgarian experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'bulgarian folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'bulgarian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'bulgarian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'bulgarian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'bulgarian rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'burkinabe pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'burkinabe traditional': {'discogs': {'traditional': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'burundian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'bury st edmunds indie': {'discogs': {'orchestra': '/genre/classical',
#    'indie': '/genre/rock'},
#   'wikidata': {}},
#  'c-pop': {'discogs': {'pop': '/genre/pop'},
#   'wikidata': {'c-pop': 'Q1192110'}},
#  'c86': {'discogs': {}, 'wikidata': {'c86': 'Q97942949'}},
#  'cabaret': {'discogs': {}, 'wikidata': {'cabaret': 'Q27976507'}},
#  'calgary indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'cali rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'california hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'calming instrumental': {'discogs': {'instrumental': '/style/instrumental'},
#   'wikidata': {}},
#  'cambodian rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'cambodian rock': 'Q60745864'}},
#  'cambridge choir': {'discogs': {}, 'wikidata': {}},
#  'cambridgeshire indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'cameroonian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'canadian americana': {'discogs': {'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'canadian black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'canadian blues': {'discogs': {'blues': '/genre/blues'},
#   'wikidata': {'canadian blues': 'Q5030714'}},
#  'canadian ccm': {'discogs': {}, 'wikidata': {}},
#  'canadian celtic': {'discogs': {'celtic': '/style/celtic'}, 'wikidata': {}},
#  'canadian classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'canadian contemporary country': {'discogs': {'contemporary': '/style/contemporary',
#    'country': '/style/country'},
#   'wikidata': {}},
#  'canadian contemporary r&b': {'discogs': {'contemporary': '/style/contemporary',
#    'contemporary r&b': '/style/contemporary-r-b'},
#   'wikidata': {}},
#  'canadian country': {'discogs': {'country': '/style/country'},
#   'wikidata': {}},
#  'canadian death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'canadian drill': {'discogs': {'drill': '/genre/hip-hop'}, 'wikidata': {}},
#  'canadian electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'canadian electropop': {'discogs': {'electropop': '/genre/pop'},
#   'wikidata': {}},
#  'canadian experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'canadian folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'canadian garage rock': {'discogs': {'rock': '/genre/rock',
#    'garage rock': '/style/garage-rock'},
#   'wikidata': {}},
#  'canadian hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'canadian hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'canadian hip hop': 'Q469630'}},
#  'canadian house': {'discogs': {'house': '/style/house'}, 'wikidata': {}},
#  'canadian indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'canadian indie folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'canadian indigenous': {'discogs': {}, 'wikidata': {}},
#  'canadian latin': {'discogs': {'latin': '/genre/latin'}, 'wikidata': {}},
#  'canadian metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'canadian metalcore': {'discogs': {'metalcore': '/style/metalcore'},
#   'wikidata': {}},
#  'canadian modern jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'canadian old school hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'canadian pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'canadian pop punk': {'discogs': {'pop': '/genre/pop',
#    'pop punk': '/style/pop-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'canadian post-hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'canadian post-punk': {'discogs': {'post-punk': '/style/post-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'canadian post-rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'canadian psychedelic': {'discogs': {'psychedelic': '/style/psychedelic'},
#   'wikidata': {}},
#  'canadian psychedelic rock': {'discogs': {'rock': '/genre/rock',
#    'psychedelic': '/style/psychedelic',
#    'psychedelic rock': '/style/psychedelic-rock'},
#   'wikidata': {}},
#  'canadian punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'canadian rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'canadian rock': 'Q3437821'}},
#  'canadian rockabilly': {'discogs': {'rockabilly': '/style/rockabilly'},
#   'wikidata': {}},
#  'canadian shoegaze': {'discogs': {'shoegaze': '/style/shoegaze'},
#   'wikidata': {}},
#  'canadian singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'canadian stoner rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'canadian trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'canadian underground hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'cancion infantil latinoamericana': {'discogs': {}, 'wikidata': {}},
#  'cancion melodica': {'discogs': {}, 'wikidata': {}},
#  'candomble': {'discogs': {}, 'wikidata': {}},
#  'candy pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'cantautor': {'discogs': {}, 'wikidata': {}},
#  'cantautora argentina': {'discogs': {}, 'wikidata': {}},
#  'cante flamenco': {'discogs': {'flamenco': '/style/flamenco'},
#   'wikidata': {}},
#  'canterbury scene': {'discogs': {},
#   'wikidata': {'canterbury scene': 'Q727803'}},
#  "canzone d'autore": {'discogs': {},
#   'wikidata': {"canzone d'autore": 'Q108297209'}},
#  'canzone genovese': {'discogs': {}, 'wikidata': {}},
#  'canzone napoletana': {'discogs': {'canzone napoletana': '/style/canzone-napoletana'},
#   'wikidata': {'canzone napoletana': 'Q1195630'}},
#  'cape breton folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'cape breton indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'cape town indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'cape verdean folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'caracas indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'cardiff indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'carnatic': {'discogs': {'carnatic': '/style/carnatic'}, 'wikidata': {}},
#  'carnatic instrumental': {'discogs': {'carnatic': '/style/carnatic',
#    'instrumental': '/style/instrumental'},
#   'wikidata': {}},
#  'cascadian black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'caucasian classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'cavernous death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'ccm': {'discogs': {}, 'wikidata': {}},
#  'cedm': {'discogs': {}, 'wikidata': {}},
#  'cello': {'discogs': {}, 'wikidata': {}},
#  'celtic': {'discogs': {'celtic': '/style/celtic'}, 'wikidata': {}},
#  'celtic metal': {'discogs': {'celtic': '/style/celtic'},
#   'wikidata': {'celtic metal': 'Q2525544'}},
#  'celtic punk': {'discogs': {'celtic': '/style/celtic', 'punk': '/style/punk'},
#   'wikidata': {'celtic punk': 'Q1990122'}},
# ...
#   'wikidata': {'cuban rumba': 'Q388475'}},
#  'cubaton': {'discogs': {}, 'wikidata': {'cubaton': 'Q108297222'}},
#  'cumbia': {'discogs': {'cumbia': '/style/cumbia'},
#   'wikidata': {'cumbia': 'Q723418'}},
#  'cumbia chilena': {'discogs': {'cumbia': '/style/cumbia'}, 'wikidata': {}},
#  'cumbia colombiana regia': {'discogs': {'cumbia': '/style/cumbia'},
#   'wikidata': {}},
#  'cumbia peruana': {'discogs': {'cumbia': '/style/cumbia'}, 'wikidata': {}},
#  'cumbia pop': {'discogs': {'pop': '/genre/pop', 'cumbia': '/style/cumbia'},
#   'wikidata': {'cumbia pop': 'Q21059341'}},
#  'cumbia ranchera': {'discogs': {'cumbia': '/style/cumbia',
#    'ranchera': '/style/ranchera'},
#   'wikidata': {}},
#  'cumbia sonorense': {'discogs': {'cumbia': '/style/cumbia'}, 'wikidata': {}},
#  'cumbia villera': {'discogs': {'cumbia': '/style/cumbia'},
#   'wikidata': {'cumbia villera': 'Q1143752'}},
#  'cyber metal': {'discogs': {}, 'wikidata': {'cyber metal': 'Q3008122'}},
#  'cybergrind': {'discogs': {}, 'wikidata': {'cybergrind': 'Q3008180'}},
#  'cyberpunk': {'discogs': {}, 'wikidata': {}},
#  'czech classical piano': {'discogs': {'classical': '/genre/classical'},
#   'wikidata': {}},
#  'czech electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'czech folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'czech hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'czech hip hop': 'Q3506890'}},
#  'czech indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'czech metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'czech pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'czech pop rock': {'discogs': {'rock': '/genre/rock',
#    'pop': '/genre/pop',
#    'pop rock': '/style/pop-rock'},
#   'wikidata': {}},
#  'czech punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'czech rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'czech rock': 'Q3437882'}},
#  'czech singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'czsk black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'czsk hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'czsk reggae': {'discogs': {'reggae': '/genre/reggae'}, 'wikidata': {}},
#  'd-beat': {'discogs': {'beat': '/style/beat'},
#   'wikidata': {'d-beat': 'Q1151260'}},
#  'dabke': {'discogs': {}, 'wikidata': {'dabke': 'Q1156570'}},
#  'dainuojamoji poezija': {'discogs': {}, 'wikidata': {}},
#  'dalarna indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'dance pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'dance rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'dance-punk': {'discogs': {'punk': '/style/punk'},
#   'wikidata': {'dance-punk': 'Q1643549'}},
#  'dancefloor dnb': {'discogs': {'dnb': '/genre/electronic'}, 'wikidata': {}},
#  'dancehall': {'discogs': {'dancehall': '/style/dancehall'},
#   'wikidata': {'dancehall': 'Q474027'}},
#  'danish alternative rock': {'discogs': {'rock': '/genre/rock',
#    'alternative rock': '/style/alternative-rock'},
#   'wikidata': {}},
#  'danish black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'danish death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'danish electro': {'discogs': {'electro': '/style/electro'}, 'wikidata': {}},
#  'danish electronic': {'discogs': {'electronic': '/genre/electronic'},
#   'wikidata': {}},
#  'danish electropop': {'discogs': {'electropop': '/genre/pop'},
#   'wikidata': {}},
#  'danish experimental': {'discogs': {'experimental': '/style/experimental'},
#   'wikidata': {}},
#  'danish folk': {'discogs': {'folk': '/style/folk'}, 'wikidata': {}},
#  'danish hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {}},
#  'danish hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'danish hip hop': 'Q1270332'}},
#  'danish indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'danish indie pop': {'discogs': {'pop': '/genre/pop',
#    'indie pop': '/style/indie-pop'},
#   'wikidata': {}},
#  'danish jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'danish jazz': 'Q5219842'}},
#  'danish metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'danish modern jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'danish pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'danish pop rock': {'discogs': {'rock': '/genre/rock',
#    'pop': '/genre/pop',
#    'pop rock': '/style/pop-rock'},
#   'wikidata': {}},
#  'danish post-punk': {'discogs': {'post-punk': '/style/post-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'danish punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'danish rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'danish rock': 'Q3437827'}},
#  'danish singer-songwriter': {'discogs': {'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'danish techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'dansband': {'discogs': {}, 'wikidata': {}},
#  'danseband': {'discogs': {}, 'wikidata': {}},
#  'dansktop': {'discogs': {}, 'wikidata': {'dansktop': 'Q12307741'}},
#  'danspunk': {'discogs': {}, 'wikidata': {}},
#  'darbuka': {'discogs': {}, 'wikidata': {}},
#  'dark ambient': {'discogs': {'dark ambient': '/style/dark-ambient'},
#   'wikidata': {'dark ambient': 'Q756956'}},
#  'dark black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {}},
#  'dark cabaret': {'discogs': {}, 'wikidata': {'dark cabaret': 'Q1166158'}},
#  'dark clubbing': {'discogs': {}, 'wikidata': {}},
#  'dark disco': {'discogs': {'disco': '/style/disco'}, 'wikidata': {}},
#  'dark electro': {'discogs': {'electro': '/style/electro'},
#   'wikidata': {'dark electro': 'Q4155078'}},
#  'dark folk': {'discogs': {'folk': '/style/folk'},
#   'wikidata': {'dark folk': 'Q106621114'}},
#  'dark hardcore': {'discogs': {'hardcore': '/style/hardcore'}, 'wikidata': {}},
#  'dark jazz': {'discogs': {'jazz': '/genre/jazz'},
#   'wikidata': {'dark jazz': 'Q31837446'}},
#  'dark minimal techno': {'discogs': {'minimal': '/style/minimal',
#    'minimal techno': '/style/minimal-techno',
#    'techno': '/style/techno'},
#   'wikidata': {}},
#  'dark post-punk': {'discogs': {'post-punk': '/style/post-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'dark psytrance': {'discogs': {}, 'wikidata': {'dark psytrance': 'Q2452152'}},
#  'dark rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'dark rock': 'Q1166218'}},
#  'dark techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'dark trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'dark wave': {'discogs': {}, 'wikidata': {'dark wave': 'Q3840596'}},
#  'darkstep': {'discogs': {}, 'wikidata': {'darkstep': 'Q1166321'}},
#  'darksynth': {'discogs': {}, 'wikidata': {'darksynth': 'Q60973191'}},
#  'dayton indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'dc hardcore': {'discogs': {'hardcore': '/style/hardcore'}, 'wikidata': {}},
#  'dc indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  "death 'n' roll": {'discogs': {}, 'wikidata': {"death 'n' roll": 'Q1181308'}},
#  'death doom': {'discogs': {'deathcore': '/genre/rock',
#    'doom': '/genre/electronic'},
#   'wikidata': {}},
#  'death industrial': {'discogs': {'industrial': '/style/industrial'},
#   'wikidata': {'death industrial': 'Q3487358'}},
#  'death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {'death metal': 'Q483251'}},
#  'deathcore': {'discogs': {}, 'wikidata': {'deathcore': 'Q475221'}},
#  'deathgrass': {'discogs': {}, 'wikidata': {}},
#  'deathgrind': {'discogs': {}, 'wikidata': {'deathgrind': 'Q888612'}},
#  'deathrash': {'discogs': {}, 'wikidata': {'deathrash': 'Q11320601'}},
#  'deathrock': {'discogs': {'deathrock': '/style/deathrock'}, 'wikidata': {}},
#  'deathstep': {'discogs': {}, 'wikidata': {'deathstep': 'Q106528420'}},
#  'deconstructed club': {'discogs': {},
#   'wikidata': {'deconstructed club': 'Q96376113'}},
#  'deep acoustic pop': {'discogs': {'acoustic': '/style/acoustic',
#    'pop': '/genre/pop'},
#   'wikidata': {}},
#  'deep big room': {'discogs': {}, 'wikidata': {}},
#  'deep breakcore': {'discogs': {'breakcore': '/style/breakcore'},
#   'wikidata': {}},
#  'deep ccm': {'discogs': {}, 'wikidata': {}},
#  'deep chill-out': {'discogs': {}, 'wikidata': {}},
#  'deep christian rock': {'discogs': {'rock': '/genre/rock',
#    'christian': '/style/christian'},
#   'wikidata': {}},
#  'deep classic garage rock': {'discogs': {'rock': '/genre/rock',
#    'garage rock': '/style/garage-rock'},
#   'wikidata': {}},
#  'deep comedy': {'discogs': {'comedy': '/style/comedy'}, 'wikidata': {}},
#  'deep dance pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'deep darkpsy': {'discogs': {}, 'wikidata': {}},
#  'deep deep house': {'discogs': {'deep house': '/style/deep-house',
#    'house': '/style/house'},
#   'wikidata': {}},
#  'deep disco house': {'discogs': {'disco': '/style/disco',
#    'house': '/style/house'},
#   'wikidata': {}},
#  'deep discofox': {'discogs': {}, 'wikidata': {}},
#  'deep dnb': {'discogs': {'dnb': '/genre/electronic'}, 'wikidata': {}},
#  'deep dubstep': {'discogs': {'dubstep': '/style/dubstep'}, 'wikidata': {}},
#  'deep east coast hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'deep euro house': {'discogs': {'euro house': '/style/euro-house',
#    'house': '/style/house'},
#   'wikidata': {}},
#  'deep flow': {'discogs': {}, 'wikidata': {}},
#  'deep folk metal': {'discogs': {'folk': '/style/folk',
#    'folk metal': '/style/folk-metal'},
#   'wikidata': {}},
#  'deep funk': {'discogs': {'funk': '/style/funk'},
#   'wikidata': {'deep funk': 'Q1182371'}},
#  'deep german hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'deep german indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'deep german punk': {'discogs': {'punk': '/style/punk'}, 'wikidata': {}},
#  'deep gothic post-punk': {'discogs': {'post-punk': '/style/post-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'deep groove house': {'discogs': {'house': '/style/house'}, 'wikidata': {}},
#  'deep hardcore': {'discogs': {'hardcore': '/style/hardcore'}, 'wikidata': {}},
#  'deep house': {'discogs': {'deep house': '/style/deep-house'},
#   'wikidata': {'deep house': 'Q874038'}},
#  'deep idm': {'discogs': {'idm': '/style/idm'}, 'wikidata': {}},
#  'deep indie pop': {'discogs': {'pop': '/genre/pop',
#    'indie pop': '/style/indie-pop'},
#   'wikidata': {}},
#  'deep indie rock': {'discogs': {'rock': '/genre/rock',
#    'indie rock': '/style/indie-rock'},
#   'wikidata': {}},
#  'deep indie singer-songwriter': {'discogs': {'indie': '/genre/rock',
#    'singer-songwriter': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'deep italo disco': {'discogs': {'disco': '/style/disco'}, 'wikidata': {}},
#  'deep jazz fusion': {'discogs': {'jazz': '/genre/jazz',
#    'fusion': '/style/fusion'},
#   'wikidata': {}},
#  'deep latin alternative': {'discogs': {'latin': '/genre/latin'},
#   'wikidata': {}},
#  'deep latin christian': {'discogs': {'latin': '/genre/latin',
#    'christian': '/style/christian'},
#   'wikidata': {}},
#  'deep latin jazz': {'discogs': {'latin': '/genre/latin',
#    'jazz': '/genre/jazz',
#    'latin jazz': '/style/latin-jazz'},
#   'wikidata': {}},
#  'deep liquid': {'discogs': {}, 'wikidata': {}},
#  'deep liquid bass': {'discogs': {}, 'wikidata': {}},
#  'deep melodic death metal': {'discogs': {'death metal': '/style/death-metal'},
#   'wikidata': {}},
#  'deep melodic hard rock': {'discogs': {'rock': '/genre/rock',
#    'hard rock': '/style/hard-rock'},
#   'wikidata': {}},
#  'deep melodic metalcore': {'discogs': {'metalcore': '/style/metalcore'},
#   'wikidata': {}},
#  'deep metalcore': {'discogs': {'metalcore': '/style/metalcore'},
#   'wikidata': {}},
#  'deep minimal techno': {'discogs': {'minimal': '/style/minimal',
#    'minimal techno': '/style/minimal-techno',
#    'techno': '/style/techno'},
#   'wikidata': {}},
#  'deep motown': {'discogs': {}, 'wikidata': {}},
#  'deep new americana': {'discogs': {'americana': '/genre/folk-world-country'},
#   'wikidata': {}},
#  'deep pop edm': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'deep pop emo': {'discogs': {'pop': '/genre/pop', 'emo': '/style/emo'},
#   'wikidata': {}},
#  'deep power-pop punk': {'discogs': {'pop': '/genre/pop',
#    'pop punk': '/style/pop-punk',
#    'punk': '/style/punk'},
#   'wikidata': {}},
#  'deep progressive rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'deep psychobilly': {'discogs': {'psychobilly': '/style/psychobilly'},
#   'wikidata': {}},
#  'deep rai': {'discogs': {}, 'wikidata': {}},
#  'deep regional mexican': {'discogs': {}, 'wikidata': {}},
#  'deep soft rock': {'discogs': {'rock': '/genre/rock',
#    'soft rock': '/style/soft-rock'},
#   'wikidata': {}},
#  'deep soul house': {'discogs': {'house': '/style/house',
#    'soul': '/style/soul'},
#   'wikidata': {}},
#  'deep southern trap': {'discogs': {'trap': '/style/trap'}, 'wikidata': {}},
#  'deep space rock': {'discogs': {'rock': '/genre/rock',
#    'space rock': '/style/space-rock'},
#   'wikidata': {}},
#  'deep surf music': {'discogs': {'surf': '/style/surf'}, 'wikidata': {}},
#  'deep swedish rock': {'discogs': {'rock': '/genre/rock'}, 'wikidata': {}},
#  'deep talent show': {'discogs': {}, 'wikidata': {}},
#  'deep tech house': {'discogs': {'house': '/style/house',
#    'tech house': '/style/tech-house'},
#   'wikidata': {}},
#  'deep techno': {'discogs': {'deep techno': '/style/deep-techno'},
#   'wikidata': {'deep techno': 'Q106521662'}},
#  'deep tropical house': {'discogs': {'house': '/style/house',
#    'tropical house': '/style/tropical-house'},
#   'wikidata': {}},
#  'deep turkish pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'deep underground hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {}},
#  'deep uplifting trance': {'discogs': {'trance': '/style/trance'},
#   'wikidata': {}},
#  'delaware indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'dembow': {'discogs': {}, 'wikidata': {'dembow': 'Q16491869'}},
#  'demoscene': {'discogs': {}, 'wikidata': {}},
#  'denton tx indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'denver indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'denver metal': {'discogs': {'metal': '/genre/rock'}, 'wikidata': {}},
#  'depressive black metal': {'discogs': {'black metal': '/style/black-metal'},
#   'wikidata': {'depressive black metal': 'Q28949059'}},
#  'derby indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'derry indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'desert blues': {'discogs': {'blues': '/genre/blues'},
#   'wikidata': {'desert blues': 'Q7800608'}},
#  'desi hip hop': {'discogs': {'hip hop': '/genre/hip-hop'},
#   'wikidata': {'desi hip hop': 'Q5264196'}},
#  'desi pop': {'discogs': {'pop': '/genre/pop'}, 'wikidata': {}},
#  'destroy techno': {'discogs': {'techno': '/style/techno'}, 'wikidata': {}},
#  'detroit hip hop': {'discogs': {'hip hop': '/genre/hip-hop'}, 'wikidata': {}},
#  'detroit house': {'discogs': {'house': '/style/house'},
#   'wikidata': {'detroit house': 'Q108610706'}},
#  'detroit indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'detroit rock': {'discogs': {'rock': '/genre/rock'},
#   'wikidata': {'detroit rock': 'Q904500'}},
#  'detroit techno': {'discogs': {'techno': '/style/techno'},
#   'wikidata': {'detroit techno': 'Q526463'}},
#  'deutschrock': {'discogs': {}, 'wikidata': {}},
#  'devon indie': {'discogs': {'indie': '/genre/rock'}, 'wikidata': {}},
#  'dfw rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'didgeridoo': {'discogs': {}, 'wikidata': {}},
#  'digital hardcore': {'discogs': {'hardcore': '/style/hardcore'},
#   'wikidata': {'digital hardcore': 'Q56580'}},
#  'dinner jazz': {'discogs': {'jazz': '/genre/jazz'}, 'wikidata': {}},
#  'dirty south rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'dirty texas rap': {'discogs': {'rap': '/genre/hip-hop'}, 'wikidata': {}},
#  'disco': {'discogs': {'disco': '/style/disco'},
#   'wikidata': {'disco': 'Q58339'}},
#  ...}
